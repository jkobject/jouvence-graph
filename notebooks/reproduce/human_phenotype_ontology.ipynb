# %% [markdown]
# # Reproduce Human Phenotype Ontology
#
# Generated by reproduce/generate_parquet_reproduction_notebooks.py; do not edit.
#
# ## Objective and meaning
#
# Document the coherent `hpo` acquisition/build/mapping pipeline and safely verify all 5 current canonical Parquets assigned to it.
#
# Grouping justification: these outputs share a defensible source/transformation family context. Exact producer and command evidence remains per output and may be absent; layer alone is not used as a grouping rule, and differences remain explicit in each output contract.
#
# ## Canonical outputs owned by this notebook
#
# | Layer | Canonical output | Rows | Replay level | Catalog |
# |---|---|---:|---|---|
# | `edges` | `disease_has_phenotype` | 241,797 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__disease_has_phenotype.md) |
# | `edges` | `gene_associated_phenotype` | 3,330 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__gene_associated_phenotype.md) |
# | `edges` | `phenotype_subtype_of_phenotype` | 37,472 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__phenotype_subtype_of_phenotype.md) |
# | `features` | `phenotype_textual_summary` | 13,810 | `documented-not-replayed` | [catalog](../../docs/parquet-catalog/datasets/features__phenotype_textual_summary.md) |
# | `nodes` | `phenotype` | 16,449 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/nodes__phenotype.md) |

# %% [markdown]
# ## Native inputs, release, acquisition and environment
#
# Shared acquisition context is stated once; release and retained input differences are restated under every owned output.
#
# ## Expected schema and identifiers
#
# Each output section carries its exact catalog schema, row count, object generation and checksum.
#
# ## Keys, mappings and joins
#
# Shared family mappings are applied only where stated; every output preserves its own key contract.
#
# ## Cleaning, normalization, transformations and filters
#
# Transformation and filter differences are explicit per output below.
#
# ## Deduplication and assertion/evidence semantics
#
# Canonical edges are deduplicated assertions; source-specific multiplicity and context remain evidence/features where applicable.
#
# ## Quarantines, exclusions and missing data
#
# Every output contract states its known exclusions and unresolved provenance.
#
# ## Problems encountered and decisions
#
# Known decisions and alternatives are reported conservatively; migration identity is not treated as proof of biological replayability.
#
# ## Producer / builder
#
# The per-output contracts name an evidenced tracked producer or state that it is unavailable.
#
# ## Full worker rebuild command (inert text; never executed by this notebook)
#
# Any command below is documentation only and remains approved-worker, staging and review gated.
#
# ## Migration receipt
#
# Every output includes its generation-matched, verified migration receipt.
#
# ## QC, bounded replay and verification
#
# The first code cell validates all embedded output contracts offline. The opt-in cell verifies one selected GCS object metadata record and Parquet footer, chosen with `JOUVENCE_OUTPUT_ID`; it never scans all family outputs.
#
# ## Reproducibility limits
#
# Replay levels remain per output. No family-level label upgrades weaker members.
#
# ## Linked code, tests, reports and historical notebooks
#
# Links are listed in each output contract.

# %% [markdown]
# ## Per-output reproduction contracts
#
# ### Output `edges__disease_has_phenotype`
#
# - Canonical URI: `gs://jouvencekb/main/edges/disease_has_phenotype.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__disease_has_phenotype.md`](../../docs/parquet-catalog/datasets/edges__disease_has_phenotype.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: HPO annotation
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** HPO release 2025-05-06
#
# - `gs://jouvencekb/raw/hpo_hp.obo`
# - `gs://jouvencekb/raw/hpo_phenotype.hpoa`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **241,797**; bytes: **666,676**; row groups: **1**; schema hash (`arrow-fields-v1`): `078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1`; generation: `1785155482357028`; CRC32C: `V8jc3Q==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize HP identifiers, obsolete/replacement terms and disease/gene annotation endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse ontology definitions and annotations, normalize identifiers, build hierarchy/association assertions and source-backed summaries.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine obsolete-unresolved terms, missing endpoints and unsupported association direction; ontology hierarchy is not clinical causality.
#
# **Problems encountered and decisions.** Raw ontology/annotation files are retained, but the exact accepted graph-builder argv is historical; only the textual-summary argv is current and explicit.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/disease_has_phenotype.parquet`
# - Destination generation: `1785155482357028`
# - Destination CRC32C: `V8jc3Q==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__disease_has_phenotype.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_textual_summary_features.py`
#
#
# ### Output `edges__gene_associated_phenotype`
#
# - Canonical URI: `gs://jouvencekb/main/edges/gene_associated_phenotype.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__gene_associated_phenotype.md`](../../docs/parquet-catalog/datasets/edges__gene_associated_phenotype.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Non-causal HPO gene-to-phenotype association; direction is gene→phenotype
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** HPO release 2025-05-06
#
# - `gs://jouvencekb/raw/hpo_hp.obo`
# - `gs://jouvencekb/raw/hpo_phenotype.hpoa`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **3,330**; bytes: **19,819**; row groups: **1**; schema hash (`arrow-fields-v1`): `7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2`; generation: `1785155483521432`; CRC32C: `gB/U8w==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `display_relation` | `string` | `true` |
# | `source` | `string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize HP identifiers, obsolete/replacement terms and disease/gene annotation endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse ontology definitions and annotations, normalize identifiers, build hierarchy/association assertions and source-backed summaries.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine obsolete-unresolved terms, missing endpoints and unsupported association direction; ontology hierarchy is not clinical causality.
#
# **Problems encountered and decisions.** Raw ontology/annotation files are retained, but the exact accepted graph-builder argv is historical; only the textual-summary argv is current and explicit.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/gene_associated_phenotype.parquet`
# - Destination generation: `1785155483521432`
# - Destination CRC32C: `gB/U8w==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__gene_associated_phenotype.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_textual_summary_features.py`
#
#
# ### Output `edges__phenotype_subtype_of_phenotype`
#
# - Canonical URI: `gs://jouvencekb/main/edges/phenotype_subtype_of_phenotype.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__phenotype_subtype_of_phenotype.md`](../../docs/parquet-catalog/datasets/edges__phenotype_subtype_of_phenotype.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: HPO hierarchy
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** HPO release 2025-05-06
#
# - `gs://jouvencekb/raw/hpo_hp.obo`
# - `gs://jouvencekb/raw/hpo_phenotype.hpoa`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **37,472**; bytes: **266,843**; row groups: **1**; schema hash (`arrow-fields-v1`): `078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1`; generation: `1785155489255840`; CRC32C: `4PL6iA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize HP identifiers, obsolete/replacement terms and disease/gene annotation endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse ontology definitions and annotations, normalize identifiers, build hierarchy/association assertions and source-backed summaries.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine obsolete-unresolved terms, missing endpoints and unsupported association direction; ontology hierarchy is not clinical causality.
#
# **Problems encountered and decisions.** Raw ontology/annotation files are retained, but the exact accepted graph-builder argv is historical; only the textual-summary argv is current and explicit.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/phenotype_subtype_of_phenotype.parquet`
# - Destination generation: `1785155489255840`
# - Destination CRC32C: `4PL6iA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__phenotype_subtype_of_phenotype.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_textual_summary_features.py`
#
#
# ### Output `features__phenotype_textual_summary`
#
# - Canonical URI: `gs://jouvencekb/main/features/phenotype_textual_summary.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__phenotype_textual_summary.md`](../../docs/parquet-catalog/datasets/features__phenotype_textual_summary.md)
# - Replay level: **`documented-not-replayed`**
# - Meaning: Source-backed text payloads for `phenotype` nodes, suitable for retrieval or text feature construction.
# - Does not mean: Text is not a curated label, causal claim, or complete coverage of the node table.
#
# **Native inputs and release.** HPO release 2025-05-06
#
# - `gs://jouvencekb/raw/hpo_hp.obo`
# - `gs://jouvencekb/raw/hpo_phenotype.hpoa`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **13,810**; bytes: **1,296,148**; row groups: **1**; schema hash (`arrow-fields-v1`): `072e4e1123aae68dcd32db4e101aaaa5fe72ae3dbba51a17c9484a660724221b`; generation: `1785155496176656`; CRC32C: `w4HIzA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `feature_key` | `string` | `true` |
# | `feature_table` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `summary_kind` | `string` | `true` |
# | `summary_text` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `feature_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize HP identifiers, obsolete/replacement terms and disease/gene annotation endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse ontology definitions and annotations, normalize identifiers, build hierarchy/association assertions and source-backed summaries.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine obsolete-unresolved terms, missing endpoints and unsupported association direction; ontology hierarchy is not clinical causality.
#
# **Problems encountered and decisions.** Raw ontology/annotation files are retained, but the exact accepted graph-builder argv is historical; only the textual-summary argv is current and explicit.
#
# Known gaps: none declared.
#
# **Producer / builder.** `manage_db/build_textual_summary_features.py`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# ```text
# uv run python -m manage_db.build_textual_summary_features --node-root <worker-local-main>/nodes --output-root artifacts/staged/<task-id>/textual-summary --release HPO-2025-05-06 --hpo-obo <worker-local-raw>/hpo_hp.obo
# ```
#
# This exact argv is preserved as documentation only. It must run on an approved in-region worker, against worker-local verified inputs, with task-local staging and review before any canonical write.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/phenotype_textual_summary.parquet`
# - Destination generation: `1785155496176656`
# - Destination CRC32C: `w4HIzA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__phenotype_textual_summary.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_textual_summary_features.py`
#
#
# ### Output `nodes__phenotype`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/phenotype.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__phenotype.md`](../../docs/parquet-catalog/datasets/nodes__phenotype.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Canonical phenotype registry keyed in the HP namespace (example `HP:0000118`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** HPO release 2025-05-06
#
# - `gs://jouvencekb/raw/hpo_hp.obo`
# - `gs://jouvencekb/raw/hpo_phenotype.hpoa`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **16,449**; bytes: **410,078**; row groups: **1**; schema hash (`arrow-fields-v1`): `ac671bc0333116a3523ae3ac03be440787657a957bd36dba6120d9adcfafbf18`; generation: `1785155479660755`; CRC32C: `pJnlKA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `legacy_type` | `large_string` | `true` |
# | `legacy_id` | `large_string` | `true` |
# | `legacy_index` | `double` | `true` |
# | `source` | `large_string` | `true` |
# | `ncbi_gene_id` | `large_string` | `true` |
# | `hgnc_id` | `double` | `true` |
# | `uniprot_id` | `double` | `true` |
# | `gene_name` | `large_string` | `true` |
# | `drugbank_id` | `large_string` | `true` |
# | `pubchem_cid` | `double` | `true` |
# | `cas_rn` | `double` | `true` |
# | `inchikey` | `double` | `true` |
# | `smiles` | `double` | `true` |
# | `mondo_id` | `large_string` | `true` |
# | `efo_id` | `large_string` | `true` |
# | `mp_id` | `large_string` | `true` |
# | `mesh_id` | `large_string` | `true` |
# | `hp_id` | `large_string` | `true` |
# | `omim_id` | `double` | `true` |
# | `doid_id` | `double` | `true` |
# | `icd10_code` | `double` | `true` |
# | `go_id` | `large_string` | `true` |
# | `kegg_id` | `double` | `true` |
# | `bto_id` | `double` | `true` |
# | `fma_id` | `double` | `true` |
# | `name` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize HP identifiers, obsolete/replacement terms and disease/gene annotation endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse ontology definitions and annotations, normalize identifiers, build hierarchy/association assertions and source-backed summaries.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine obsolete-unresolved terms, missing endpoints and unsupported association direction; ontology hierarchy is not clinical causality.
#
# **Problems encountered and decisions.** Raw ontology/annotation files are retained, but the exact accepted graph-builder argv is historical; only the textual-summary argv is current and explicit.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/phenotype.parquet`
# - Destination generation: `1785155479660755`
# - Destination CRC32C: `pJnlKA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__phenotype.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_textual_summary_features.py`

# %% [markdown]
# ## Offline bounded contract check
#
# This cell uses only the embedded frozen lineage record.

# %%
import hashlib
import json

RECORDS = json.loads(r'''[{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/disease_has_phenotype.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__disease_has_phenotype.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__disease_has_phenotype.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_textual_summary_features.py"],"mappings_and_joins":"Normalize HP identifiers, obsolete/replacement terms and disease/gene annotation endpoints.","meaning":"HPO annotation","migration_receipt":{"action":"copied","destination_crc32c":"V8jc3Q==","destination_generation":"1785155482357028","source":"kg/v2/edges/disease_has_phenotype.parquet","source_generation":"1781177662189940","verified":true},"name":"disease_has_phenotype","native_inputs":["gs://jouvencekb/raw/hpo_hp.obo","gs://jouvencekb/raw/hpo_phenotype.hpoa"],"native_source":["gs://jouvencekb/raw/hpo_hp.obo","gs://jouvencekb/raw/hpo_phenotype.hpoa"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"hpo","problems_and_decisions":"Raw ontology/annotation files are retained, but the exact accepted graph-builder argv is historical; only the textual-summary argv is current and explicit.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":666676,"crc32c_base64":"V8jc3Q==","generation":"1785155482357028","md5_base64":"LzGaBzwFr9sL2HDzpJIr1Q==","row_groups":1,"rows":241797,"schema_hash":"078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine obsolete-unresolved terms, missing endpoints and unsupported association direction; ontology hierarchy is not clinical causality.","rebuild_command_evidenced":false,"release":"HPO release 2025-05-06","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/human_phenotype_ontology.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"hpo","source_family_label":"Human Phenotype Ontology","transformations_and_filters":"Parse ontology definitions and annotations, normalize identifiers, build hierarchy/association assertions and source-backed summaries."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/gene_associated_phenotype.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__gene_associated_phenotype.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"display_relation","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__gene_associated_phenotype.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_textual_summary_features.py"],"mappings_and_joins":"Normalize HP identifiers, obsolete/replacement terms and disease/gene annotation endpoints.","meaning":"Non-causal HPO gene-to-phenotype association; direction is gene→phenotype","migration_receipt":{"action":"copied","destination_crc32c":"gB/U8w==","destination_generation":"1785155483521432","source":"kg/v2/edges/gene_associated_phenotype.parquet","source_generation":"1781796935596578","verified":true},"name":"gene_associated_phenotype","native_inputs":["gs://jouvencekb/raw/hpo_hp.obo","gs://jouvencekb/raw/hpo_phenotype.hpoa"],"native_source":["gs://jouvencekb/raw/hpo_hp.obo","gs://jouvencekb/raw/hpo_phenotype.hpoa"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"hpo","problems_and_decisions":"Raw ontology/annotation files are retained, but the exact accepted graph-builder argv is historical; only the textual-summary argv is current and explicit.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":19819,"crc32c_base64":"gB/U8w==","generation":"1785155483521432","md5_base64":"vaRjl1yRJAvKUonzqJlFvQ==","row_groups":1,"rows":3330,"schema_hash":"7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine obsolete-unresolved terms, missing endpoints and unsupported association direction; ontology hierarchy is not clinical causality.","rebuild_command_evidenced":false,"release":"HPO release 2025-05-06","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/human_phenotype_ontology.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"hpo","source_family_label":"Human Phenotype Ontology","transformations_and_filters":"Parse ontology definitions and annotations, normalize identifiers, build hierarchy/association assertions and source-backed summaries."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/phenotype_subtype_of_phenotype.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__phenotype_subtype_of_phenotype.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__phenotype_subtype_of_phenotype.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_textual_summary_features.py"],"mappings_and_joins":"Normalize HP identifiers, obsolete/replacement terms and disease/gene annotation endpoints.","meaning":"HPO hierarchy","migration_receipt":{"action":"copied","destination_crc32c":"4PL6iA==","destination_generation":"1785155489255840","source":"kg/v2/edges/phenotype_subtype_of_phenotype.parquet","source_generation":"1780837807126694","verified":true},"name":"phenotype_subtype_of_phenotype","native_inputs":["gs://jouvencekb/raw/hpo_hp.obo","gs://jouvencekb/raw/hpo_phenotype.hpoa"],"native_source":["gs://jouvencekb/raw/hpo_hp.obo","gs://jouvencekb/raw/hpo_phenotype.hpoa"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"hpo","problems_and_decisions":"Raw ontology/annotation files are retained, but the exact accepted graph-builder argv is historical; only the textual-summary argv is current and explicit.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":266843,"crc32c_base64":"4PL6iA==","generation":"1785155489255840","md5_base64":"V5PLVbt3kn+RkoW2BHUmNg==","row_groups":1,"rows":37472,"schema_hash":"078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine obsolete-unresolved terms, missing endpoints and unsupported association direction; ontology hierarchy is not clinical causality.","rebuild_command_evidenced":false,"release":"HPO release 2025-05-06","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/human_phenotype_ontology.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"hpo","source_family_label":"Human Phenotype Ontology","transformations_and_filters":"Parse ontology definitions and annotations, normalize identifiers, build hierarchy/association assertions and source-backed summaries."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/phenotype_textual_summary.parquet","catalog_page":"docs/parquet-catalog/datasets/features__phenotype_textual_summary.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"feature_key","nullable":true},{"dtype":"string","name":"feature_table","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"summary_kind","nullable":true},{"dtype":"string","name":"summary_text","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":"uv run python -m manage_db.build_textual_summary_features --node-root <worker-local-main>/nodes --output-root artifacts/staged/<task-id>/textual-summary --release HPO-2025-05-06 --hpo-obo <worker-local-raw>/hpo_hp.obo","keys":{"candidate_join":["feature_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":[],"layer":"features","links":["docs/parquet-catalog/datasets/features__phenotype_textual_summary.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_textual_summary_features.py"],"mappings_and_joins":"Normalize HP identifiers, obsolete/replacement terms and disease/gene annotation endpoints.","meaning":"Source-backed text payloads for `phenotype` nodes, suitable for retrieval or text feature construction.","migration_receipt":{"action":"copied","destination_crc32c":"w4HIzA==","destination_generation":"1785155496176656","source":"kg/v2/features/phenotype_textual_summary.parquet","source_generation":"1782169819880354","verified":true},"name":"phenotype_textual_summary","native_inputs":["gs://jouvencekb/raw/hpo_hp.obo","gs://jouvencekb/raw/hpo_phenotype.hpoa"],"native_source":["gs://jouvencekb/raw/hpo_hp.obo","gs://jouvencekb/raw/hpo_phenotype.hpoa"],"non_meaning":"Text is not a curated label, causal claim, or complete coverage of the node table.","pipeline_family":"hpo","problems_and_decisions":"Raw ontology/annotation files are retained, but the exact accepted graph-builder argv is historical; only the textual-summary argv is current and explicit.","producer":"manage_db/build_textual_summary_features.py","producer_builder":"manage_db/build_textual_summary_features.py","provenance_gaps":[],"qc":{"as_of":"2026-07-27","bytes":1296148,"crc32c_base64":"w4HIzA==","generation":"1785155496176656","md5_base64":"ZeRlCu86punWj82aOEDrKA==","row_groups":1,"rows":13810,"schema_hash":"072e4e1123aae68dcd32db4e101aaaa5fe72ae3dbba51a17c9484a660724221b","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine obsolete-unresolved terms, missing endpoints and unsupported association direction; ontology hierarchy is not clinical causality.","rebuild_command_evidenced":true,"release":"HPO release 2025-05-06","replay_level":"documented-not-replayed","reproduce_notebook":"notebooks/reproduce/human_phenotype_ontology.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"documented-not-replayed","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"hpo","source_family_label":"Human Phenotype Ontology","transformations_and_filters":"Parse ontology definitions and annotations, normalize identifiers, build hierarchy/association assertions and source-backed summaries."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/phenotype.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__phenotype.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"large_string","name":"legacy_type","nullable":true},{"dtype":"large_string","name":"legacy_id","nullable":true},{"dtype":"double","name":"legacy_index","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"large_string","name":"ncbi_gene_id","nullable":true},{"dtype":"double","name":"hgnc_id","nullable":true},{"dtype":"double","name":"uniprot_id","nullable":true},{"dtype":"large_string","name":"gene_name","nullable":true},{"dtype":"large_string","name":"drugbank_id","nullable":true},{"dtype":"double","name":"pubchem_cid","nullable":true},{"dtype":"double","name":"cas_rn","nullable":true},{"dtype":"double","name":"inchikey","nullable":true},{"dtype":"double","name":"smiles","nullable":true},{"dtype":"large_string","name":"mondo_id","nullable":true},{"dtype":"large_string","name":"efo_id","nullable":true},{"dtype":"large_string","name":"mp_id","nullable":true},{"dtype":"large_string","name":"mesh_id","nullable":true},{"dtype":"large_string","name":"hp_id","nullable":true},{"dtype":"double","name":"omim_id","nullable":true},{"dtype":"double","name":"doid_id","nullable":true},{"dtype":"double","name":"icd10_code","nullable":true},{"dtype":"large_string","name":"go_id","nullable":true},{"dtype":"double","name":"kegg_id","nullable":true},{"dtype":"double","name":"bto_id","nullable":true},{"dtype":"double","name":"fma_id","nullable":true},{"dtype":"large_string","name":"name","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__phenotype.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_textual_summary_features.py"],"mappings_and_joins":"Normalize HP identifiers, obsolete/replacement terms and disease/gene annotation endpoints.","meaning":"Canonical phenotype registry keyed in the HP namespace (example `HP:0000118`).","migration_receipt":{"action":"copied","destination_crc32c":"pJnlKA==","destination_generation":"1785155479660755","source":"kg/v2/nodes/phenotype.parquet","source_generation":"1781009655679863","verified":true},"name":"phenotype","native_inputs":["gs://jouvencekb/raw/hpo_hp.obo","gs://jouvencekb/raw/hpo_phenotype.hpoa"],"native_source":["gs://jouvencekb/raw/hpo_hp.obo","gs://jouvencekb/raw/hpo_phenotype.hpoa"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"hpo","problems_and_decisions":"Raw ontology/annotation files are retained, but the exact accepted graph-builder argv is historical; only the textual-summary argv is current and explicit.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":410078,"crc32c_base64":"pJnlKA==","generation":"1785155479660755","md5_base64":"+cd5285HnASq4ih//X9a8A==","row_groups":1,"rows":16449,"schema_hash":"ac671bc0333116a3523ae3ac03be440787657a957bd36dba6120d9adcfafbf18","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine obsolete-unresolved terms, missing endpoints and unsupported association direction; ontology hierarchy is not clinical causality.","rebuild_command_evidenced":false,"release":"HPO release 2025-05-06","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/human_phenotype_ontology.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"hpo","source_family_label":"Human Phenotype Ontology","transformations_and_filters":"Parse ontology definitions and annotations, normalize identifiers, build hierarchy/association assertions and source-backed summaries."}]''')

def require(condition, message):
    if not condition:
        raise RuntimeError(message)

for RECORD in RECORDS:
    require(RECORD["canonical_uri"] == "gs://jouvencekb/main/" + ("embeddings" if RECORD["layer"] == "embedding" else RECORD["layer"]) + "/" + RECORD["name"] + ".parquet", "canonical URI/identity mismatch")
    require(RECORD["replay_level"] in ['documented-not-replayed', 'fully-replayable', 'historical-builder-only', 'provenance-gap'], "unsupported replay level")
    require(RECORD["qc"]["rows"] >= 0, "negative expected row count")
    require(len(RECORD["qc"]["schema_hash"]) == 64, "invalid schema hash")
    require(RECORD["migration_receipt"]["verified"] is True, "migration receipt is not verified")
    require(bool(RECORD["fields"]), "empty expected schema")
summary = {
    "pipeline_family": RECORDS[0]["pipeline_family"],
    "output_count": len(RECORDS),
    "identities": [record["layer"] + "__" + record["name"] for record in RECORDS],
}
summary

# %% [markdown]
# ## Optional bounded live canonical footer check
#
# This cell is skipped unless the caller explicitly opts in.

# %%
import os

if os.environ.get("JOUVENCE_LIVE_GCS") != "1":
    live_result = {"status": "SKIPPED", "reason": "set JOUVENCE_LIVE_GCS=1 and caller-owned JOUVENCE_BILLING_PROJECT"}
else:
    import gcsfs
    import pyarrow.parquet as pq

    billing_project = os.environ.get("JOUVENCE_BILLING_PROJECT")
    if not billing_project:
        raise RuntimeError("JOUVENCE_BILLING_PROJECT is required for requester-pays live verification")
    fs = gcsfs.GCSFileSystem(project=billing_project, requester_pays=billing_project, version_aware=True)
    if not fs.version_aware:
        raise RuntimeError("version-aware GCS reads are required")
    selected_id = os.environ.get("JOUVENCE_OUTPUT_ID", RECORDS[0]["layer"] + "__" + RECORDS[0]["name"])
    selected = [record for record in RECORDS if record["layer"] + "__" + record["name"] == selected_id]
    if len(selected) != 1:
        raise RuntimeError("JOUVENCE_OUTPUT_ID must select exactly one output owned by this notebook")
    RECORD = selected[0]
    object_path = RECORD["canonical_uri"].removeprefix("gs://")
    if "#" in object_path:
        raise RuntimeError("canonical object key must not already contain a generation suffix")
    expected_generation = RECORD["qc"]["generation"]
    pinned_path = object_path + "#" + expected_generation
    info = fs.info(pinned_path)
    if str(info.get("generation", "")) != expected_generation:
        raise RuntimeError("generation-qualified object resolved a different generation")
    with fs.open(pinned_path, "rb") as handle:
        parquet = pq.ParquetFile(handle)
        live_fields = [
            {"name": field.name, "dtype": str(field.type), "nullable": bool(field.nullable)}
            for field in parquet.schema_arrow
        ]
        live_rows = parquet.metadata.num_rows
        live_row_groups = parquet.metadata.num_row_groups
    if live_rows != RECORD["qc"]["rows"]:
        raise RuntimeError("live footer row count differs from the frozen registry")
    if live_row_groups != RECORD["qc"]["row_groups"]:
        raise RuntimeError("live footer row-group count differs from the frozen registry")
    if live_fields != RECORD["fields"]:
        raise RuntimeError("live footer schema differs from the frozen registry")
    live_result = {"status": "PASS", "generation": str(info["generation"]), "rows": live_rows, "row_groups": live_row_groups}
live_result
