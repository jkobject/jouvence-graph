# %% [markdown]
# # Reproduce Nucleotide Transformer and ESM2 sequence embedding pipelines
#
# Generated by reproduce/generate_parquet_reproduction_notebooks.py; do not edit.
#
# ## Objective and meaning
#
# Document the coherent `sequence_embeddings` acquisition/build/mapping pipeline and safely verify all 3 current canonical Parquets assigned to it.
#
# Grouping justification: these outputs share a defensible source/transformation family context. Exact producer and command evidence remains per output and may be absent; layer alone is not used as a grouping rule, and differences remain explicit in each output contract.
#
# ## Canonical outputs owned by this notebook
#
# | Layer | Canonical output | Rows | Replay level | Catalog |
# |---|---|---:|---|---|
# | `embedding` | `gene_genomic_sequence_nucleotide_transformer_v2_50m_multi_species` | 78,644 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/embedding__gene_genomic_sequence_nucleotide_transformer_v2_50m_multi_species.md) |
# | `embedding` | `protein_sequence_esm2_t33_650m_ur50d` | 112,051 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/embedding__protein_sequence_esm2_t33_650m_ur50d.md) |
# | `embedding` | `transcript_sequence_nucleotide_transformer_v2_50m_multi_species` | 187,268 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/embedding__transcript_sequence_nucleotide_transformer_v2_50m_multi_species.md) |

# %% [markdown]
# ## Native inputs, release, acquisition and environment
#
# Shared acquisition context is stated once; release and retained input differences are restated under every owned output.
#
# ## Expected schema and identifiers
#
# Each output section carries its exact catalog schema, row count, object generation and checksum.
#
# ## Keys, mappings and joins
#
# Shared family mappings are applied only where stated; every output preserves its own key contract.
#
# ## Cleaning, normalization, transformations and filters
#
# Transformation and filter differences are explicit per output below.
#
# ## Deduplication and assertion/evidence semantics
#
# Canonical edges are deduplicated assertions; source-specific multiplicity and context remain evidence/features where applicable.
#
# ## Quarantines, exclusions and missing data
#
# Every output contract states its known exclusions and unresolved provenance.
#
# ## Problems encountered and decisions
#
# Known decisions and alternatives are reported conservatively; migration identity is not treated as proof of biological replayability.
#
# ## Producer / builder
#
# The per-output contracts name an evidenced tracked producer or state that it is unavailable.
#
# ## Full worker rebuild command (inert text; never executed by this notebook)
#
# Any command below is documentation only and remains approved-worker, staging and review gated.
#
# ## Migration receipt
#
# Every output includes its generation-matched, verified migration receipt.
#
# ## QC, bounded replay and verification
#
# The first code cell validates all embedded output contracts offline. The opt-in cell verifies one selected GCS object metadata record and Parquet footer, chosen with `JOUVENCE_OUTPUT_ID`; it never scans all family outputs.
#
# ## Reproducibility limits
#
# Replay levels remain per output. No family-level label upgrades weaker members.
#
# ## Linked code, tests, reports and historical notebooks
#
# Links are listed in each output contract.

# %% [markdown]
# ## Per-output reproduction contracts
#
# ### Output `embedding__gene_genomic_sequence_nucleotide_transformer_v2_50m_multi_species`
#
# - Canonical URI: `gs://jouvencekb/main/embeddings/gene_genomic_sequence_nucleotide_transformer_v2_50m_multi_species.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/embedding__gene_genomic_sequence_nucleotide_transformer_v2_50m_multi_species.md`](../../docs/parquet-catalog/datasets/embedding__gene_genomic_sequence_nucleotide_transformer_v2_50m_multi_species.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Accepted learned vector table for canonical `gene` nodes.
# - Does not mean: Vector similarity is not functional equivalence, causality, or therapeutic evidence.
#
# **Native inputs and release.** Accepted immutable genomic/transcript/protein sequence embedding candidates; model identity is encoded in each canonical leaf
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **78,644**; bytes: **257,636,628**; row groups: **154**; schema hash (`arrow-fields-v1`): `92851cb60ebfaa124202db3109aea560a791751a5d85d0750cf43cbfe6514b71`; generation: `1785155499455510`; CRC32C: `6B0P8Q==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `embedding_key` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `source_feature_table` | `string` | `true` |
# | `source_feature_key` | `string` | `true` |
# | `source_feature_hash` | `string` | `true` |
# | `source_sequence_sha256` | `string` | `true` |
# | `modality` | `string` | `true` |
# | `sequence_kind` | `string` | `true` |
# | `alphabet` | `string` | `true` |
# | `chromosome` | `string` | `true` |
# | `start_1based` | `string` | `true` |
# | `end_1based` | `string` | `true` |
# | `strand` | `string` | `true` |
# | `reference_build` | `string` | `true` |
# | `gene_name` | `string` | `true` |
# | `gene_biotype` | `string` | `true` |
# | `embedding_model` | `string` | `true` |
# | `embedding_version` | `string` | `true` |
# | `embedding_dim` | `int64` | `true` |
# | `embedding_dtype` | `string` | `true` |
# | `embedding_format` | `string` | `true` |
# | `embedding` | `fixed_size_list<element: float>[512]` | `true` |
# | `pooling` | `string` | `true` |
# | `normalization` | `string` | `true` |
# | `preprocessing` | `string` | `true` |
# | `input_length` | `int64` | `true` |
# | `source_row_index` | `int64` | `true` |
# | `window_count` | `int64` | `true` |
# | `window_spans` | `string` | `true` |
# | `created_at` | `string` | `true` |
# | `source_feature_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `embedding_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join exact ENSG, ENST or ENSP canonical IDs to source sequences and hashes; preserve model, pooling, normalization and coverage metadata.
#
# **Cleaning, normalization, transformations and filters.** Encode genomic, transcript or protein sequence with the leaf-specific Nucleotide Transformer or ESM2 model and retain deterministic feature lineage.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not fabricate vectors for missing sequences, cross-project one sequence modality into another or treat similarity as biological evidence.
#
# **Problems encountered and decisions.** Accepted sequence-vector objects and migration receipts survive, but no single verified argv with pinned model revisions and all accepted input checksums covers every sequence leaf.
#
# Known gaps: `current builder`, `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/embeddings/nucleotide_sequence/gene/instadeepai_nucleotide_transformer_v2_50m_multi_species/81b29e5786726d891dbf929404ef20adca5b36f1+gene_locus_1000nt_policy_v1/part-000.parquet`
# - Destination generation: `1785155499455510`
# - Destination CRC32C: `6B0P8Q==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/embedding__gene_genomic_sequence_nucleotide_transformer_v2_50m_multi_species.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_real_embeddings.py`
#
#
# ### Output `embedding__protein_sequence_esm2_t33_650m_ur50d`
#
# - Canonical URI: `gs://jouvencekb/main/embeddings/protein_sequence_esm2_t33_650m_ur50d.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/embedding__protein_sequence_esm2_t33_650m_ur50d.md`](../../docs/parquet-catalog/datasets/embedding__protein_sequence_esm2_t33_650m_ur50d.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Accepted learned vector table for canonical `protein` nodes.
# - Does not mean: Vector similarity is not functional equivalence, causality, or therapeutic evidence.
#
# **Native inputs and release.** Accepted immutable genomic/transcript/protein sequence embedding candidates; model identity is encoded in each canonical leaf
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **112,051**; bytes: **542,567,080**; row groups: **1**; schema hash (`arrow-fields-v1`): `989f3af24af92c01f2a6065ee66097adc7f1f8cf9ad3ad69da10e33bb8b079d0`; generation: `1785155778430754`; CRC32C: `JliYlA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `embedding_key` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `source_feature_table` | `string` | `true` |
# | `source_feature_key` | `string` | `true` |
# | `source_feature_hash` | `string` | `true` |
# | `modality` | `string` | `true` |
# | `embedding_model` | `string` | `true` |
# | `embedding_version` | `string` | `true` |
# | `embedding_dim` | `int32` | `true` |
# | `embedding_dtype` | `string` | `true` |
# | `embedding_format` | `string` | `true` |
# | `embedding` | `list<element: float>` | `true` |
# | `pooling` | `string` | `true` |
# | `normalization` | `string` | `true` |
# | `preprocessing` | `string` | `true` |
# | `input_length` | `int64` | `true` |
# | `window_count` | `int32` | `true` |
# | `created_at` | `string` | `true` |
# | `source_feature_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
# | `source_sequence_sha256` | `string` | `true` |
# | `sequence_kind` | `string` | `true` |
# | `source_row_index` | `int64` | `true` |
# | `window_spans` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `embedding_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join exact ENSG, ENST or ENSP canonical IDs to source sequences and hashes; preserve model, pooling, normalization and coverage metadata.
#
# **Cleaning, normalization, transformations and filters.** Encode genomic, transcript or protein sequence with the leaf-specific Nucleotide Transformer or ESM2 model and retain deterministic feature lineage.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not fabricate vectors for missing sequences, cross-project one sequence modality into another or treat similarity as biological evidence.
#
# **Problems encountered and decisions.** Accepted sequence-vector objects and migration receipts survive, but no single verified argv with pinned model revisions and all accepted input checksums covers every sequence leaf.
#
# Known gaps: `current builder`, `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `compacted`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/embeddings/protein_sequence/protein/esm2_t33_650m_ur50d/release_20260715_v2__src_39f3e5434cca/part-00000.parquet`
#   - `kg/v2/features/embeddings/protein_sequence/protein/esm2_t33_650m_ur50d/release_20260715_v2__src_39f3e5434cca/part-00001.parquet`
# - Destination generation: `1785155778430754`
# - Destination CRC32C: `JliYlA==`
# - Verified migration readback: `True`
# - Destination SHA-256: `52a7d5682f86cea80aea5f952ccee6e57b90151389d81152cd910589848dc5ed`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/embedding__protein_sequence_esm2_t33_650m_ur50d.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_real_embeddings.py`
#
#
# ### Output `embedding__transcript_sequence_nucleotide_transformer_v2_50m_multi_species`
#
# - Canonical URI: `gs://jouvencekb/main/embeddings/transcript_sequence_nucleotide_transformer_v2_50m_multi_species.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/embedding__transcript_sequence_nucleotide_transformer_v2_50m_multi_species.md`](../../docs/parquet-catalog/datasets/embedding__transcript_sequence_nucleotide_transformer_v2_50m_multi_species.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Accepted learned vector table for canonical `transcript` nodes.
# - Does not mean: Vector similarity is not functional equivalence, causality, or therapeutic evidence.
#
# **Native inputs and release.** Accepted immutable genomic/transcript/protein sequence embedding candidates; model identity is encoded in each canonical leaf
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **187,268**; bytes: **420,253,189**; row groups: **46**; schema hash (`arrow-fields-v1`): `3a9b993fd957d115ac6dad10e985584eb0b839efb930bc9a5cd89fb9097441fb`; generation: `1785155497694542`; CRC32C: `RLlQ9w==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `embedding_key` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `source_feature_table` | `string` | `true` |
# | `source_feature_key` | `string` | `true` |
# | `source_feature_hash` | `string` | `true` |
# | `modality` | `string` | `true` |
# | `embedding_model` | `string` | `true` |
# | `embedding_version` | `string` | `true` |
# | `embedding_dim` | `int32` | `false` |
# | `embedding_dtype` | `string` | `true` |
# | `embedding_format` | `string` | `false` |
# | `embedding` | `fixed_size_list<element: float>[512]` | `false` |
# | `pooling` | `string` | `true` |
# | `normalization` | `string` | `true` |
# | `preprocessing` | `string` | `true` |
# | `input_length` | `int64` | `true` |
# | `window_count` | `int32` | `false` |
# | `created_at` | `string` | `true` |
# | `source_feature_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
# | `source_sequence_sha256` | `string` | `true` |
# | `sequence_kind` | `string` | `true` |
# | `alphabet` | `string` | `true` |
# | `source_row_index` | `int64` | `true` |
# | `window_spans` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `embedding_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join exact ENSG, ENST or ENSP canonical IDs to source sequences and hashes; preserve model, pooling, normalization and coverage metadata.
#
# **Cleaning, normalization, transformations and filters.** Encode genomic, transcript or protein sequence with the leaf-specific Nucleotide Transformer or ESM2 model and retain deterministic feature lineage.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not fabricate vectors for missing sequences, cross-project one sequence modality into another or treat similarity as biological evidence.
#
# **Problems encountered and decisions.** Accepted sequence-vector objects and migration receipts survive, but no single verified argv with pinned model revisions and all accepted input checksums covers every sequence leaf.
#
# Known gaps: `current builder`, `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/embeddings/nucleotide_sequence/transcript/nucleotide_transformer_v2_50m_multi_species/release_20260715_v2__src_74d50ff1fdbb/part-00000.parquet`
# - Destination generation: `1785155497694542`
# - Destination CRC32C: `RLlQ9w==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/embedding__transcript_sequence_nucleotide_transformer_v2_50m_multi_species.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_real_embeddings.py`

# %% [markdown]
# ## Offline bounded contract check
#
# This cell uses only the embedded frozen lineage record.

# %%
import hashlib
import json

RECORDS = json.loads(r'''[{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/embeddings/gene_genomic_sequence_nucleotide_transformer_v2_50m_multi_species.parquet","catalog_page":"docs/parquet-catalog/datasets/embedding__gene_genomic_sequence_nucleotide_transformer_v2_50m_multi_species.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"embedding_key","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"source_feature_table","nullable":true},{"dtype":"string","name":"source_feature_key","nullable":true},{"dtype":"string","name":"source_feature_hash","nullable":true},{"dtype":"string","name":"source_sequence_sha256","nullable":true},{"dtype":"string","name":"modality","nullable":true},{"dtype":"string","name":"sequence_kind","nullable":true},{"dtype":"string","name":"alphabet","nullable":true},{"dtype":"string","name":"chromosome","nullable":true},{"dtype":"string","name":"start_1based","nullable":true},{"dtype":"string","name":"end_1based","nullable":true},{"dtype":"string","name":"strand","nullable":true},{"dtype":"string","name":"reference_build","nullable":true},{"dtype":"string","name":"gene_name","nullable":true},{"dtype":"string","name":"gene_biotype","nullable":true},{"dtype":"string","name":"embedding_model","nullable":true},{"dtype":"string","name":"embedding_version","nullable":true},{"dtype":"int64","name":"embedding_dim","nullable":true},{"dtype":"string","name":"embedding_dtype","nullable":true},{"dtype":"string","name":"embedding_format","nullable":true},{"dtype":"fixed_size_list<element: float>[512]","name":"embedding","nullable":true},{"dtype":"string","name":"pooling","nullable":true},{"dtype":"string","name":"normalization","nullable":true},{"dtype":"string","name":"preprocessing","nullable":true},{"dtype":"int64","name":"input_length","nullable":true},{"dtype":"int64","name":"source_row_index","nullable":true},{"dtype":"int64","name":"window_count","nullable":true},{"dtype":"string","name":"window_spans","nullable":true},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"source_feature_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["embedding_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","retained native input","verified exact rebuild command"],"layer":"embedding","links":["docs/parquet-catalog/datasets/embedding__gene_genomic_sequence_nucleotide_transformer_v2_50m_multi_species.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_real_embeddings.py"],"mappings_and_joins":"Join exact ENSG, ENST or ENSP canonical IDs to source sequences and hashes; preserve model, pooling, normalization and coverage metadata.","meaning":"Accepted learned vector table for canonical `gene` nodes.","migration_receipt":{"action":"copied","destination_crc32c":"6B0P8Q==","destination_generation":"1785155499455510","source":"kg/v2/features/embeddings/nucleotide_sequence/gene/instadeepai_nucleotide_transformer_v2_50m_multi_species/81b29e5786726d891dbf929404ef20adca5b36f1+gene_locus_1000nt_policy_v1/part-000.parquet","source_generation":"1784724412910933","verified":true},"name":"gene_genomic_sequence_nucleotide_transformer_v2_50m_multi_species","native_inputs":[],"native_source":[],"non_meaning":"Vector similarity is not functional equivalence, causality, or therapeutic evidence.","pipeline_family":"sequence_embeddings","problems_and_decisions":"Accepted sequence-vector objects and migration receipts survive, but no single verified argv with pinned model revisions and all accepted input checksums covers every sequence leaf.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":257636628,"crc32c_base64":"6B0P8Q==","generation":"1785155499455510","md5_base64":null,"row_groups":154,"rows":78644,"schema_hash":"92851cb60ebfaa124202db3109aea560a791751a5d85d0750cf43cbfe6514b71","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not fabricate vectors for missing sequences, cross-project one sequence modality into another or treat similarity as biological evidence.","rebuild_command_evidenced":false,"release":"Accepted immutable genomic/transcript/protein sequence embedding candidates; model identity is encoded in each canonical leaf","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/sequence_embeddings.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"sequence_embeddings","source_family_label":"Nucleotide Transformer and ESM2 sequence embedding pipelines","transformations_and_filters":"Encode genomic, transcript or protein sequence with the leaf-specific Nucleotide Transformer or ESM2 model and retain deterministic feature lineage."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/embeddings/protein_sequence_esm2_t33_650m_ur50d.parquet","catalog_page":"docs/parquet-catalog/datasets/embedding__protein_sequence_esm2_t33_650m_ur50d.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"embedding_key","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"source_feature_table","nullable":true},{"dtype":"string","name":"source_feature_key","nullable":true},{"dtype":"string","name":"source_feature_hash","nullable":true},{"dtype":"string","name":"modality","nullable":true},{"dtype":"string","name":"embedding_model","nullable":true},{"dtype":"string","name":"embedding_version","nullable":true},{"dtype":"int32","name":"embedding_dim","nullable":true},{"dtype":"string","name":"embedding_dtype","nullable":true},{"dtype":"string","name":"embedding_format","nullable":true},{"dtype":"list<element: float>","name":"embedding","nullable":true},{"dtype":"string","name":"pooling","nullable":true},{"dtype":"string","name":"normalization","nullable":true},{"dtype":"string","name":"preprocessing","nullable":true},{"dtype":"int64","name":"input_length","nullable":true},{"dtype":"int32","name":"window_count","nullable":true},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"source_feature_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true},{"dtype":"string","name":"source_sequence_sha256","nullable":true},{"dtype":"string","name":"sequence_kind","nullable":true},{"dtype":"int64","name":"source_row_index","nullable":true},{"dtype":"string","name":"window_spans","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["embedding_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","retained native input","verified exact rebuild command"],"layer":"embedding","links":["docs/parquet-catalog/datasets/embedding__protein_sequence_esm2_t33_650m_ur50d.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_real_embeddings.py"],"mappings_and_joins":"Join exact ENSG, ENST or ENSP canonical IDs to source sequences and hashes; preserve model, pooling, normalization and coverage metadata.","meaning":"Accepted learned vector table for canonical `protein` nodes.","migration_receipt":{"action":"compacted","destination_crc32c":"JliYlA==","destination_generation":"1785155778430754","destination_rows":112051,"destination_sha256":"52a7d5682f86cea80aea5f952ccee6e57b90151389d81152cd910589848dc5ed","source_rows":112051,"sources":["kg/v2/features/embeddings/protein_sequence/protein/esm2_t33_650m_ur50d/release_20260715_v2__src_39f3e5434cca/part-00000.parquet","kg/v2/features/embeddings/protein_sequence/protein/esm2_t33_650m_ur50d/release_20260715_v2__src_39f3e5434cca/part-00001.parquet"],"verified":true},"name":"protein_sequence_esm2_t33_650m_ur50d","native_inputs":[],"native_source":[],"non_meaning":"Vector similarity is not functional equivalence, causality, or therapeutic evidence.","pipeline_family":"sequence_embeddings","problems_and_decisions":"Accepted sequence-vector objects and migration receipts survive, but no single verified argv with pinned model revisions and all accepted input checksums covers every sequence leaf.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":542567080,"crc32c_base64":"JliYlA==","generation":"1785155778430754","md5_base64":null,"row_groups":1,"rows":112051,"schema_hash":"989f3af24af92c01f2a6065ee66097adc7f1f8cf9ad3ad69da10e33bb8b079d0","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not fabricate vectors for missing sequences, cross-project one sequence modality into another or treat similarity as biological evidence.","rebuild_command_evidenced":false,"release":"Accepted immutable genomic/transcript/protein sequence embedding candidates; model identity is encoded in each canonical leaf","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/sequence_embeddings.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"sequence_embeddings","source_family_label":"Nucleotide Transformer and ESM2 sequence embedding pipelines","transformations_and_filters":"Encode genomic, transcript or protein sequence with the leaf-specific Nucleotide Transformer or ESM2 model and retain deterministic feature lineage."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/embeddings/transcript_sequence_nucleotide_transformer_v2_50m_multi_species.parquet","catalog_page":"docs/parquet-catalog/datasets/embedding__transcript_sequence_nucleotide_transformer_v2_50m_multi_species.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"embedding_key","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"source_feature_table","nullable":true},{"dtype":"string","name":"source_feature_key","nullable":true},{"dtype":"string","name":"source_feature_hash","nullable":true},{"dtype":"string","name":"modality","nullable":true},{"dtype":"string","name":"embedding_model","nullable":true},{"dtype":"string","name":"embedding_version","nullable":true},{"dtype":"int32","name":"embedding_dim","nullable":false},{"dtype":"string","name":"embedding_dtype","nullable":true},{"dtype":"string","name":"embedding_format","nullable":false},{"dtype":"fixed_size_list<element: float>[512]","name":"embedding","nullable":false},{"dtype":"string","name":"pooling","nullable":true},{"dtype":"string","name":"normalization","nullable":true},{"dtype":"string","name":"preprocessing","nullable":true},{"dtype":"int64","name":"input_length","nullable":true},{"dtype":"int32","name":"window_count","nullable":false},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"source_feature_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true},{"dtype":"string","name":"source_sequence_sha256","nullable":true},{"dtype":"string","name":"sequence_kind","nullable":true},{"dtype":"string","name":"alphabet","nullable":true},{"dtype":"int64","name":"source_row_index","nullable":true},{"dtype":"string","name":"window_spans","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["embedding_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","retained native input","verified exact rebuild command"],"layer":"embedding","links":["docs/parquet-catalog/datasets/embedding__transcript_sequence_nucleotide_transformer_v2_50m_multi_species.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_real_embeddings.py"],"mappings_and_joins":"Join exact ENSG, ENST or ENSP canonical IDs to source sequences and hashes; preserve model, pooling, normalization and coverage metadata.","meaning":"Accepted learned vector table for canonical `transcript` nodes.","migration_receipt":{"action":"copied","destination_crc32c":"RLlQ9w==","destination_generation":"1785155497694542","source":"kg/v2/features/embeddings/nucleotide_sequence/transcript/nucleotide_transformer_v2_50m_multi_species/release_20260715_v2__src_74d50ff1fdbb/part-00000.parquet","source_generation":"1784460735576727","verified":true},"name":"transcript_sequence_nucleotide_transformer_v2_50m_multi_species","native_inputs":[],"native_source":[],"non_meaning":"Vector similarity is not functional equivalence, causality, or therapeutic evidence.","pipeline_family":"sequence_embeddings","problems_and_decisions":"Accepted sequence-vector objects and migration receipts survive, but no single verified argv with pinned model revisions and all accepted input checksums covers every sequence leaf.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":420253189,"crc32c_base64":"RLlQ9w==","generation":"1785155497694542","md5_base64":"V48FFJivLdX/jV1+TmTPVQ==","row_groups":46,"rows":187268,"schema_hash":"3a9b993fd957d115ac6dad10e985584eb0b839efb930bc9a5cd89fb9097441fb","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not fabricate vectors for missing sequences, cross-project one sequence modality into another or treat similarity as biological evidence.","rebuild_command_evidenced":false,"release":"Accepted immutable genomic/transcript/protein sequence embedding candidates; model identity is encoded in each canonical leaf","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/sequence_embeddings.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"sequence_embeddings","source_family_label":"Nucleotide Transformer and ESM2 sequence embedding pipelines","transformations_and_filters":"Encode genomic, transcript or protein sequence with the leaf-specific Nucleotide Transformer or ESM2 model and retain deterministic feature lineage."}]''')

def require(condition, message):
    if not condition:
        raise RuntimeError(message)

for RECORD in RECORDS:
    require(RECORD["canonical_uri"] == "gs://jouvencekb/main/" + ("embeddings" if RECORD["layer"] == "embedding" else RECORD["layer"]) + "/" + RECORD["name"] + ".parquet", "canonical URI/identity mismatch")
    require(RECORD["replay_level"] in ['documented-not-replayed', 'fully-replayable', 'historical-builder-only', 'provenance-gap'], "unsupported replay level")
    require(RECORD["qc"]["rows"] >= 0, "negative expected row count")
    require(len(RECORD["qc"]["schema_hash"]) == 64, "invalid schema hash")
    require(RECORD["migration_receipt"]["verified"] is True, "migration receipt is not verified")
    require(bool(RECORD["fields"]), "empty expected schema")
summary = {
    "pipeline_family": RECORDS[0]["pipeline_family"],
    "output_count": len(RECORDS),
    "identities": [record["layer"] + "__" + record["name"] for record in RECORDS],
}
summary

# %% [markdown]
# ## Optional bounded live canonical footer check
#
# This cell is skipped unless the caller explicitly opts in.

# %%
import os

if os.environ.get("JOUVENCE_LIVE_GCS") != "1":
    live_result = {"status": "SKIPPED", "reason": "set JOUVENCE_LIVE_GCS=1 and caller-owned JOUVENCE_BILLING_PROJECT"}
else:
    import gcsfs
    import pyarrow.parquet as pq

    billing_project = os.environ.get("JOUVENCE_BILLING_PROJECT")
    if not billing_project:
        raise RuntimeError("JOUVENCE_BILLING_PROJECT is required for requester-pays live verification")
    fs = gcsfs.GCSFileSystem(project=billing_project, requester_pays=billing_project, version_aware=True)
    if not fs.version_aware:
        raise RuntimeError("version-aware GCS reads are required")
    selected_id = os.environ.get("JOUVENCE_OUTPUT_ID", RECORDS[0]["layer"] + "__" + RECORDS[0]["name"])
    selected = [record for record in RECORDS if record["layer"] + "__" + record["name"] == selected_id]
    if len(selected) != 1:
        raise RuntimeError("JOUVENCE_OUTPUT_ID must select exactly one output owned by this notebook")
    RECORD = selected[0]
    object_path = RECORD["canonical_uri"].removeprefix("gs://")
    if "#" in object_path:
        raise RuntimeError("canonical object key must not already contain a generation suffix")
    expected_generation = RECORD["qc"]["generation"]
    pinned_path = object_path + "#" + expected_generation
    info = fs.info(pinned_path)
    if str(info.get("generation", "")) != expected_generation:
        raise RuntimeError("generation-qualified object resolved a different generation")
    with fs.open(pinned_path, "rb") as handle:
        parquet = pq.ParquetFile(handle)
        live_fields = [
            {"name": field.name, "dtype": str(field.type), "nullable": bool(field.nullable)}
            for field in parquet.schema_arrow
        ]
        live_rows = parquet.metadata.num_rows
        live_row_groups = parquet.metadata.num_row_groups
    if live_rows != RECORD["qc"]["rows"]:
        raise RuntimeError("live footer row count differs from the frozen registry")
    if live_row_groups != RECORD["qc"]["row_groups"]:
        raise RuntimeError("live footer row-group count differs from the frozen registry")
    if live_fields != RECORD["fields"]:
        raise RuntimeError("live footer schema differs from the frozen registry")
    live_result = {"status": "PASS", "generation": str(info["generation"]), "rows": live_rows, "row_groups": live_row_groups}
live_result
