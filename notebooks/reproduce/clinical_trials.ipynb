# %% [markdown]
# # Reproduce ClinicalTrials.gov API v2 sidecars
#
# Generated by reproduce/generate_parquet_reproduction_notebooks.py; do not edit.
#
# ## Objective and meaning
#
# Document the coherent `clinical_trials` acquisition/build/mapping pipeline and safely verify all 3 current canonical Parquets assigned to it.
#
# Grouping justification: these outputs share a defensible source/transformation family context. Exact producer and command evidence remains per output and may be absent; layer alone is not used as a grouping rule, and differences remain explicit in each output contract.
#
# ## Canonical outputs owned by this notebook
#
# | Layer | Canonical output | Rows | Replay level | Catalog |
# |---|---|---:|---|---|
# | `features` | `clinical_trials_gov_trial_index` | 6,092 | `provenance-gap` | [catalog](../../docs/parquet-catalog/datasets/features__clinical_trials_gov_trial_index.md) |
# | `features` | `clinical_trials_gov_trial_text_features` | 6,092 | `provenance-gap` | [catalog](../../docs/parquet-catalog/datasets/features__clinical_trials_gov_trial_text_features.md) |
# | `features` | `molecule_treats_disease_clinical_trial_links` | 7,804 | `provenance-gap` | [catalog](../../docs/parquet-catalog/datasets/features__molecule_treats_disease_clinical_trial_links.md) |

# %% [markdown]
# ## Native inputs, release, acquisition and environment
#
# Shared acquisition context is stated once; release and retained input differences are restated under every owned output.
#
# ## Expected schema and identifiers
#
# Each output section carries its exact catalog schema, row count, object generation and checksum.
#
# ## Keys, mappings and joins
#
# Shared family mappings are applied only where stated; every output preserves its own key contract.
#
# ## Cleaning, normalization, transformations and filters
#
# Transformation and filter differences are explicit per output below.
#
# ## Deduplication and assertion/evidence semantics
#
# Canonical edges are deduplicated assertions; source-specific multiplicity and context remain evidence/features where applicable.
#
# ## Quarantines, exclusions and missing data
#
# Every output contract states its known exclusions and unresolved provenance.
#
# ## Problems encountered and decisions
#
# Known decisions and alternatives are reported conservatively; migration identity is not treated as proof of biological replayability.
#
# ## Producer / builder
#
# The per-output contracts name an evidenced tracked producer or state that it is unavailable.
#
# ## Full worker rebuild command (inert text; never executed by this notebook)
#
# Any command below is documentation only and remains approved-worker, staging and review gated.
#
# ## Migration receipt
#
# Every output includes its generation-matched, verified migration receipt.
#
# ## QC, bounded replay and verification
#
# The first code cell validates all embedded output contracts offline. The opt-in cell verifies one selected GCS object metadata record and Parquet footer, chosen with `JOUVENCE_OUTPUT_ID`; it never scans all family outputs.
#
# ## Reproducibility limits
#
# Replay levels remain per output. No family-level label upgrades weaker members.
#
# ## Linked code, tests, reports and historical notebooks
#
# Links are listed in each output contract.

# %% [markdown]
# ## Per-output reproduction contracts
#
# ### Output `features__clinical_trials_gov_trial_index`
#
# - Canonical URI: `gs://jouvencekb/main/features/clinical_trials_gov_trial_index.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__clinical_trials_gov_trial_index.md`](../../docs/parquet-catalog/datasets/features__clinical_trials_gov_trial_index.md)
# - Replay level: **`provenance-gap`**
# - Meaning: ClinicalTrials.gov sidecar keyed by NCT ID or a canonical treatment-edge support key.
# - Does not mean: It is not graph topology, a clinical-trial node layer, participant-level data, or a treatment label.
#
# **Native inputs and release.** Frozen API v2 response chunks used by the accepted staged/canonical candidate; fetch timestamps identify snapshots
#
# - `https://clinicaltrials.gov/data-api/api`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **6,092**; bytes: **21,169,466**; row groups: **1**; schema hash (`arrow-fields-v1`): `4d1e35cc974223b4f762f7d77c3b87b68b2ad927459e489c16c9d224859958ae`; generation: `1785155497027025`; CRC32C: `InsfHQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `nct_id` | `large_string` | `true` |
# | `brief_title` | `large_string` | `true` |
# | `official_title` | `large_string` | `true` |
# | `overall_status` | `large_string` | `true` |
# | `why_stopped` | `large_string` | `true` |
# | `trajectory_class` | `large_string` | `true` |
# | `phase` | `large_string` | `true` |
# | `study_type` | `large_string` | `true` |
# | `allocation` | `large_string` | `true` |
# | `masking` | `large_string` | `true` |
# | `enrollment_count` | `double` | `true` |
# | `enrollment_type` | `large_string` | `true` |
# | `start_date` | `large_string` | `true` |
# | `primary_completion_date` | `large_string` | `true` |
# | `completion_date` | `large_string` | `true` |
# | `conditions` | `large_string` | `true` |
# | `brief_summary` | `large_string` | `true` |
# | `detailed_description` | `large_string` | `true` |
# | `intervention_names` | `large_string` | `true` |
# | `intervention_types` | `large_string` | `true` |
# | `intervention_details` | `large_string` | `true` |
# | `primary_endpoints` | `large_string` | `true` |
# | `secondary_endpoints` | `large_string` | `true` |
# | `primary_outcome_text` | `large_string` | `true` |
# | `secondary_outcome_text` | `large_string` | `true` |
# | `primary_endpoint_count` | `int64` | `true` |
# | `secondary_endpoint_count` | `int64` | `true` |
# | `eligibility_criteria` | `large_string` | `true` |
# | `result_summary_text` | `large_string` | `true` |
# | `lead_sponsor` | `large_string` | `true` |
# | `lead_sponsor_class` | `large_string` | `true` |
# | `collaborators` | `large_string` | `true` |
# | `publication_ids` | `large_string` | `true` |
# | `source_url` | `large_string` | `true` |
# | `fetched_at` | `large_string` | `true` |
# | `source_dataset` | `large_string` | `true` |
# | `source_release` | `large_string` | `true` |
# | `source_record_id` | `large_string` | `true` |
# | `raw_response_sha256` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `nct_id`
# - Linkage: `nct_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join NCT IDs to Open Targets treatment support and canonical molecule-disease keys where explicitly asserted.
#
# **Cleaning, normalization, transformations and filters.** Normalize trial metadata/text into sidecars; keep trial records separate from graph topology.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Report fetch misses and unsupported treatment links; trial registration is not proof of efficacy.
#
# **Problems encountered and decisions.** The accepted frozen response chunks are not retained under raw/, and the current builder may fetch missing studies; no complete offline exact argv is tracked.
#
# Known gaps: `current builder`, `exact accepted source-to-object lineage`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/metadata/clinical_trials_gov_trial_index.parquet`
# - Destination generation: `1785155497027025`
# - Destination CRC32C: `InsfHQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__clinical_trials_gov_trial_index.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/28_cell_line_pharmacology_clinical_reproduction.ipynb`
# - `manage_db/stage_clinicaltrials_gov_production_candidate.py`
#
#
# ### Output `features__clinical_trials_gov_trial_text_features`
#
# - Canonical URI: `gs://jouvencekb/main/features/clinical_trials_gov_trial_text_features.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__clinical_trials_gov_trial_text_features.md`](../../docs/parquet-catalog/datasets/features__clinical_trials_gov_trial_text_features.md)
# - Replay level: **`provenance-gap`**
# - Meaning: ClinicalTrials.gov sidecar keyed by NCT ID or a canonical treatment-edge support key.
# - Does not mean: It is not graph topology, a clinical-trial node layer, participant-level data, or a treatment label.
#
# **Native inputs and release.** Frozen API v2 response chunks used by the accepted staged/canonical candidate; fetch timestamps identify snapshots
#
# - `https://clinicaltrials.gov/data-api/api`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **6,092**; bytes: **38,038,096**; row groups: **1**; schema hash (`arrow-fields-v1`): `a6600aee3b6a53211c798968af5229ada346eb273ffdc5396993b1adb33ba9c0`; generation: `1785155495259824`; CRC32C: `z4KaGg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `nct_id` | `large_string` | `true` |
# | `source_feature_key` | `large_string` | `true` |
# | `source_text` | `large_string` | `true` |
# | `source_field_inventory` | `large_string` | `true` |
# | `source_text_hash` | `large_string` | `true` |
# | `source_text_length` | `int64` | `true` |
# | `brief_title` | `large_string` | `true` |
# | `official_title` | `large_string` | `true` |
# | `brief_summary` | `large_string` | `true` |
# | `detailed_description` | `large_string` | `true` |
# | `condition_text` | `large_string` | `true` |
# | `intervention_text` | `large_string` | `true` |
# | `primary_outcome_text` | `large_string` | `true` |
# | `secondary_outcome_text` | `large_string` | `true` |
# | `eligibility_criteria` | `large_string` | `true` |
# | `why_stopped` | `large_string` | `true` |
# | `result_summary_text` | `large_string` | `true` |
# | `extraction_version` | `large_string` | `true` |
# | `source_dataset` | `large_string` | `true` |
# | `source_release` | `large_string` | `true` |
# | `license` | `large_string` | `true` |
# | `created_at` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `nct_id`
# - Linkage: `nct_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join NCT IDs to Open Targets treatment support and canonical molecule-disease keys where explicitly asserted.
#
# **Cleaning, normalization, transformations and filters.** Normalize trial metadata/text into sidecars; keep trial records separate from graph topology.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Report fetch misses and unsupported treatment links; trial registration is not proof of efficacy.
#
# **Problems encountered and decisions.** The accepted frozen response chunks are not retained under raw/, and the current builder may fetch missing studies; no complete offline exact argv is tracked.
#
# Known gaps: `current builder`, `exact accepted source-to-object lineage`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/clinical_trials_gov_trial_text_features.parquet`
# - Destination generation: `1785155495259824`
# - Destination CRC32C: `z4KaGg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__clinical_trials_gov_trial_text_features.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/28_cell_line_pharmacology_clinical_reproduction.ipynb`
# - `manage_db/stage_clinicaltrials_gov_production_candidate.py`
#
#
# ### Output `features__molecule_treats_disease_clinical_trial_links`
#
# - Canonical URI: `gs://jouvencekb/main/features/molecule_treats_disease_clinical_trial_links.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__molecule_treats_disease_clinical_trial_links.md`](../../docs/parquet-catalog/datasets/features__molecule_treats_disease_clinical_trial_links.md)
# - Replay level: **`provenance-gap`**
# - Meaning: Canonical public `molecule_treats_disease_clinical_trial_links` features table.
# - Does not mean: Interpret only according to its columns and linked provenance; it is not an implicit graph relation.
#
# **Native inputs and release.** Frozen API v2 response chunks used by the accepted staged/canonical candidate; fetch timestamps identify snapshots
#
# - `https://clinicaltrials.gov/data-api/api`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **7,804**; bytes: **398,019**; row groups: **1**; schema hash (`arrow-fields-v1`): `0181a8454c2ceb01c92011cf97a7f8b0a08b08300e2bae2b958de90d05164a22`; generation: `1785155497178520`; CRC32C: `OowvEQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `predicate` | `large_string` | `true` |
# | `study_id` | `large_string` | `true` |
# | `text_span` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `source_dataset` | `large_string` | `true` |
# | `source_record_id` | `large_string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `release` | `large_string` | `true` |
# | `nct_id` | `large_string` | `true` |
# | `mapping_source` | `large_string` | `true` |
# | `mapping_method` | `large_string` | `true` |
# | `mapping_confidence` | `large_string` | `true` |
# | `source_study_id_raw` | `large_string` | `true` |
# | `source_text_span_hash` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `nct_id`, `edge_key`
# - Linkage: `edge_key`, `nct_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join NCT IDs to Open Targets treatment support and canonical molecule-disease keys where explicitly asserted.
#
# **Cleaning, normalization, transformations and filters.** Normalize trial metadata/text into sidecars; keep trial records separate from graph topology.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Report fetch misses and unsupported treatment links; trial registration is not proof of efficacy.
#
# **Problems encountered and decisions.** The accepted frozen response chunks are not retained under raw/, and the current builder may fetch missing studies; no complete offline exact argv is tracked.
#
# Known gaps: `current builder`, `exact accepted source-to-object lineage`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/metadata/molecule_treats_disease_clinical_trials_gov_trial_links.parquet`
# - Destination generation: `1785155497178520`
# - Destination CRC32C: `OowvEQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__molecule_treats_disease_clinical_trial_links.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/28_cell_line_pharmacology_clinical_reproduction.ipynb`
# - `manage_db/stage_clinicaltrials_gov_production_candidate.py`

# %% [markdown]
# ## Offline bounded contract check
#
# This cell uses only the embedded frozen lineage record.

# %%
import hashlib
import json

RECORDS = json.loads(r'''[{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/clinical_trials_gov_trial_index.parquet","catalog_page":"docs/parquet-catalog/datasets/features__clinical_trials_gov_trial_index.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"nct_id","nullable":true},{"dtype":"large_string","name":"brief_title","nullable":true},{"dtype":"large_string","name":"official_title","nullable":true},{"dtype":"large_string","name":"overall_status","nullable":true},{"dtype":"large_string","name":"why_stopped","nullable":true},{"dtype":"large_string","name":"trajectory_class","nullable":true},{"dtype":"large_string","name":"phase","nullable":true},{"dtype":"large_string","name":"study_type","nullable":true},{"dtype":"large_string","name":"allocation","nullable":true},{"dtype":"large_string","name":"masking","nullable":true},{"dtype":"double","name":"enrollment_count","nullable":true},{"dtype":"large_string","name":"enrollment_type","nullable":true},{"dtype":"large_string","name":"start_date","nullable":true},{"dtype":"large_string","name":"primary_completion_date","nullable":true},{"dtype":"large_string","name":"completion_date","nullable":true},{"dtype":"large_string","name":"conditions","nullable":true},{"dtype":"large_string","name":"brief_summary","nullable":true},{"dtype":"large_string","name":"detailed_description","nullable":true},{"dtype":"large_string","name":"intervention_names","nullable":true},{"dtype":"large_string","name":"intervention_types","nullable":true},{"dtype":"large_string","name":"intervention_details","nullable":true},{"dtype":"large_string","name":"primary_endpoints","nullable":true},{"dtype":"large_string","name":"secondary_endpoints","nullable":true},{"dtype":"large_string","name":"primary_outcome_text","nullable":true},{"dtype":"large_string","name":"secondary_outcome_text","nullable":true},{"dtype":"int64","name":"primary_endpoint_count","nullable":true},{"dtype":"int64","name":"secondary_endpoint_count","nullable":true},{"dtype":"large_string","name":"eligibility_criteria","nullable":true},{"dtype":"large_string","name":"result_summary_text","nullable":true},{"dtype":"large_string","name":"lead_sponsor","nullable":true},{"dtype":"large_string","name":"lead_sponsor_class","nullable":true},{"dtype":"large_string","name":"collaborators","nullable":true},{"dtype":"large_string","name":"publication_ids","nullable":true},{"dtype":"large_string","name":"source_url","nullable":true},{"dtype":"large_string","name":"fetched_at","nullable":true},{"dtype":"large_string","name":"source_dataset","nullable":true},{"dtype":"large_string","name":"source_release","nullable":true},{"dtype":"large_string","name":"source_record_id","nullable":true},{"dtype":"large_string","name":"raw_response_sha256","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["nct_id"],"linkage":["nct_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"layer":"features","links":["docs/parquet-catalog/datasets/features__clinical_trials_gov_trial_index.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/28_cell_line_pharmacology_clinical_reproduction.ipynb","manage_db/stage_clinicaltrials_gov_production_candidate.py"],"mappings_and_joins":"Join NCT IDs to Open Targets treatment support and canonical molecule-disease keys where explicitly asserted.","meaning":"ClinicalTrials.gov sidecar keyed by NCT ID or a canonical treatment-edge support key.","migration_receipt":{"action":"copied","destination_crc32c":"InsfHQ==","destination_generation":"1785155497027025","source":"kg/v2/metadata/clinical_trials_gov_trial_index.parquet","source_generation":"1782333884823119","verified":true},"name":"clinical_trials_gov_trial_index","native_inputs":["https://clinicaltrials.gov/data-api/api"],"native_source":["https://clinicaltrials.gov/data-api/api"],"non_meaning":"It is not graph topology, a clinical-trial node layer, participant-level data, or a treatment label.","pipeline_family":"clinical_trials","problems_and_decisions":"The accepted frozen response chunks are not retained under raw/, and the current builder may fetch missing studies; no complete offline exact argv is tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":21169466,"crc32c_base64":"InsfHQ==","generation":"1785155497027025","md5_base64":"MEh+/xP7c9cmPIT/AU3RKg==","row_groups":1,"rows":6092,"schema_hash":"4d1e35cc974223b4f762f7d77c3b87b68b2ad927459e489c16c9d224859958ae","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Report fetch misses and unsupported treatment links; trial registration is not proof of efficacy.","rebuild_command_evidenced":false,"release":"Frozen API v2 response chunks used by the accepted staged/canonical candidate; fetch timestamps identify snapshots","replay_level":"provenance-gap","reproduce_notebook":"notebooks/reproduce/clinical_trials.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"provenance-gap","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"clinical_trials","source_family_label":"ClinicalTrials.gov API v2 sidecars","transformations_and_filters":"Normalize trial metadata/text into sidecars; keep trial records separate from graph topology."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/clinical_trials_gov_trial_text_features.parquet","catalog_page":"docs/parquet-catalog/datasets/features__clinical_trials_gov_trial_text_features.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"nct_id","nullable":true},{"dtype":"large_string","name":"source_feature_key","nullable":true},{"dtype":"large_string","name":"source_text","nullable":true},{"dtype":"large_string","name":"source_field_inventory","nullable":true},{"dtype":"large_string","name":"source_text_hash","nullable":true},{"dtype":"int64","name":"source_text_length","nullable":true},{"dtype":"large_string","name":"brief_title","nullable":true},{"dtype":"large_string","name":"official_title","nullable":true},{"dtype":"large_string","name":"brief_summary","nullable":true},{"dtype":"large_string","name":"detailed_description","nullable":true},{"dtype":"large_string","name":"condition_text","nullable":true},{"dtype":"large_string","name":"intervention_text","nullable":true},{"dtype":"large_string","name":"primary_outcome_text","nullable":true},{"dtype":"large_string","name":"secondary_outcome_text","nullable":true},{"dtype":"large_string","name":"eligibility_criteria","nullable":true},{"dtype":"large_string","name":"why_stopped","nullable":true},{"dtype":"large_string","name":"result_summary_text","nullable":true},{"dtype":"large_string","name":"extraction_version","nullable":true},{"dtype":"large_string","name":"source_dataset","nullable":true},{"dtype":"large_string","name":"source_release","nullable":true},{"dtype":"large_string","name":"license","nullable":true},{"dtype":"large_string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["nct_id"],"linkage":["nct_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"layer":"features","links":["docs/parquet-catalog/datasets/features__clinical_trials_gov_trial_text_features.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/28_cell_line_pharmacology_clinical_reproduction.ipynb","manage_db/stage_clinicaltrials_gov_production_candidate.py"],"mappings_and_joins":"Join NCT IDs to Open Targets treatment support and canonical molecule-disease keys where explicitly asserted.","meaning":"ClinicalTrials.gov sidecar keyed by NCT ID or a canonical treatment-edge support key.","migration_receipt":{"action":"copied","destination_crc32c":"z4KaGg==","destination_generation":"1785155495259824","source":"kg/v2/features/clinical_trials_gov_trial_text_features.parquet","source_generation":"1782333885998413","verified":true},"name":"clinical_trials_gov_trial_text_features","native_inputs":["https://clinicaltrials.gov/data-api/api"],"native_source":["https://clinicaltrials.gov/data-api/api"],"non_meaning":"It is not graph topology, a clinical-trial node layer, participant-level data, or a treatment label.","pipeline_family":"clinical_trials","problems_and_decisions":"The accepted frozen response chunks are not retained under raw/, and the current builder may fetch missing studies; no complete offline exact argv is tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":38038096,"crc32c_base64":"z4KaGg==","generation":"1785155495259824","md5_base64":"bAGG4IPYwtFKy5DSKDRMQA==","row_groups":1,"rows":6092,"schema_hash":"a6600aee3b6a53211c798968af5229ada346eb273ffdc5396993b1adb33ba9c0","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Report fetch misses and unsupported treatment links; trial registration is not proof of efficacy.","rebuild_command_evidenced":false,"release":"Frozen API v2 response chunks used by the accepted staged/canonical candidate; fetch timestamps identify snapshots","replay_level":"provenance-gap","reproduce_notebook":"notebooks/reproduce/clinical_trials.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"provenance-gap","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"clinical_trials","source_family_label":"ClinicalTrials.gov API v2 sidecars","transformations_and_filters":"Normalize trial metadata/text into sidecars; keep trial records separate from graph topology."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/molecule_treats_disease_clinical_trial_links.parquet","catalog_page":"docs/parquet-catalog/datasets/features__molecule_treats_disease_clinical_trial_links.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"edge_key","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"predicate","nullable":true},{"dtype":"large_string","name":"study_id","nullable":true},{"dtype":"large_string","name":"text_span","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"large_string","name":"source_dataset","nullable":true},{"dtype":"large_string","name":"source_record_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"large_string","name":"release","nullable":true},{"dtype":"large_string","name":"nct_id","nullable":true},{"dtype":"large_string","name":"mapping_source","nullable":true},{"dtype":"large_string","name":"mapping_method","nullable":true},{"dtype":"large_string","name":"mapping_confidence","nullable":true},{"dtype":"large_string","name":"source_study_id_raw","nullable":true},{"dtype":"large_string","name":"source_text_span_hash","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["nct_id","edge_key"],"linkage":["edge_key","nct_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"layer":"features","links":["docs/parquet-catalog/datasets/features__molecule_treats_disease_clinical_trial_links.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/28_cell_line_pharmacology_clinical_reproduction.ipynb","manage_db/stage_clinicaltrials_gov_production_candidate.py"],"mappings_and_joins":"Join NCT IDs to Open Targets treatment support and canonical molecule-disease keys where explicitly asserted.","meaning":"Canonical public `molecule_treats_disease_clinical_trial_links` features table.","migration_receipt":{"action":"copied","destination_crc32c":"OowvEQ==","destination_generation":"1785155497178520","source":"kg/v2/metadata/molecule_treats_disease_clinical_trials_gov_trial_links.parquet","source_generation":"1782333885111043","verified":true},"name":"molecule_treats_disease_clinical_trial_links","native_inputs":["https://clinicaltrials.gov/data-api/api"],"native_source":["https://clinicaltrials.gov/data-api/api"],"non_meaning":"Interpret only according to its columns and linked provenance; it is not an implicit graph relation.","pipeline_family":"clinical_trials","problems_and_decisions":"The accepted frozen response chunks are not retained under raw/, and the current builder may fetch missing studies; no complete offline exact argv is tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":398019,"crc32c_base64":"OowvEQ==","generation":"1785155497178520","md5_base64":"e47HAf/E0ByPqPMah4rsgw==","row_groups":1,"rows":7804,"schema_hash":"0181a8454c2ceb01c92011cf97a7f8b0a08b08300e2bae2b958de90d05164a22","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Report fetch misses and unsupported treatment links; trial registration is not proof of efficacy.","rebuild_command_evidenced":false,"release":"Frozen API v2 response chunks used by the accepted staged/canonical candidate; fetch timestamps identify snapshots","replay_level":"provenance-gap","reproduce_notebook":"notebooks/reproduce/clinical_trials.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"provenance-gap","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"clinical_trials","source_family_label":"ClinicalTrials.gov API v2 sidecars","transformations_and_filters":"Normalize trial metadata/text into sidecars; keep trial records separate from graph topology."}]''')

def require(condition, message):
    if not condition:
        raise RuntimeError(message)

for RECORD in RECORDS:
    require(RECORD["canonical_uri"] == "gs://jouvencekb/main/" + ("embeddings" if RECORD["layer"] == "embedding" else RECORD["layer"]) + "/" + RECORD["name"] + ".parquet", "canonical URI/identity mismatch")
    require(RECORD["replay_level"] in ['documented-not-replayed', 'fully-replayable', 'historical-builder-only', 'provenance-gap'], "unsupported replay level")
    require(RECORD["qc"]["rows"] >= 0, "negative expected row count")
    require(len(RECORD["qc"]["schema_hash"]) == 64, "invalid schema hash")
    require(RECORD["migration_receipt"]["verified"] is True, "migration receipt is not verified")
    require(bool(RECORD["fields"]), "empty expected schema")
summary = {
    "pipeline_family": RECORDS[0]["pipeline_family"],
    "output_count": len(RECORDS),
    "identities": [record["layer"] + "__" + record["name"] for record in RECORDS],
}
summary

# %% [markdown]
# ## Optional bounded live canonical footer check
#
# This cell is skipped unless the caller explicitly opts in.

# %%
import os

if os.environ.get("JOUVENCE_LIVE_GCS") != "1":
    live_result = {"status": "SKIPPED", "reason": "set JOUVENCE_LIVE_GCS=1 and caller-owned JOUVENCE_BILLING_PROJECT"}
else:
    import gcsfs
    import pyarrow.parquet as pq

    billing_project = os.environ.get("JOUVENCE_BILLING_PROJECT")
    if not billing_project:
        raise RuntimeError("JOUVENCE_BILLING_PROJECT is required for requester-pays live verification")
    fs = gcsfs.GCSFileSystem(project=billing_project, requester_pays=billing_project, version_aware=True)
    if not fs.version_aware:
        raise RuntimeError("version-aware GCS reads are required")
    selected_id = os.environ.get("JOUVENCE_OUTPUT_ID", RECORDS[0]["layer"] + "__" + RECORDS[0]["name"])
    selected = [record for record in RECORDS if record["layer"] + "__" + record["name"] == selected_id]
    if len(selected) != 1:
        raise RuntimeError("JOUVENCE_OUTPUT_ID must select exactly one output owned by this notebook")
    RECORD = selected[0]
    object_path = RECORD["canonical_uri"].removeprefix("gs://")
    if "#" in object_path:
        raise RuntimeError("canonical object key must not already contain a generation suffix")
    expected_generation = RECORD["qc"]["generation"]
    pinned_path = object_path + "#" + expected_generation
    info = fs.info(pinned_path)
    if str(info.get("generation", "")) != expected_generation:
        raise RuntimeError("generation-qualified object resolved a different generation")
    with fs.open(pinned_path, "rb") as handle:
        parquet = pq.ParquetFile(handle)
        live_fields = [
            {"name": field.name, "dtype": str(field.type), "nullable": bool(field.nullable)}
            for field in parquet.schema_arrow
        ]
        live_rows = parquet.metadata.num_rows
        live_row_groups = parquet.metadata.num_row_groups
    if live_rows != RECORD["qc"]["rows"]:
        raise RuntimeError("live footer row count differs from the frozen registry")
    if live_row_groups != RECORD["qc"]["row_groups"]:
        raise RuntimeError("live footer row-group count differs from the frozen registry")
    if live_fields != RECORD["fields"]:
        raise RuntimeError("live footer schema differs from the frozen registry")
    live_result = {"status": "PASS", "generation": str(info["generation"]), "rows": live_rows, "row_groups": live_row_groups}
live_result
