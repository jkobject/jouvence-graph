# %% [markdown]
# # Reproduce Source-backed biomedical text embedding pipeline
#
# Generated by reproduce/generate_parquet_reproduction_notebooks.py; do not edit.
#
# ## Objective and meaning
#
# Document the coherent `text_embeddings` acquisition/build/mapping pipeline and safely verify all 9 current canonical Parquets assigned to it.
#
# Grouping justification: these outputs share a defensible source/transformation family context. Exact producer and command evidence remains per output and may be absent; layer alone is not used as a grouping rule, and differences remain explicit in each output contract.
#
# ## Canonical outputs owned by this notebook
#
# | Layer | Canonical output | Rows | Replay level | Catalog |
# |---|---|---:|---|---|
# | `embedding` | `cell_line_text_sbiobert_snli_multinli_stsb` | 1,140 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/embedding__cell_line_text_sbiobert_snli_multinli_stsb.md) |
# | `embedding` | `cell_type_text_sbiobert_snli_multinli_stsb` | 3,135 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/embedding__cell_type_text_sbiobert_snli_multinli_stsb.md) |
# | `embedding` | `disease_text_sbiobert_snli_multinli_stsb` | 26,395 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/embedding__disease_text_sbiobert_snli_multinli_stsb.md) |
# | `embedding` | `gene_text_sbiobert_snli_multinli_stsb` | 212,029 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/embedding__gene_text_sbiobert_snli_multinli_stsb.md) |
# | `embedding` | `molecule_text_sbiobert_snli_multinli_stsb` | 22,230 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/embedding__molecule_text_sbiobert_snli_multinli_stsb.md) |
# | `embedding` | `pathway_text_sbiobert_snli_multinli_stsb` | 37,492 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/embedding__pathway_text_sbiobert_snli_multinli_stsb.md) |
# | `embedding` | `phenotype_text_sbiobert_snli_multinli_stsb` | 13,810 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/embedding__phenotype_text_sbiobert_snli_multinli_stsb.md) |
# | `embedding` | `protein_text_sbiobert_snli_multinli_stsb` | 162,163 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/embedding__protein_text_sbiobert_snli_multinli_stsb.md) |
# | `embedding` | `tissue_text_sbiobert_snli_multinli_stsb` | 11,942 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/embedding__tissue_text_sbiobert_snli_multinli_stsb.md) |

# %% [markdown]
# ## Native inputs, release, acquisition and environment
#
# Shared acquisition context is stated once; release and retained input differences are restated under every owned output.
#
# ## Expected schema and identifiers
#
# Each output section carries its exact catalog schema, row count, object generation and checksum.
#
# ## Keys, mappings and joins
#
# Shared family mappings are applied only where stated; every output preserves its own key contract.
#
# ## Cleaning, normalization, transformations and filters
#
# Transformation and filter differences are explicit per output below.
#
# ## Deduplication and assertion/evidence semantics
#
# Canonical edges are deduplicated assertions; source-specific multiplicity and context remain evidence/features where applicable.
#
# ## Quarantines, exclusions and missing data
#
# Every output contract states its known exclusions and unresolved provenance.
#
# ## Problems encountered and decisions
#
# Known decisions and alternatives are reported conservatively; migration identity is not treated as proof of biological replayability.
#
# ## Producer / builder
#
# The per-output contracts name an evidenced tracked producer or state that it is unavailable.
#
# ## Full worker rebuild command (inert text; never executed by this notebook)
#
# Any command below is documentation only and remains approved-worker, staging and review gated.
#
# ## Migration receipt
#
# Every output includes its generation-matched, verified migration receipt.
#
# ## QC, bounded replay and verification
#
# The first code cell validates all embedded output contracts offline. The opt-in cell verifies one selected GCS object metadata record and Parquet footer, chosen with `JOUVENCE_OUTPUT_ID`; it never scans all family outputs.
#
# ## Reproducibility limits
#
# Replay levels remain per output. No family-level label upgrades weaker members.
#
# ## Linked code, tests, reports and historical notebooks
#
# Links are listed in each output contract.

# %% [markdown]
# ## Per-output reproduction contracts
#
# ### Output `embedding__cell_line_text_sbiobert_snli_multinli_stsb`
#
# - Canonical URI: `gs://jouvencekb/main/embeddings/cell_line_text_sbiobert_snli_multinli_stsb.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/embedding__cell_line_text_sbiobert_snli_multinli_stsb.md`](../../docs/parquet-catalog/datasets/embedding__cell_line_text_sbiobert_snli_multinli_stsb.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Accepted learned vector table for canonical `cell_line` nodes.
# - Does not mean: Vector similarity is not functional equivalence, causality, or therapeutic evidence.
#
# **Native inputs and release.** Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **1,140**; bytes: **4,058,123**; row groups: **1**; schema hash (`arrow-fields-v1`): `39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab`; generation: `1785155497866360`; CRC32C: `o1yMPg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `embedding_key` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `source_feature_table` | `string` | `true` |
# | `source_feature_key` | `string` | `true` |
# | `source_feature_hash` | `string` | `true` |
# | `modality` | `string` | `true` |
# | `embedding_model` | `string` | `true` |
# | `embedding_version` | `string` | `true` |
# | `embedding_dim` | `int32` | `false` |
# | `embedding_dtype` | `string` | `true` |
# | `embedding_format` | `string` | `false` |
# | `embedding` | `fixed_size_list<element: float>[768]` | `false` |
# | `pooling` | `string` | `true` |
# | `normalization` | `string` | `true` |
# | `preprocessing` | `string` | `true` |
# | `input_length` | `int64` | `true` |
# | `window_count` | `int32` | `false` |
# | `created_at` | `string` | `true` |
# | `source_feature_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `embedding_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.
#
# **Cleaning, normalization, transformations and filters.** Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.
#
# **Problems encountered and decisions.** The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.
#
# Known gaps: `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `manage_db/build_real_embeddings.py`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/embeddings/text/cell_line/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet`
# - Destination generation: `1785155497866360`
# - Destination CRC32C: `o1yMPg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/embedding__cell_line_text_sbiobert_snli_multinli_stsb.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_real_embeddings.py`
#
#
# ### Output `embedding__cell_type_text_sbiobert_snli_multinli_stsb`
#
# - Canonical URI: `gs://jouvencekb/main/embeddings/cell_type_text_sbiobert_snli_multinli_stsb.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/embedding__cell_type_text_sbiobert_snli_multinli_stsb.md`](../../docs/parquet-catalog/datasets/embedding__cell_type_text_sbiobert_snli_multinli_stsb.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Accepted learned vector table for canonical `cell_type` nodes.
# - Does not mean: Vector similarity is not functional equivalence, causality, or therapeutic evidence.
#
# **Native inputs and release.** Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **3,135**; bytes: **10,008,117**; row groups: **1**; schema hash (`arrow-fields-v1`): `39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab`; generation: `1785155498038129`; CRC32C: `f35ahg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `embedding_key` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `source_feature_table` | `string` | `true` |
# | `source_feature_key` | `string` | `true` |
# | `source_feature_hash` | `string` | `true` |
# | `modality` | `string` | `true` |
# | `embedding_model` | `string` | `true` |
# | `embedding_version` | `string` | `true` |
# | `embedding_dim` | `int32` | `false` |
# | `embedding_dtype` | `string` | `true` |
# | `embedding_format` | `string` | `false` |
# | `embedding` | `fixed_size_list<element: float>[768]` | `false` |
# | `pooling` | `string` | `true` |
# | `normalization` | `string` | `true` |
# | `preprocessing` | `string` | `true` |
# | `input_length` | `int64` | `true` |
# | `window_count` | `int32` | `false` |
# | `created_at` | `string` | `true` |
# | `source_feature_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `embedding_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.
#
# **Cleaning, normalization, transformations and filters.** Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.
#
# **Problems encountered and decisions.** The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.
#
# Known gaps: `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `manage_db/build_real_embeddings.py`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/embeddings/text/cell_type/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet`
# - Destination generation: `1785155498038129`
# - Destination CRC32C: `f35ahg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/embedding__cell_type_text_sbiobert_snli_multinli_stsb.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_real_embeddings.py`
#
#
# ### Output `embedding__disease_text_sbiobert_snli_multinli_stsb`
#
# - Canonical URI: `gs://jouvencekb/main/embeddings/disease_text_sbiobert_snli_multinli_stsb.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/embedding__disease_text_sbiobert_snli_multinli_stsb.md`](../../docs/parquet-catalog/datasets/embedding__disease_text_sbiobert_snli_multinli_stsb.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Accepted learned vector table for canonical `disease` nodes.
# - Does not mean: Vector similarity is not functional equivalence, causality, or therapeutic evidence.
#
# **Native inputs and release.** Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **26,395**; bytes: **83,411,173**; row groups: **7**; schema hash (`arrow-fields-v1`): `39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab`; generation: `1785155498236926`; CRC32C: `Wm+Pxg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `embedding_key` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `source_feature_table` | `string` | `true` |
# | `source_feature_key` | `string` | `true` |
# | `source_feature_hash` | `string` | `true` |
# | `modality` | `string` | `true` |
# | `embedding_model` | `string` | `true` |
# | `embedding_version` | `string` | `true` |
# | `embedding_dim` | `int32` | `false` |
# | `embedding_dtype` | `string` | `true` |
# | `embedding_format` | `string` | `false` |
# | `embedding` | `fixed_size_list<element: float>[768]` | `false` |
# | `pooling` | `string` | `true` |
# | `normalization` | `string` | `true` |
# | `preprocessing` | `string` | `true` |
# | `input_length` | `int64` | `true` |
# | `window_count` | `int32` | `false` |
# | `created_at` | `string` | `true` |
# | `source_feature_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `embedding_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.
#
# **Cleaning, normalization, transformations and filters.** Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.
#
# **Problems encountered and decisions.** The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.
#
# Known gaps: `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `manage_db/build_real_embeddings.py`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/embeddings/text/disease/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet`
# - Destination generation: `1785155498236926`
# - Destination CRC32C: `Wm+Pxg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/embedding__disease_text_sbiobert_snli_multinli_stsb.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_real_embeddings.py`
#
#
# ### Output `embedding__gene_text_sbiobert_snli_multinli_stsb`
#
# - Canonical URI: `gs://jouvencekb/main/embeddings/gene_text_sbiobert_snli_multinli_stsb.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/embedding__gene_text_sbiobert_snli_multinli_stsb.md`](../../docs/parquet-catalog/datasets/embedding__gene_text_sbiobert_snli_multinli_stsb.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Accepted learned vector table for canonical `gene` nodes.
# - Does not mean: Vector similarity is not functional equivalence, causality, or therapeutic evidence.
#
# **Native inputs and release.** Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **212,029**; bytes: **658,824,072**; row groups: **52**; schema hash (`arrow-fields-v1`): `39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab`; generation: `1785155498443137`; CRC32C: `Vfaygw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `embedding_key` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `source_feature_table` | `string` | `true` |
# | `source_feature_key` | `string` | `true` |
# | `source_feature_hash` | `string` | `true` |
# | `modality` | `string` | `true` |
# | `embedding_model` | `string` | `true` |
# | `embedding_version` | `string` | `true` |
# | `embedding_dim` | `int32` | `false` |
# | `embedding_dtype` | `string` | `true` |
# | `embedding_format` | `string` | `false` |
# | `embedding` | `fixed_size_list<element: float>[768]` | `false` |
# | `pooling` | `string` | `true` |
# | `normalization` | `string` | `true` |
# | `preprocessing` | `string` | `true` |
# | `input_length` | `int64` | `true` |
# | `window_count` | `int32` | `false` |
# | `created_at` | `string` | `true` |
# | `source_feature_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `embedding_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.
#
# **Cleaning, normalization, transformations and filters.** Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.
#
# **Problems encountered and decisions.** The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.
#
# Known gaps: `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `manage_db/build_real_embeddings.py`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/embeddings/text/gene/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet`
# - Destination generation: `1785155498443137`
# - Destination CRC32C: `Vfaygw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/embedding__gene_text_sbiobert_snli_multinli_stsb.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_real_embeddings.py`
#
#
# ### Output `embedding__molecule_text_sbiobert_snli_multinli_stsb`
#
# - Canonical URI: `gs://jouvencekb/main/embeddings/molecule_text_sbiobert_snli_multinli_stsb.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/embedding__molecule_text_sbiobert_snli_multinli_stsb.md`](../../docs/parquet-catalog/datasets/embedding__molecule_text_sbiobert_snli_multinli_stsb.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Accepted learned vector table for canonical `molecule` nodes.
# - Does not mean: Vector similarity is not functional equivalence, causality, or therapeutic evidence.
#
# **Native inputs and release.** Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **22,230**; bytes: **69,504,010**; row groups: **6**; schema hash (`arrow-fields-v1`): `39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab`; generation: `1785155498633508`; CRC32C: `aldyBQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `embedding_key` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `source_feature_table` | `string` | `true` |
# | `source_feature_key` | `string` | `true` |
# | `source_feature_hash` | `string` | `true` |
# | `modality` | `string` | `true` |
# | `embedding_model` | `string` | `true` |
# | `embedding_version` | `string` | `true` |
# | `embedding_dim` | `int32` | `false` |
# | `embedding_dtype` | `string` | `true` |
# | `embedding_format` | `string` | `false` |
# | `embedding` | `fixed_size_list<element: float>[768]` | `false` |
# | `pooling` | `string` | `true` |
# | `normalization` | `string` | `true` |
# | `preprocessing` | `string` | `true` |
# | `input_length` | `int64` | `true` |
# | `window_count` | `int32` | `false` |
# | `created_at` | `string` | `true` |
# | `source_feature_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `embedding_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.
#
# **Cleaning, normalization, transformations and filters.** Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.
#
# **Problems encountered and decisions.** The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.
#
# Known gaps: `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `manage_db/build_real_embeddings.py`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/embeddings/text/molecule/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet`
# - Destination generation: `1785155498633508`
# - Destination CRC32C: `aldyBQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/embedding__molecule_text_sbiobert_snli_multinli_stsb.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_real_embeddings.py`
#
#
# ### Output `embedding__pathway_text_sbiobert_snli_multinli_stsb`
#
# - Canonical URI: `gs://jouvencekb/main/embeddings/pathway_text_sbiobert_snli_multinli_stsb.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/embedding__pathway_text_sbiobert_snli_multinli_stsb.md`](../../docs/parquet-catalog/datasets/embedding__pathway_text_sbiobert_snli_multinli_stsb.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Accepted learned vector table for canonical `pathway` nodes.
# - Does not mean: Vector similarity is not functional equivalence, causality, or therapeutic evidence.
#
# **Native inputs and release.** Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **37,492**; bytes: **118,074,019**; row groups: **10**; schema hash (`arrow-fields-v1`): `39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab`; generation: `1785155498783527`; CRC32C: `3tyvPw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `embedding_key` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `source_feature_table` | `string` | `true` |
# | `source_feature_key` | `string` | `true` |
# | `source_feature_hash` | `string` | `true` |
# | `modality` | `string` | `true` |
# | `embedding_model` | `string` | `true` |
# | `embedding_version` | `string` | `true` |
# | `embedding_dim` | `int32` | `false` |
# | `embedding_dtype` | `string` | `true` |
# | `embedding_format` | `string` | `false` |
# | `embedding` | `fixed_size_list<element: float>[768]` | `false` |
# | `pooling` | `string` | `true` |
# | `normalization` | `string` | `true` |
# | `preprocessing` | `string` | `true` |
# | `input_length` | `int64` | `true` |
# | `window_count` | `int32` | `false` |
# | `created_at` | `string` | `true` |
# | `source_feature_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `embedding_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.
#
# **Cleaning, normalization, transformations and filters.** Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.
#
# **Problems encountered and decisions.** The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.
#
# Known gaps: `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `manage_db/build_real_embeddings.py`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/embeddings/text/pathway/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet`
# - Destination generation: `1785155498783527`
# - Destination CRC32C: `3tyvPw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/embedding__pathway_text_sbiobert_snli_multinli_stsb.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_real_embeddings.py`
#
#
# ### Output `embedding__phenotype_text_sbiobert_snli_multinli_stsb`
#
# - Canonical URI: `gs://jouvencekb/main/embeddings/phenotype_text_sbiobert_snli_multinli_stsb.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/embedding__phenotype_text_sbiobert_snli_multinli_stsb.md`](../../docs/parquet-catalog/datasets/embedding__phenotype_text_sbiobert_snli_multinli_stsb.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Accepted learned vector table for canonical `phenotype` nodes.
# - Does not mean: Vector similarity is not functional equivalence, causality, or therapeutic evidence.
#
# **Native inputs and release.** Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **13,810**; bytes: **43,813,040**; row groups: **4**; schema hash (`arrow-fields-v1`): `39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab`; generation: `1785155498956211`; CRC32C: `eoo3uA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `embedding_key` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `source_feature_table` | `string` | `true` |
# | `source_feature_key` | `string` | `true` |
# | `source_feature_hash` | `string` | `true` |
# | `modality` | `string` | `true` |
# | `embedding_model` | `string` | `true` |
# | `embedding_version` | `string` | `true` |
# | `embedding_dim` | `int32` | `false` |
# | `embedding_dtype` | `string` | `true` |
# | `embedding_format` | `string` | `false` |
# | `embedding` | `fixed_size_list<element: float>[768]` | `false` |
# | `pooling` | `string` | `true` |
# | `normalization` | `string` | `true` |
# | `preprocessing` | `string` | `true` |
# | `input_length` | `int64` | `true` |
# | `window_count` | `int32` | `false` |
# | `created_at` | `string` | `true` |
# | `source_feature_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `embedding_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.
#
# **Cleaning, normalization, transformations and filters.** Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.
#
# **Problems encountered and decisions.** The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.
#
# Known gaps: `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `manage_db/build_real_embeddings.py`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/embeddings/text/phenotype/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet`
# - Destination generation: `1785155498956211`
# - Destination CRC32C: `eoo3uA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/embedding__phenotype_text_sbiobert_snli_multinli_stsb.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_real_embeddings.py`
#
#
# ### Output `embedding__protein_text_sbiobert_snli_multinli_stsb`
#
# - Canonical URI: `gs://jouvencekb/main/embeddings/protein_text_sbiobert_snli_multinli_stsb.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/embedding__protein_text_sbiobert_snli_multinli_stsb.md`](../../docs/parquet-catalog/datasets/embedding__protein_text_sbiobert_snli_multinli_stsb.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Accepted learned vector table for canonical `protein` nodes.
# - Does not mean: Vector similarity is not functional equivalence, causality, or therapeutic evidence.
#
# **Native inputs and release.** Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **162,163**; bytes: **510,293,975**; row groups: **40**; schema hash (`arrow-fields-v1`): `39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab`; generation: `1785155499119022`; CRC32C: `jHmOmw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `embedding_key` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `source_feature_table` | `string` | `true` |
# | `source_feature_key` | `string` | `true` |
# | `source_feature_hash` | `string` | `true` |
# | `modality` | `string` | `true` |
# | `embedding_model` | `string` | `true` |
# | `embedding_version` | `string` | `true` |
# | `embedding_dim` | `int32` | `false` |
# | `embedding_dtype` | `string` | `true` |
# | `embedding_format` | `string` | `false` |
# | `embedding` | `fixed_size_list<element: float>[768]` | `false` |
# | `pooling` | `string` | `true` |
# | `normalization` | `string` | `true` |
# | `preprocessing` | `string` | `true` |
# | `input_length` | `int64` | `true` |
# | `window_count` | `int32` | `false` |
# | `created_at` | `string` | `true` |
# | `source_feature_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `embedding_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.
#
# **Cleaning, normalization, transformations and filters.** Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.
#
# **Problems encountered and decisions.** The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.
#
# Known gaps: `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `manage_db/build_real_embeddings.py`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/embeddings/text/protein/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet`
# - Destination generation: `1785155499119022`
# - Destination CRC32C: `jHmOmw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/embedding__protein_text_sbiobert_snli_multinli_stsb.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_real_embeddings.py`
#
#
# ### Output `embedding__tissue_text_sbiobert_snli_multinli_stsb`
#
# - Canonical URI: `gs://jouvencekb/main/embeddings/tissue_text_sbiobert_snli_multinli_stsb.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/embedding__tissue_text_sbiobert_snli_multinli_stsb.md`](../../docs/parquet-catalog/datasets/embedding__tissue_text_sbiobert_snli_multinli_stsb.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Accepted learned vector table for canonical `tissue` nodes.
# - Does not mean: Vector similarity is not functional equivalence, causality, or therapeutic evidence.
#
# **Native inputs and release.** Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **11,942**; bytes: **37,627,203**; row groups: **3**; schema hash (`arrow-fields-v1`): `39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab`; generation: `1785155499285276`; CRC32C: `9u0yMg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `embedding_key` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `source_feature_table` | `string` | `true` |
# | `source_feature_key` | `string` | `true` |
# | `source_feature_hash` | `string` | `true` |
# | `modality` | `string` | `true` |
# | `embedding_model` | `string` | `true` |
# | `embedding_version` | `string` | `true` |
# | `embedding_dim` | `int32` | `false` |
# | `embedding_dtype` | `string` | `true` |
# | `embedding_format` | `string` | `false` |
# | `embedding` | `fixed_size_list<element: float>[768]` | `false` |
# | `pooling` | `string` | `true` |
# | `normalization` | `string` | `true` |
# | `preprocessing` | `string` | `true` |
# | `input_length` | `int64` | `true` |
# | `window_count` | `int32` | `false` |
# | `created_at` | `string` | `true` |
# | `source_feature_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `embedding_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.
#
# **Cleaning, normalization, transformations and filters.** Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.
#
# **Problems encountered and decisions.** The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.
#
# Known gaps: `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `manage_db/build_real_embeddings.py`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/embeddings/text/tissue/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet`
# - Destination generation: `1785155499285276`
# - Destination CRC32C: `9u0yMg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/embedding__tissue_text_sbiobert_snli_multinli_stsb.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_real_embeddings.py`

# %% [markdown]
# ## Offline bounded contract check
#
# This cell uses only the embedded frozen lineage record.

# %%
import hashlib
import json

RECORDS = json.loads(r'''[{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/embeddings/cell_line_text_sbiobert_snli_multinli_stsb.parquet","catalog_page":"docs/parquet-catalog/datasets/embedding__cell_line_text_sbiobert_snli_multinli_stsb.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"embedding_key","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"source_feature_table","nullable":true},{"dtype":"string","name":"source_feature_key","nullable":true},{"dtype":"string","name":"source_feature_hash","nullable":true},{"dtype":"string","name":"modality","nullable":true},{"dtype":"string","name":"embedding_model","nullable":true},{"dtype":"string","name":"embedding_version","nullable":true},{"dtype":"int32","name":"embedding_dim","nullable":false},{"dtype":"string","name":"embedding_dtype","nullable":true},{"dtype":"string","name":"embedding_format","nullable":false},{"dtype":"fixed_size_list<element: float>[768]","name":"embedding","nullable":false},{"dtype":"string","name":"pooling","nullable":true},{"dtype":"string","name":"normalization","nullable":true},{"dtype":"string","name":"preprocessing","nullable":true},{"dtype":"int64","name":"input_length","nullable":true},{"dtype":"int32","name":"window_count","nullable":false},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"source_feature_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["embedding_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["retained native input","verified exact rebuild command"],"layer":"embedding","links":["docs/parquet-catalog/datasets/embedding__cell_line_text_sbiobert_snli_multinli_stsb.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_real_embeddings.py"],"mappings_and_joins":"Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.","meaning":"Accepted learned vector table for canonical `cell_line` nodes.","migration_receipt":{"action":"copied","destination_crc32c":"o1yMPg==","destination_generation":"1785155497866360","source":"kg/v2/features/embeddings/text/cell_line/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet","source_generation":"1784460736544221","verified":true},"name":"cell_line_text_sbiobert_snli_multinli_stsb","native_inputs":[],"native_source":[],"non_meaning":"Vector similarity is not functional equivalence, causality, or therapeutic evidence.","pipeline_family":"text_embeddings","problems_and_decisions":"The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.","producer":"manage_db/build_real_embeddings.py","producer_builder":"manage_db/build_real_embeddings.py","provenance_gaps":["retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":4058123,"crc32c_base64":"o1yMPg==","generation":"1785155497866360","md5_base64":"h+Pim6ghyrkTKgSDu0GhTw==","row_groups":1,"rows":1140,"schema_hash":"39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.","rebuild_command_evidenced":false,"release":"Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/text_embeddings.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"text_embeddings","source_family_label":"Source-backed biomedical text embedding pipeline","transformations_and_filters":"Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/embeddings/cell_type_text_sbiobert_snli_multinli_stsb.parquet","catalog_page":"docs/parquet-catalog/datasets/embedding__cell_type_text_sbiobert_snli_multinli_stsb.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"embedding_key","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"source_feature_table","nullable":true},{"dtype":"string","name":"source_feature_key","nullable":true},{"dtype":"string","name":"source_feature_hash","nullable":true},{"dtype":"string","name":"modality","nullable":true},{"dtype":"string","name":"embedding_model","nullable":true},{"dtype":"string","name":"embedding_version","nullable":true},{"dtype":"int32","name":"embedding_dim","nullable":false},{"dtype":"string","name":"embedding_dtype","nullable":true},{"dtype":"string","name":"embedding_format","nullable":false},{"dtype":"fixed_size_list<element: float>[768]","name":"embedding","nullable":false},{"dtype":"string","name":"pooling","nullable":true},{"dtype":"string","name":"normalization","nullable":true},{"dtype":"string","name":"preprocessing","nullable":true},{"dtype":"int64","name":"input_length","nullable":true},{"dtype":"int32","name":"window_count","nullable":false},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"source_feature_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["embedding_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["retained native input","verified exact rebuild command"],"layer":"embedding","links":["docs/parquet-catalog/datasets/embedding__cell_type_text_sbiobert_snli_multinli_stsb.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_real_embeddings.py"],"mappings_and_joins":"Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.","meaning":"Accepted learned vector table for canonical `cell_type` nodes.","migration_receipt":{"action":"copied","destination_crc32c":"f35ahg==","destination_generation":"1785155498038129","source":"kg/v2/features/embeddings/text/cell_type/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet","source_generation":"1784460737683374","verified":true},"name":"cell_type_text_sbiobert_snli_multinli_stsb","native_inputs":[],"native_source":[],"non_meaning":"Vector similarity is not functional equivalence, causality, or therapeutic evidence.","pipeline_family":"text_embeddings","problems_and_decisions":"The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.","producer":"manage_db/build_real_embeddings.py","producer_builder":"manage_db/build_real_embeddings.py","provenance_gaps":["retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":10008117,"crc32c_base64":"f35ahg==","generation":"1785155498038129","md5_base64":"+ozknvcy5/t5P4bPiJspkA==","row_groups":1,"rows":3135,"schema_hash":"39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.","rebuild_command_evidenced":false,"release":"Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/text_embeddings.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"text_embeddings","source_family_label":"Source-backed biomedical text embedding pipeline","transformations_and_filters":"Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/embeddings/disease_text_sbiobert_snli_multinli_stsb.parquet","catalog_page":"docs/parquet-catalog/datasets/embedding__disease_text_sbiobert_snli_multinli_stsb.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"embedding_key","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"source_feature_table","nullable":true},{"dtype":"string","name":"source_feature_key","nullable":true},{"dtype":"string","name":"source_feature_hash","nullable":true},{"dtype":"string","name":"modality","nullable":true},{"dtype":"string","name":"embedding_model","nullable":true},{"dtype":"string","name":"embedding_version","nullable":true},{"dtype":"int32","name":"embedding_dim","nullable":false},{"dtype":"string","name":"embedding_dtype","nullable":true},{"dtype":"string","name":"embedding_format","nullable":false},{"dtype":"fixed_size_list<element: float>[768]","name":"embedding","nullable":false},{"dtype":"string","name":"pooling","nullable":true},{"dtype":"string","name":"normalization","nullable":true},{"dtype":"string","name":"preprocessing","nullable":true},{"dtype":"int64","name":"input_length","nullable":true},{"dtype":"int32","name":"window_count","nullable":false},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"source_feature_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["embedding_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["retained native input","verified exact rebuild command"],"layer":"embedding","links":["docs/parquet-catalog/datasets/embedding__disease_text_sbiobert_snli_multinli_stsb.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_real_embeddings.py"],"mappings_and_joins":"Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.","meaning":"Accepted learned vector table for canonical `disease` nodes.","migration_receipt":{"action":"copied","destination_crc32c":"Wm+Pxg==","destination_generation":"1785155498236926","source":"kg/v2/features/embeddings/text/disease/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet","source_generation":"1784460742500050","verified":true},"name":"disease_text_sbiobert_snli_multinli_stsb","native_inputs":[],"native_source":[],"non_meaning":"Vector similarity is not functional equivalence, causality, or therapeutic evidence.","pipeline_family":"text_embeddings","problems_and_decisions":"The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.","producer":"manage_db/build_real_embeddings.py","producer_builder":"manage_db/build_real_embeddings.py","provenance_gaps":["retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":83411173,"crc32c_base64":"Wm+Pxg==","generation":"1785155498236926","md5_base64":"B887Du9fIvkTiQkJ6CfYWw==","row_groups":7,"rows":26395,"schema_hash":"39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.","rebuild_command_evidenced":false,"release":"Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/text_embeddings.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"text_embeddings","source_family_label":"Source-backed biomedical text embedding pipeline","transformations_and_filters":"Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/embeddings/gene_text_sbiobert_snli_multinli_stsb.parquet","catalog_page":"docs/parquet-catalog/datasets/embedding__gene_text_sbiobert_snli_multinli_stsb.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"embedding_key","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"source_feature_table","nullable":true},{"dtype":"string","name":"source_feature_key","nullable":true},{"dtype":"string","name":"source_feature_hash","nullable":true},{"dtype":"string","name":"modality","nullable":true},{"dtype":"string","name":"embedding_model","nullable":true},{"dtype":"string","name":"embedding_version","nullable":true},{"dtype":"int32","name":"embedding_dim","nullable":false},{"dtype":"string","name":"embedding_dtype","nullable":true},{"dtype":"string","name":"embedding_format","nullable":false},{"dtype":"fixed_size_list<element: float>[768]","name":"embedding","nullable":false},{"dtype":"string","name":"pooling","nullable":true},{"dtype":"string","name":"normalization","nullable":true},{"dtype":"string","name":"preprocessing","nullable":true},{"dtype":"int64","name":"input_length","nullable":true},{"dtype":"int32","name":"window_count","nullable":false},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"source_feature_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["embedding_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["retained native input","verified exact rebuild command"],"layer":"embedding","links":["docs/parquet-catalog/datasets/embedding__gene_text_sbiobert_snli_multinli_stsb.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_real_embeddings.py"],"mappings_and_joins":"Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.","meaning":"Accepted learned vector table for canonical `gene` nodes.","migration_receipt":{"action":"copied","destination_crc32c":"Vfaygw==","destination_generation":"1785155498443137","source":"kg/v2/features/embeddings/text/gene/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet","source_generation":"1784460777610436","verified":true},"name":"gene_text_sbiobert_snli_multinli_stsb","native_inputs":[],"native_source":[],"non_meaning":"Vector similarity is not functional equivalence, causality, or therapeutic evidence.","pipeline_family":"text_embeddings","problems_and_decisions":"The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.","producer":"manage_db/build_real_embeddings.py","producer_builder":"manage_db/build_real_embeddings.py","provenance_gaps":["retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":658824072,"crc32c_base64":"Vfaygw==","generation":"1785155498443137","md5_base64":"axT8Yajhyd7n8Ho18tQNVg==","row_groups":52,"rows":212029,"schema_hash":"39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.","rebuild_command_evidenced":false,"release":"Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/text_embeddings.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"text_embeddings","source_family_label":"Source-backed biomedical text embedding pipeline","transformations_and_filters":"Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/embeddings/molecule_text_sbiobert_snli_multinli_stsb.parquet","catalog_page":"docs/parquet-catalog/datasets/embedding__molecule_text_sbiobert_snli_multinli_stsb.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"embedding_key","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"source_feature_table","nullable":true},{"dtype":"string","name":"source_feature_key","nullable":true},{"dtype":"string","name":"source_feature_hash","nullable":true},{"dtype":"string","name":"modality","nullable":true},{"dtype":"string","name":"embedding_model","nullable":true},{"dtype":"string","name":"embedding_version","nullable":true},{"dtype":"int32","name":"embedding_dim","nullable":false},{"dtype":"string","name":"embedding_dtype","nullable":true},{"dtype":"string","name":"embedding_format","nullable":false},{"dtype":"fixed_size_list<element: float>[768]","name":"embedding","nullable":false},{"dtype":"string","name":"pooling","nullable":true},{"dtype":"string","name":"normalization","nullable":true},{"dtype":"string","name":"preprocessing","nullable":true},{"dtype":"int64","name":"input_length","nullable":true},{"dtype":"int32","name":"window_count","nullable":false},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"source_feature_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["embedding_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["retained native input","verified exact rebuild command"],"layer":"embedding","links":["docs/parquet-catalog/datasets/embedding__molecule_text_sbiobert_snli_multinli_stsb.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_real_embeddings.py"],"mappings_and_joins":"Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.","meaning":"Accepted learned vector table for canonical `molecule` nodes.","migration_receipt":{"action":"copied","destination_crc32c":"aldyBQ==","destination_generation":"1785155498633508","source":"kg/v2/features/embeddings/text/molecule/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet","source_generation":"1784460781823286","verified":true},"name":"molecule_text_sbiobert_snli_multinli_stsb","native_inputs":[],"native_source":[],"non_meaning":"Vector similarity is not functional equivalence, causality, or therapeutic evidence.","pipeline_family":"text_embeddings","problems_and_decisions":"The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.","producer":"manage_db/build_real_embeddings.py","producer_builder":"manage_db/build_real_embeddings.py","provenance_gaps":["retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":69504010,"crc32c_base64":"aldyBQ==","generation":"1785155498633508","md5_base64":"OIkFGOuVAE7X/ib4cN2ZBw==","row_groups":6,"rows":22230,"schema_hash":"39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.","rebuild_command_evidenced":false,"release":"Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/text_embeddings.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"text_embeddings","source_family_label":"Source-backed biomedical text embedding pipeline","transformations_and_filters":"Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/embeddings/pathway_text_sbiobert_snli_multinli_stsb.parquet","catalog_page":"docs/parquet-catalog/datasets/embedding__pathway_text_sbiobert_snli_multinli_stsb.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"embedding_key","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"source_feature_table","nullable":true},{"dtype":"string","name":"source_feature_key","nullable":true},{"dtype":"string","name":"source_feature_hash","nullable":true},{"dtype":"string","name":"modality","nullable":true},{"dtype":"string","name":"embedding_model","nullable":true},{"dtype":"string","name":"embedding_version","nullable":true},{"dtype":"int32","name":"embedding_dim","nullable":false},{"dtype":"string","name":"embedding_dtype","nullable":true},{"dtype":"string","name":"embedding_format","nullable":false},{"dtype":"fixed_size_list<element: float>[768]","name":"embedding","nullable":false},{"dtype":"string","name":"pooling","nullable":true},{"dtype":"string","name":"normalization","nullable":true},{"dtype":"string","name":"preprocessing","nullable":true},{"dtype":"int64","name":"input_length","nullable":true},{"dtype":"int32","name":"window_count","nullable":false},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"source_feature_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["embedding_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["retained native input","verified exact rebuild command"],"layer":"embedding","links":["docs/parquet-catalog/datasets/embedding__pathway_text_sbiobert_snli_multinli_stsb.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_real_embeddings.py"],"mappings_and_joins":"Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.","meaning":"Accepted learned vector table for canonical `pathway` nodes.","migration_receipt":{"action":"copied","destination_crc32c":"3tyvPw==","destination_generation":"1785155498783527","source":"kg/v2/features/embeddings/text/pathway/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet","source_generation":"1784460788293117","verified":true},"name":"pathway_text_sbiobert_snli_multinli_stsb","native_inputs":[],"native_source":[],"non_meaning":"Vector similarity is not functional equivalence, causality, or therapeutic evidence.","pipeline_family":"text_embeddings","problems_and_decisions":"The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.","producer":"manage_db/build_real_embeddings.py","producer_builder":"manage_db/build_real_embeddings.py","provenance_gaps":["retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":118074019,"crc32c_base64":"3tyvPw==","generation":"1785155498783527","md5_base64":"vRnIAeKg1cRSukE7keu7IQ==","row_groups":10,"rows":37492,"schema_hash":"39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.","rebuild_command_evidenced":false,"release":"Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/text_embeddings.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"text_embeddings","source_family_label":"Source-backed biomedical text embedding pipeline","transformations_and_filters":"Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/embeddings/phenotype_text_sbiobert_snli_multinli_stsb.parquet","catalog_page":"docs/parquet-catalog/datasets/embedding__phenotype_text_sbiobert_snli_multinli_stsb.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"embedding_key","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"source_feature_table","nullable":true},{"dtype":"string","name":"source_feature_key","nullable":true},{"dtype":"string","name":"source_feature_hash","nullable":true},{"dtype":"string","name":"modality","nullable":true},{"dtype":"string","name":"embedding_model","nullable":true},{"dtype":"string","name":"embedding_version","nullable":true},{"dtype":"int32","name":"embedding_dim","nullable":false},{"dtype":"string","name":"embedding_dtype","nullable":true},{"dtype":"string","name":"embedding_format","nullable":false},{"dtype":"fixed_size_list<element: float>[768]","name":"embedding","nullable":false},{"dtype":"string","name":"pooling","nullable":true},{"dtype":"string","name":"normalization","nullable":true},{"dtype":"string","name":"preprocessing","nullable":true},{"dtype":"int64","name":"input_length","nullable":true},{"dtype":"int32","name":"window_count","nullable":false},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"source_feature_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["embedding_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["retained native input","verified exact rebuild command"],"layer":"embedding","links":["docs/parquet-catalog/datasets/embedding__phenotype_text_sbiobert_snli_multinli_stsb.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_real_embeddings.py"],"mappings_and_joins":"Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.","meaning":"Accepted learned vector table for canonical `phenotype` nodes.","migration_receipt":{"action":"copied","destination_crc32c":"eoo3uA==","destination_generation":"1785155498956211","source":"kg/v2/features/embeddings/text/phenotype/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet","source_generation":"1784460791120436","verified":true},"name":"phenotype_text_sbiobert_snli_multinli_stsb","native_inputs":[],"native_source":[],"non_meaning":"Vector similarity is not functional equivalence, causality, or therapeutic evidence.","pipeline_family":"text_embeddings","problems_and_decisions":"The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.","producer":"manage_db/build_real_embeddings.py","producer_builder":"manage_db/build_real_embeddings.py","provenance_gaps":["retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":43813040,"crc32c_base64":"eoo3uA==","generation":"1785155498956211","md5_base64":"Akw7BNHKkDxDNn//4BSi1w==","row_groups":4,"rows":13810,"schema_hash":"39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.","rebuild_command_evidenced":false,"release":"Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/text_embeddings.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"text_embeddings","source_family_label":"Source-backed biomedical text embedding pipeline","transformations_and_filters":"Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/embeddings/protein_text_sbiobert_snli_multinli_stsb.parquet","catalog_page":"docs/parquet-catalog/datasets/embedding__protein_text_sbiobert_snli_multinli_stsb.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"embedding_key","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"source_feature_table","nullable":true},{"dtype":"string","name":"source_feature_key","nullable":true},{"dtype":"string","name":"source_feature_hash","nullable":true},{"dtype":"string","name":"modality","nullable":true},{"dtype":"string","name":"embedding_model","nullable":true},{"dtype":"string","name":"embedding_version","nullable":true},{"dtype":"int32","name":"embedding_dim","nullable":false},{"dtype":"string","name":"embedding_dtype","nullable":true},{"dtype":"string","name":"embedding_format","nullable":false},{"dtype":"fixed_size_list<element: float>[768]","name":"embedding","nullable":false},{"dtype":"string","name":"pooling","nullable":true},{"dtype":"string","name":"normalization","nullable":true},{"dtype":"string","name":"preprocessing","nullable":true},{"dtype":"int64","name":"input_length","nullable":true},{"dtype":"int32","name":"window_count","nullable":false},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"source_feature_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["embedding_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["retained native input","verified exact rebuild command"],"layer":"embedding","links":["docs/parquet-catalog/datasets/embedding__protein_text_sbiobert_snli_multinli_stsb.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_real_embeddings.py"],"mappings_and_joins":"Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.","meaning":"Accepted learned vector table for canonical `protein` nodes.","migration_receipt":{"action":"copied","destination_crc32c":"jHmOmw==","destination_generation":"1785155499119022","source":"kg/v2/features/embeddings/text/protein/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet","source_generation":"1784460817709315","verified":true},"name":"protein_text_sbiobert_snli_multinli_stsb","native_inputs":[],"native_source":[],"non_meaning":"Vector similarity is not functional equivalence, causality, or therapeutic evidence.","pipeline_family":"text_embeddings","problems_and_decisions":"The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.","producer":"manage_db/build_real_embeddings.py","producer_builder":"manage_db/build_real_embeddings.py","provenance_gaps":["retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":510293975,"crc32c_base64":"jHmOmw==","generation":"1785155499119022","md5_base64":"TwVcCHrUvnn+XnM4CUlKjw==","row_groups":40,"rows":162163,"schema_hash":"39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.","rebuild_command_evidenced":false,"release":"Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/text_embeddings.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"text_embeddings","source_family_label":"Source-backed biomedical text embedding pipeline","transformations_and_filters":"Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/embeddings/tissue_text_sbiobert_snli_multinli_stsb.parquet","catalog_page":"docs/parquet-catalog/datasets/embedding__tissue_text_sbiobert_snli_multinli_stsb.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"embedding_key","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"source_feature_table","nullable":true},{"dtype":"string","name":"source_feature_key","nullable":true},{"dtype":"string","name":"source_feature_hash","nullable":true},{"dtype":"string","name":"modality","nullable":true},{"dtype":"string","name":"embedding_model","nullable":true},{"dtype":"string","name":"embedding_version","nullable":true},{"dtype":"int32","name":"embedding_dim","nullable":false},{"dtype":"string","name":"embedding_dtype","nullable":true},{"dtype":"string","name":"embedding_format","nullable":false},{"dtype":"fixed_size_list<element: float>[768]","name":"embedding","nullable":false},{"dtype":"string","name":"pooling","nullable":true},{"dtype":"string","name":"normalization","nullable":true},{"dtype":"string","name":"preprocessing","nullable":true},{"dtype":"int64","name":"input_length","nullable":true},{"dtype":"int32","name":"window_count","nullable":false},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"source_feature_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["embedding_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["retained native input","verified exact rebuild command"],"layer":"embedding","links":["docs/parquet-catalog/datasets/embedding__tissue_text_sbiobert_snli_multinli_stsb.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_real_embeddings.py"],"mappings_and_joins":"Join exact canonical node IDs to source-feature keys and hashes; preserve model, pooling, normalization and coverage metadata.","meaning":"Accepted learned vector table for canonical `tissue` nodes.","migration_receipt":{"action":"copied","destination_crc32c":"9u0yMg==","destination_generation":"1785155499285276","source":"kg/v2/features/embeddings/text/tissue/sbiobert_snli_multinli_stsb/release_20260715_v2__src_b0cc26307c23/part-00000.parquet","source_generation":"1784460820243942","verified":true},"name":"tissue_text_sbiobert_snli_multinli_stsb","native_inputs":[],"native_source":[],"non_meaning":"Vector similarity is not functional equivalence, causality, or therapeutic evidence.","pipeline_family":"text_embeddings","problems_and_decisions":"The accepted text-vector objects and migration receipts survive, but a single verified exact argv with pinned model revision and all source-feature checksums is not tracked for every leaf.","producer":"manage_db/build_real_embeddings.py","producer_builder":"manage_db/build_real_embeddings.py","provenance_gaps":["retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":37627203,"crc32c_base64":"9u0yMg==","generation":"1785155499285276","md5_base64":"iHP6ce39m5GL7JDOz4bAUg==","row_groups":3,"rows":11942,"schema_hash":"39a4c988b787cc24fe86497333a87f2a3151ec8d55b0932ba153c9009aa082ab","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not fabricate vectors for missing source payloads or treat similarity as causality/equivalence; learned fallback stays model-side.","rebuild_command_evidenced":false,"release":"Accepted immutable S-BioBERT text embedding candidate; exact source revision is row-level and in preserved release evidence where available","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/text_embeddings.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"text_embeddings","source_family_label":"Source-backed biomedical text embedding pipeline","transformations_and_filters":"Encode source-backed textual summaries with the recorded S-BioBERT model, pooling and normalization policy; retain deterministic feature lineage."}]''')

def require(condition, message):
    if not condition:
        raise RuntimeError(message)

for RECORD in RECORDS:
    require(RECORD["canonical_uri"] == "gs://jouvencekb/main/" + ("embeddings" if RECORD["layer"] == "embedding" else RECORD["layer"]) + "/" + RECORD["name"] + ".parquet", "canonical URI/identity mismatch")
    require(RECORD["replay_level"] in ['documented-not-replayed', 'fully-replayable', 'historical-builder-only', 'provenance-gap'], "unsupported replay level")
    require(RECORD["qc"]["rows"] >= 0, "negative expected row count")
    require(len(RECORD["qc"]["schema_hash"]) == 64, "invalid schema hash")
    require(RECORD["migration_receipt"]["verified"] is True, "migration receipt is not verified")
    require(bool(RECORD["fields"]), "empty expected schema")
summary = {
    "pipeline_family": RECORDS[0]["pipeline_family"],
    "output_count": len(RECORDS),
    "identities": [record["layer"] + "__" + record["name"] for record in RECORDS],
}
summary

# %% [markdown]
# ## Optional bounded live canonical footer check
#
# This cell is skipped unless the caller explicitly opts in.

# %%
import os

if os.environ.get("JOUVENCE_LIVE_GCS") != "1":
    live_result = {"status": "SKIPPED", "reason": "set JOUVENCE_LIVE_GCS=1 and caller-owned JOUVENCE_BILLING_PROJECT"}
else:
    import gcsfs
    import pyarrow.parquet as pq

    billing_project = os.environ.get("JOUVENCE_BILLING_PROJECT")
    if not billing_project:
        raise RuntimeError("JOUVENCE_BILLING_PROJECT is required for requester-pays live verification")
    fs = gcsfs.GCSFileSystem(project=billing_project, requester_pays=billing_project, version_aware=True)
    if not fs.version_aware:
        raise RuntimeError("version-aware GCS reads are required")
    selected_id = os.environ.get("JOUVENCE_OUTPUT_ID", RECORDS[0]["layer"] + "__" + RECORDS[0]["name"])
    selected = [record for record in RECORDS if record["layer"] + "__" + record["name"] == selected_id]
    if len(selected) != 1:
        raise RuntimeError("JOUVENCE_OUTPUT_ID must select exactly one output owned by this notebook")
    RECORD = selected[0]
    object_path = RECORD["canonical_uri"].removeprefix("gs://")
    if "#" in object_path:
        raise RuntimeError("canonical object key must not already contain a generation suffix")
    expected_generation = RECORD["qc"]["generation"]
    pinned_path = object_path + "#" + expected_generation
    info = fs.info(pinned_path)
    if str(info.get("generation", "")) != expected_generation:
        raise RuntimeError("generation-qualified object resolved a different generation")
    with fs.open(pinned_path, "rb") as handle:
        parquet = pq.ParquetFile(handle)
        live_fields = [
            {"name": field.name, "dtype": str(field.type), "nullable": bool(field.nullable)}
            for field in parquet.schema_arrow
        ]
        live_rows = parquet.metadata.num_rows
        live_row_groups = parquet.metadata.num_row_groups
    if live_rows != RECORD["qc"]["rows"]:
        raise RuntimeError("live footer row count differs from the frozen registry")
    if live_row_groups != RECORD["qc"]["row_groups"]:
        raise RuntimeError("live footer row-group count differs from the frozen registry")
    if live_fields != RECORD["fields"]:
        raise RuntimeError("live footer schema differs from the frozen registry")
    live_result = {"status": "PASS", "generation": str(info["generation"]), "rows": live_rows, "row_groups": live_row_groups}
live_result
