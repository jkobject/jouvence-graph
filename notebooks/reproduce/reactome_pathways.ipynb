# %% [markdown]
# # Reproduce Reactome and Gene Ontology pathway lineage
#
# Generated by reproduce/generate_parquet_reproduction_notebooks.py; do not edit.
#
# ## Objective and meaning
#
# Document the coherent `reactome` acquisition/build/mapping pipeline and safely verify all 8 current canonical Parquets assigned to it.
#
# Grouping justification: these outputs share a defensible source/transformation family context. Exact producer and command evidence remains per output and may be absent; layer alone is not used as a grouping rule, and differences remain explicit in each output contract.
#
# ## Canonical outputs owned by this notebook
#
# | Layer | Canonical output | Rows | Replay level | Catalog |
# |---|---|---:|---|---|
# | `edges` | `disease_involves_pathway` | 2,296 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__disease_involves_pathway.md) |
# | `edges` | `molecule_in_pathway` | 1,680 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__molecule_in_pathway.md) |
# | `edges` | `pathway_child_of_pathway` | 147,680 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__pathway_child_of_pathway.md) |
# | `edges` | `pathway_contains_gene` | 630,932 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__pathway_contains_gene.md) |
# | `evidence` | `disease_involves_pathway` | 2,296 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__disease_involves_pathway.md) |
# | `evidence` | `pathway_contains_gene` | 630,932 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__pathway_contains_gene.md) |
# | `features` | `pathway_textual_summary` | 37,492 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/features__pathway_textual_summary.md) |
# | `nodes` | `pathway` | 48,575 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/nodes__pathway.md) |

# %% [markdown]
# ## Native inputs, release, acquisition and environment
#
# Shared acquisition context is stated once; release and retained input differences are restated under every owned output.
#
# ## Expected schema and identifiers
#
# Each output section carries its exact catalog schema, row count, object generation and checksum.
#
# ## Keys, mappings and joins
#
# Shared family mappings are applied only where stated; every output preserves its own key contract.
#
# ## Cleaning, normalization, transformations and filters
#
# Transformation and filter differences are explicit per output below.
#
# ## Deduplication and assertion/evidence semantics
#
# Canonical edges are deduplicated assertions; source-specific multiplicity and context remain evidence/features where applicable.
#
# ## Quarantines, exclusions and missing data
#
# Every output contract states its known exclusions and unresolved provenance.
#
# ## Problems encountered and decisions
#
# Known decisions and alternatives are reported conservatively; migration identity is not treated as proof of biological replayability.
#
# ## Producer / builder
#
# The per-output contracts name an evidenced tracked producer or state that it is unavailable.
#
# ## Full worker rebuild command (inert text; never executed by this notebook)
#
# Any command below is documentation only and remains approved-worker, staging and review gated.
#
# ## Migration receipt
#
# Every output includes its generation-matched, verified migration receipt.
#
# ## QC, bounded replay and verification
#
# The first code cell validates all embedded output contracts offline. The opt-in cell verifies one selected GCS object metadata record and Parquet footer, chosen with `JOUVENCE_OUTPUT_ID`; it never scans all family outputs.
#
# ## Reproducibility limits
#
# Replay levels remain per output. No family-level label upgrades weaker members.
#
# ## Linked code, tests, reports and historical notebooks
#
# Links are listed in each output contract.

# %% [markdown]
# ## Per-output reproduction contracts
#
# ### Output `edges__disease_involves_pathway`
#
# - Canonical URI: `gs://jouvencekb/main/edges/disease_involves_pathway.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__disease_involves_pathway.md`](../../docs/parquet-catalog/datasets/edges__disease_involves_pathway.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Pathway→disease direction for causal/directed pathway involvement; source/evidence rows preserve enrichment/provenance.
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs
#
# - `gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **2,296**; bytes: **69,329**; row groups: **1**; schema hash (`arrow-fields-v1`): `0dc6911b08f5dc26f659c28f94ab8db265f64a672ff7d2255e0dd9a74eac9c17`; generation: `1785155482593137`; CRC32C: `u1qK6A==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
# | `score` | `double` | `true` |
# | `pathway_name` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.
#
# **Cleaning, normalization, transformations and filters.** Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.
#
# **Problems encountered and decisions.** A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/disease_involves_pathway.parquet`
# - Destination generation: `1785155482593137`
# - Destination CRC32C: `u1qK6A==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__disease_involves_pathway.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/27_source_native_protein_context_reproduction.ipynb`
# - `manage_db/build_reactome_pathway_protein_membership.py`
#
#
# ### Output `edges__molecule_in_pathway`
#
# - Canonical URI: `gs://jouvencekb/main/edges/molecule_in_pathway.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__molecule_in_pathway.md`](../../docs/parquet-catalog/datasets/edges__molecule_in_pathway.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Metabolic pathway
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs
#
# - `gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **1,680**; bytes: **12,794**; row groups: **1**; schema hash (`arrow-fields-v1`): `078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1`; generation: `1785155484516413`; CRC32C: `duv1Tg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.
#
# **Cleaning, normalization, transformations and filters.** Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.
#
# **Problems encountered and decisions.** A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/molecule_in_pathway.parquet`
# - Destination generation: `1785155484516413`
# - Destination CRC32C: `duv1Tg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__molecule_in_pathway.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/27_source_native_protein_context_reproduction.ipynb`
# - `manage_db/build_reactome_pathway_protein_membership.py`
#
#
# ### Output `edges__pathway_child_of_pathway`
#
# - Canonical URI: `gs://jouvencekb/main/edges/pathway_child_of_pathway.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__pathway_child_of_pathway.md`](../../docs/parquet-catalog/datasets/edges__pathway_child_of_pathway.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Reactome hierarchy
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs
#
# - `gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **147,680**; bytes: **941,024**; row groups: **1**; schema hash (`arrow-fields-v1`): `078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1`; generation: `1785155488901473`; CRC32C: `Bxu68w==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.
#
# **Cleaning, normalization, transformations and filters.** Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.
#
# **Problems encountered and decisions.** A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/pathway_child_of_pathway.parquet`
# - Destination generation: `1785155488901473`
# - Destination CRC32C: `Bxu68w==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__pathway_child_of_pathway.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/27_source_native_protein_context_reproduction.ipynb`
# - `manage_db/build_reactome_pathway_protein_membership.py`
#
#
# ### Output `edges__pathway_contains_gene`
#
# - Canonical URI: `gs://jouvencekb/main/edges/pathway_contains_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__pathway_contains_gene.md`](../../docs/parquet-catalog/datasets/edges__pathway_contains_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Reactome / GO
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs
#
# - `gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **630,932**; bytes: **5,891,672**; row groups: **7**; schema hash (`arrow-fields-v1`): `6dd52ed43ba8b142cd26bff6e1c152be419f4f055308cf6dfc1b3bc1faf0b000`; generation: `1785155489096958`; CRC32C: `Ufj+8Q==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `display_relation` | `string` | `true` |
# | `source` | `string` | `true` |
# | `credibility` | `int64` | `true` |
# | `go_evidence` | `string` | `true` |
# | `go_aspect` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.
#
# **Cleaning, normalization, transformations and filters.** Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.
#
# **Problems encountered and decisions.** A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/pathway_contains_gene.parquet`
# - Destination generation: `1785155489096958`
# - Destination CRC32C: `Ufj+8Q==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__pathway_contains_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/27_source_native_protein_context_reproduction.ipynb`
# - `manage_db/build_reactome_pathway_protein_membership.py`
#
#
# ### Output `evidence__disease_involves_pathway`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/disease_involves_pathway.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__disease_involves_pathway.md`](../../docs/parquet-catalog/datasets/evidence__disease_involves_pathway.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `disease_involves_pathway` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs
#
# - `gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **2,296**; bytes: **76,231**; row groups: **1**; schema hash (`arrow-fields-v1`): `0beeb15b80896c37055bcab526fc11d4376ed2762facadbc59b012f280d8b03c`; generation: `1785155491610705`; CRC32C: `yB9g8w==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `evidence_type` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `source_dataset` | `large_string` | `true` |
# | `source_record_id` | `large_string` | `true` |
# | `paper_id` | `large_string` | `true` |
# | `dataset_id` | `large_string` | `true` |
# | `study_id` | `large_string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `large_string` | `true` |
# | `confidence_interval` | `large_string` | `true` |
# | `predicate` | `large_string` | `true` |
# | `text_span` | `large_string` | `true` |
# | `section` | `large_string` | `true` |
# | `extraction_method` | `large_string` | `true` |
# | `license` | `large_string` | `true` |
# | `release` | `large_string` | `true` |
# | `created_at` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.
#
# **Cleaning, normalization, transformations and filters.** Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.
#
# **Problems encountered and decisions.** A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/disease_involves_pathway.parquet`
# - Destination generation: `1785155491610705`
# - Destination CRC32C: `yB9g8w==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__disease_involves_pathway.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/27_source_native_protein_context_reproduction.ipynb`
# - `manage_db/build_reactome_pathway_protein_membership.py`
#
#
# ### Output `evidence__pathway_contains_gene`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/pathway_contains_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__pathway_contains_gene.md`](../../docs/parquet-catalog/datasets/evidence__pathway_contains_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `pathway_contains_gene` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs
#
# - `gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **630,932**; bytes: **30,877,933**; row groups: **2**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155494393947`; CRC32C: `RioiMw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.
#
# **Cleaning, normalization, transformations and filters.** Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.
#
# **Problems encountered and decisions.** A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/pathway_contains_gene.parquet`
# - Destination generation: `1785155494393947`
# - Destination CRC32C: `RioiMw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__pathway_contains_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/27_source_native_protein_context_reproduction.ipynb`
# - `manage_db/build_reactome_pathway_protein_membership.py`
#
#
# ### Output `features__pathway_textual_summary`
#
# - Canonical URI: `gs://jouvencekb/main/features/pathway_textual_summary.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__pathway_textual_summary.md`](../../docs/parquet-catalog/datasets/features__pathway_textual_summary.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-backed text payloads for `pathway` nodes, suitable for retrieval or text feature construction.
# - Does not mean: Text is not a curated label, causal claim, or complete coverage of the node table.
#
# **Native inputs and release.** Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs
#
# - `gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **37,492**; bytes: **3,578,312**; row groups: **1**; schema hash (`arrow-fields-v1`): `072e4e1123aae68dcd32db4e101aaaa5fe72ae3dbba51a17c9484a660724221b`; generation: `1785155495980714`; CRC32C: `X+qWEw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `feature_key` | `string` | `true` |
# | `feature_table` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `summary_kind` | `string` | `true` |
# | `summary_text` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `feature_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.
#
# **Cleaning, normalization, transformations and filters.** Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.
#
# **Problems encountered and decisions.** A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/pathway_textual_summary.parquet`
# - Destination generation: `1785155495980714`
# - Destination CRC32C: `X+qWEw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__pathway_textual_summary.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/27_source_native_protein_context_reproduction.ipynb`
# - `manage_db/build_reactome_pathway_protein_membership.py`
#
#
# ### Output `nodes__pathway`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/pathway.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__pathway.md`](../../docs/parquet-catalog/datasets/nodes__pathway.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Canonical pathway registry keyed in the Reactome namespace (example `R-HSA-5633007`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs
#
# - `gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **48,575**; bytes: **1,467,941**; row groups: **1**; schema hash (`arrow-fields-v1`): `8d5f2057104dbdcc69883d7beb768e400f56f89def8f6cf78f6add38fa2cc404`; generation: `1785155479494611`; CRC32C: `KegEWQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `legacy_type` | `large_string` | `true` |
# | `legacy_id` | `large_string` | `true` |
# | `legacy_index` | `double` | `true` |
# | `source` | `large_string` | `true` |
# | `ncbi_gene_id` | `large_string` | `true` |
# | `hgnc_id` | `double` | `true` |
# | `uniprot_id` | `double` | `true` |
# | `gene_name` | `large_string` | `true` |
# | `drugbank_id` | `large_string` | `true` |
# | `pubchem_cid` | `double` | `true` |
# | `cas_rn` | `double` | `true` |
# | `inchikey` | `double` | `true` |
# | `smiles` | `double` | `true` |
# | `mondo_id` | `large_string` | `true` |
# | `efo_id` | `double` | `true` |
# | `mp_id` | `double` | `true` |
# | `mesh_id` | `double` | `true` |
# | `hp_id` | `large_string` | `true` |
# | `omim_id` | `double` | `true` |
# | `doid_id` | `double` | `true` |
# | `icd10_code` | `double` | `true` |
# | `go_id` | `large_string` | `true` |
# | `kegg_id` | `large_string` | `true` |
# | `bto_id` | `double` | `true` |
# | `fma_id` | `double` | `true` |
# | `reactome_id` | `large_string` | `true` |
# | `name` | `large_string` | `true` |
# | `aspect` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.
#
# **Cleaning, normalization, transformations and filters.** Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.
#
# **Problems encountered and decisions.** A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/pathway.parquet`
# - Destination generation: `1785155479494611`
# - Destination CRC32C: `KegEWQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__pathway.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/27_source_native_protein_context_reproduction.ipynb`
# - `manage_db/build_reactome_pathway_protein_membership.py`

# %% [markdown]
# ## Offline bounded contract check
#
# This cell uses only the embedded frozen lineage record.

# %%
import hashlib
import json

RECORDS = json.loads(r'''[{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/disease_involves_pathway.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__disease_involves_pathway.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"double","name":"score","nullable":true},{"dtype":"large_string","name":"pathway_name","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__disease_involves_pathway.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/27_source_native_protein_context_reproduction.ipynb","manage_db/build_reactome_pathway_protein_membership.py"],"mappings_and_joins":"Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.","meaning":"Pathway→disease direction for causal/directed pathway involvement; source/evidence rows preserve enrichment/provenance.","migration_receipt":{"action":"copied","destination_crc32c":"u1qK6A==","destination_generation":"1785155482593137","source":"kg/v2/edges/disease_involves_pathway.parquet","source_generation":"1781862038597418","verified":true},"name":"disease_involves_pathway","native_inputs":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"native_source":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"reactome","problems_and_decisions":"A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":69329,"crc32c_base64":"u1qK6A==","generation":"1785155482593137","md5_base64":"hJGj23LA425r+jDG+BUZxg==","row_groups":1,"rows":2296,"schema_hash":"0dc6911b08f5dc26f659c28f94ab8db265f64a672ff7d2255e0dd9a74eac9c17","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.","rebuild_command_evidenced":false,"release":"Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/reactome_pathways.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"reactome","source_family_label":"Reactome and Gene Ontology pathway lineage","transformations_and_filters":"Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/molecule_in_pathway.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__molecule_in_pathway.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__molecule_in_pathway.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/27_source_native_protein_context_reproduction.ipynb","manage_db/build_reactome_pathway_protein_membership.py"],"mappings_and_joins":"Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.","meaning":"Metabolic pathway","migration_receipt":{"action":"copied","destination_crc32c":"duv1Tg==","destination_generation":"1785155484516413","source":"kg/v2/edges/molecule_in_pathway.parquet","source_generation":"1780837798218233","verified":true},"name":"molecule_in_pathway","native_inputs":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"native_source":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"reactome","problems_and_decisions":"A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":12794,"crc32c_base64":"duv1Tg==","generation":"1785155484516413","md5_base64":"uQkNOVs0jSlYz0EPXKt/wA==","row_groups":1,"rows":1680,"schema_hash":"078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.","rebuild_command_evidenced":false,"release":"Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/reactome_pathways.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"reactome","source_family_label":"Reactome and Gene Ontology pathway lineage","transformations_and_filters":"Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/pathway_child_of_pathway.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__pathway_child_of_pathway.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__pathway_child_of_pathway.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/27_source_native_protein_context_reproduction.ipynb","manage_db/build_reactome_pathway_protein_membership.py"],"mappings_and_joins":"Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.","meaning":"Reactome hierarchy","migration_receipt":{"action":"copied","destination_crc32c":"Bxu68w==","destination_generation":"1785155488901473","source":"kg/v2/edges/pathway_child_of_pathway.parquet","source_generation":"1780837803707493","verified":true},"name":"pathway_child_of_pathway","native_inputs":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"native_source":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"reactome","problems_and_decisions":"A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":941024,"crc32c_base64":"Bxu68w==","generation":"1785155488901473","md5_base64":"wo2zgKvosDY7Z7xpf3b7oA==","row_groups":1,"rows":147680,"schema_hash":"078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.","rebuild_command_evidenced":false,"release":"Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/reactome_pathways.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"reactome","source_family_label":"Reactome and Gene Ontology pathway lineage","transformations_and_filters":"Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/pathway_contains_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__pathway_contains_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"display_relation","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"string","name":"go_evidence","nullable":true},{"dtype":"string","name":"go_aspect","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__pathway_contains_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/27_source_native_protein_context_reproduction.ipynb","manage_db/build_reactome_pathway_protein_membership.py"],"mappings_and_joins":"Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.","meaning":"Reactome / GO","migration_receipt":{"action":"copied","destination_crc32c":"Ufj+8Q==","destination_generation":"1785155489096958","source":"kg/v2/edges/pathway_contains_gene.parquet","source_generation":"1781796931756900","verified":true},"name":"pathway_contains_gene","native_inputs":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"native_source":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"reactome","problems_and_decisions":"A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":5891672,"crc32c_base64":"Ufj+8Q==","generation":"1785155489096958","md5_base64":"0u5RhQGC7+c3lsllp4AM3g==","row_groups":7,"rows":630932,"schema_hash":"6dd52ed43ba8b142cd26bff6e1c152be419f4f055308cf6dfc1b3bc1faf0b000","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.","rebuild_command_evidenced":false,"release":"Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/reactome_pathways.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"reactome","source_family_label":"Reactome and Gene Ontology pathway lineage","transformations_and_filters":"Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/disease_involves_pathway.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__disease_involves_pathway.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"edge_key","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"evidence_type","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"large_string","name":"source_dataset","nullable":true},{"dtype":"large_string","name":"source_record_id","nullable":true},{"dtype":"large_string","name":"paper_id","nullable":true},{"dtype":"large_string","name":"dataset_id","nullable":true},{"dtype":"large_string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"large_string","name":"direction","nullable":true},{"dtype":"large_string","name":"confidence_interval","nullable":true},{"dtype":"large_string","name":"predicate","nullable":true},{"dtype":"large_string","name":"text_span","nullable":true},{"dtype":"large_string","name":"section","nullable":true},{"dtype":"large_string","name":"extraction_method","nullable":true},{"dtype":"large_string","name":"license","nullable":true},{"dtype":"large_string","name":"release","nullable":true},{"dtype":"large_string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__disease_involves_pathway.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/27_source_native_protein_context_reproduction.ipynb","manage_db/build_reactome_pathway_protein_membership.py"],"mappings_and_joins":"Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.","meaning":"Source-level support records for the canonical `disease_involves_pathway` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"yB9g8w==","destination_generation":"1785155491610705","source":"kg/v2/evidence/disease_involves_pathway.parquet","source_generation":"1781862039220261","verified":true},"name":"disease_involves_pathway","native_inputs":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"native_source":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"reactome","problems_and_decisions":"A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":76231,"crc32c_base64":"yB9g8w==","generation":"1785155491610705","md5_base64":"P5lIuGTQP0nATSEE17pUHA==","row_groups":1,"rows":2296,"schema_hash":"0beeb15b80896c37055bcab526fc11d4376ed2762facadbc59b012f280d8b03c","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.","rebuild_command_evidenced":false,"release":"Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/reactome_pathways.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"reactome","source_family_label":"Reactome and Gene Ontology pathway lineage","transformations_and_filters":"Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/pathway_contains_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__pathway_contains_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__pathway_contains_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/27_source_native_protein_context_reproduction.ipynb","manage_db/build_reactome_pathway_protein_membership.py"],"mappings_and_joins":"Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.","meaning":"Source-level support records for the canonical `pathway_contains_gene` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"RioiMw==","destination_generation":"1785155494393947","source":"kg/v2/evidence/pathway_contains_gene.parquet","source_generation":"1782079493564656","verified":true},"name":"pathway_contains_gene","native_inputs":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"native_source":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"reactome","problems_and_decisions":"A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":30877933,"crc32c_base64":"RioiMw==","generation":"1785155494393947","md5_base64":"ylg+0O1vG5F0vlCpZUUWvQ==","row_groups":2,"rows":630932,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.","rebuild_command_evidenced":false,"release":"Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/reactome_pathways.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"reactome","source_family_label":"Reactome and Gene Ontology pathway lineage","transformations_and_filters":"Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/pathway_textual_summary.parquet","catalog_page":"docs/parquet-catalog/datasets/features__pathway_textual_summary.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"feature_key","nullable":true},{"dtype":"string","name":"feature_table","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"summary_kind","nullable":true},{"dtype":"string","name":"summary_text","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["feature_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"features","links":["docs/parquet-catalog/datasets/features__pathway_textual_summary.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/27_source_native_protein_context_reproduction.ipynb","manage_db/build_reactome_pathway_protein_membership.py"],"mappings_and_joins":"Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.","meaning":"Source-backed text payloads for `pathway` nodes, suitable for retrieval or text feature construction.","migration_receipt":{"action":"copied","destination_crc32c":"X+qWEw==","destination_generation":"1785155495980714","source":"kg/v2/features/pathway_textual_summary.parquet","source_generation":"1782169817298055","verified":true},"name":"pathway_textual_summary","native_inputs":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"native_source":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"non_meaning":"Text is not a curated label, causal claim, or complete coverage of the node table.","pipeline_family":"reactome","problems_and_decisions":"A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":3578312,"crc32c_base64":"X+qWEw==","generation":"1785155495980714","md5_base64":"c1uy6AykMCvF8LQQ2u60kg==","row_groups":1,"rows":37492,"schema_hash":"072e4e1123aae68dcd32db4e101aaaa5fe72ae3dbba51a17c9484a660724221b","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.","rebuild_command_evidenced":false,"release":"Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/reactome_pathways.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"reactome","source_family_label":"Reactome and Gene Ontology pathway lineage","transformations_and_filters":"Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/pathway.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__pathway.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"large_string","name":"legacy_type","nullable":true},{"dtype":"large_string","name":"legacy_id","nullable":true},{"dtype":"double","name":"legacy_index","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"large_string","name":"ncbi_gene_id","nullable":true},{"dtype":"double","name":"hgnc_id","nullable":true},{"dtype":"double","name":"uniprot_id","nullable":true},{"dtype":"large_string","name":"gene_name","nullable":true},{"dtype":"large_string","name":"drugbank_id","nullable":true},{"dtype":"double","name":"pubchem_cid","nullable":true},{"dtype":"double","name":"cas_rn","nullable":true},{"dtype":"double","name":"inchikey","nullable":true},{"dtype":"double","name":"smiles","nullable":true},{"dtype":"large_string","name":"mondo_id","nullable":true},{"dtype":"double","name":"efo_id","nullable":true},{"dtype":"double","name":"mp_id","nullable":true},{"dtype":"double","name":"mesh_id","nullable":true},{"dtype":"large_string","name":"hp_id","nullable":true},{"dtype":"double","name":"omim_id","nullable":true},{"dtype":"double","name":"doid_id","nullable":true},{"dtype":"double","name":"icd10_code","nullable":true},{"dtype":"large_string","name":"go_id","nullable":true},{"dtype":"large_string","name":"kegg_id","nullable":true},{"dtype":"double","name":"bto_id","nullable":true},{"dtype":"double","name":"fma_id","nullable":true},{"dtype":"large_string","name":"reactome_id","nullable":true},{"dtype":"large_string","name":"name","nullable":true},{"dtype":"large_string","name":"aspect","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__pathway.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/27_source_native_protein_context_reproduction.ipynb","manage_db/build_reactome_pathway_protein_membership.py"],"mappings_and_joins":"Normalize R-HSA pathway IDs and exact gene/protein endpoints; preserve source database and hierarchy context.","meaning":"Canonical pathway registry keyed in the Reactome namespace (example `R-HSA-5633007`).","migration_receipt":{"action":"copied","destination_crc32c":"KegEWQ==","destination_generation":"1785155479494611","source":"kg/v2/nodes/pathway.parquet","source_generation":"1781015112606874","verified":true},"name":"pathway","native_inputs":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"native_source":["gs://jouvencekb/raw/reactome_UniProt2Reactome_All_Levels_20260323.txt"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"reactome","problems_and_decisions":"A Reactome protein-membership source is retained, but canonical gene/pathway tables combine historical Reactome/GO lanes whose exact accepted argv is incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":1467941,"crc32c_base64":"KegEWQ==","generation":"1785155479494611","md5_base64":"ncVw6NEk1L0fUKWsLT6MHQ==","row_groups":1,"rows":48575,"schema_hash":"8d5f2057104dbdcc69883d7beb768e400f56f89def8f6cf78f6add38fa2cc404","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-human, unmapped or ambiguous endpoints; do not project protein-native memberships into gene relations without an explicit policy.","rebuild_command_evidenced":false,"release":"Reactome snapshot 2026-03-23 plus Open Targets 26.03 pathway inputs","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/reactome_pathways.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"reactome","source_family_label":"Reactome and Gene Ontology pathway lineage","transformations_and_filters":"Parse hierarchy and membership, deduplicate assertions and retain source-specific support separately."}]''')

def require(condition, message):
    if not condition:
        raise RuntimeError(message)

for RECORD in RECORDS:
    require(RECORD["canonical_uri"] == "gs://jouvencekb/main/" + ("embeddings" if RECORD["layer"] == "embedding" else RECORD["layer"]) + "/" + RECORD["name"] + ".parquet", "canonical URI/identity mismatch")
    require(RECORD["replay_level"] in ['documented-not-replayed', 'fully-replayable', 'historical-builder-only', 'provenance-gap'], "unsupported replay level")
    require(RECORD["qc"]["rows"] >= 0, "negative expected row count")
    require(len(RECORD["qc"]["schema_hash"]) == 64, "invalid schema hash")
    require(RECORD["migration_receipt"]["verified"] is True, "migration receipt is not verified")
    require(bool(RECORD["fields"]), "empty expected schema")
summary = {
    "pipeline_family": RECORDS[0]["pipeline_family"],
    "output_count": len(RECORDS),
    "identities": [record["layer"] + "__" + record["name"] for record in RECORDS],
}
summary

# %% [markdown]
# ## Optional bounded live canonical footer check
#
# This cell is skipped unless the caller explicitly opts in.

# %%
import os

if os.environ.get("JOUVENCE_LIVE_GCS") != "1":
    live_result = {"status": "SKIPPED", "reason": "set JOUVENCE_LIVE_GCS=1 and caller-owned JOUVENCE_BILLING_PROJECT"}
else:
    import gcsfs
    import pyarrow.parquet as pq

    billing_project = os.environ.get("JOUVENCE_BILLING_PROJECT")
    if not billing_project:
        raise RuntimeError("JOUVENCE_BILLING_PROJECT is required for requester-pays live verification")
    fs = gcsfs.GCSFileSystem(project=billing_project, requester_pays=billing_project, version_aware=True)
    if not fs.version_aware:
        raise RuntimeError("version-aware GCS reads are required")
    selected_id = os.environ.get("JOUVENCE_OUTPUT_ID", RECORDS[0]["layer"] + "__" + RECORDS[0]["name"])
    selected = [record for record in RECORDS if record["layer"] + "__" + record["name"] == selected_id]
    if len(selected) != 1:
        raise RuntimeError("JOUVENCE_OUTPUT_ID must select exactly one output owned by this notebook")
    RECORD = selected[0]
    object_path = RECORD["canonical_uri"].removeprefix("gs://")
    if "#" in object_path:
        raise RuntimeError("canonical object key must not already contain a generation suffix")
    expected_generation = RECORD["qc"]["generation"]
    pinned_path = object_path + "#" + expected_generation
    info = fs.info(pinned_path)
    if str(info.get("generation", "")) != expected_generation:
        raise RuntimeError("generation-qualified object resolved a different generation")
    with fs.open(pinned_path, "rb") as handle:
        parquet = pq.ParquetFile(handle)
        live_fields = [
            {"name": field.name, "dtype": str(field.type), "nullable": bool(field.nullable)}
            for field in parquet.schema_arrow
        ]
        live_rows = parquet.metadata.num_rows
        live_row_groups = parquet.metadata.num_row_groups
    if live_rows != RECORD["qc"]["rows"]:
        raise RuntimeError("live footer row count differs from the frozen registry")
    if live_row_groups != RECORD["qc"]["row_groups"]:
        raise RuntimeError("live footer row-group count differs from the frozen registry")
    if live_fields != RECORD["fields"]:
        raise RuntimeError("live footer schema differs from the frozen registry")
    live_result = {"status": "PASS", "generation": str(info["generation"]), "rows": live_rows, "row_groups": live_row_groups}
live_result
