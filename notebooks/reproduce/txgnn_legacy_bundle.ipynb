# %% [markdown]
# # Reproduce TxData/TxGNN legacy source bundle
#
# Generated by reproduce/generate_parquet_reproduction_notebooks.py; do not edit.
#
# ## Objective and meaning
#
# Document the coherent `txgnn_legacy` acquisition/build/mapping pipeline and safely verify all 18 current canonical Parquets assigned to it.
#
# Grouping justification: these outputs share a defensible source/transformation family context. Exact producer and command evidence remains per output and may be absent; layer alone is not used as a grouping rule, and differences remain explicit in each output contract.
#
# ## Canonical outputs owned by this notebook
#
# | Layer | Canonical output | Rows | Replay level | Catalog |
# |---|---|---:|---|---|
# | `edges` | `cell_type_expresses_gene` | 1,561,873 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__cell_type_expresses_gene.md) |
# | `edges` | `dataset_contains_tissue` | 27 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__dataset_contains_tissue.md) |
# | `edges` | `disease_subtype_of_disease` | 104,809 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__disease_subtype_of_disease.md) |
# | `edges` | `gene_ortholog_gene` | 161,675 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__gene_ortholog_gene.md) |
# | `edges` | `molecule_associated_phenotype` | 64,784 | `provenance-gap` | [catalog](../../docs/parquet-catalog/datasets/edges__molecule_associated_phenotype.md) |
# | `edges` | `molecule_contraindicates_disease` | 30,675 | `provenance-gap` | [catalog](../../docs/parquet-catalog/datasets/edges__molecule_contraindicates_disease.md) |
# | `edges` | `molecule_parent_of_molecule` | 4,140 | `provenance-gap` | [catalog](../../docs/parquet-catalog/datasets/edges__molecule_parent_of_molecule.md) |
# | `edges` | `molecule_synergizes_molecule` | 2,672,628 | `provenance-gap` | [catalog](../../docs/parquet-catalog/datasets/edges__molecule_synergizes_molecule.md) |
# | `edges` | `molecule_treats_disease` | 14,135 | `provenance-gap` | [catalog](../../docs/parquet-catalog/datasets/edges__molecule_treats_disease.md) |
# | `edges` | `tissue_expresses_gene` | 5,338,736 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__tissue_expresses_gene.md) |
# | `evidence` | `gene_ortholog_gene` | 161,675 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__gene_ortholog_gene.md) |
# | `evidence` | `molecule_treats_disease` | 8,285 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__molecule_treats_disease.md) |
# | `features` | `cell_type_textual_summary` | 3,135 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/features__cell_type_textual_summary.md) |
# | `features` | `disease_textual_summary` | 26,395 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/features__disease_textual_summary.md) |
# | `features` | `gene_textual_summary` | 212,029 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/features__gene_textual_summary.md) |
# | `features` | `molecule_textual_summary` | 22,230 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/features__molecule_textual_summary.md) |
# | `nodes` | `cell_type` | 3,513 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/nodes__cell_type.md) |
# | `nodes` | `dataset` | 1 | `provenance-gap` | [catalog](../../docs/parquet-catalog/datasets/nodes__dataset.md) |

# %% [markdown]
# ## Native inputs, release, acquisition and environment
#
# Shared acquisition context is stated once; release and retained input differences are restated under every owned output.
#
# ## Expected schema and identifiers
#
# Each output section carries its exact catalog schema, row count, object generation and checksum.
#
# ## Keys, mappings and joins
#
# Shared family mappings are applied only where stated; every output preserves its own key contract.
#
# ## Cleaning, normalization, transformations and filters
#
# Transformation and filter differences are explicit per output below.
#
# ## Deduplication and assertion/evidence semantics
#
# Canonical edges are deduplicated assertions; source-specific multiplicity and context remain evidence/features where applicable.
#
# ## Quarantines, exclusions and missing data
#
# Every output contract states its known exclusions and unresolved provenance.
#
# ## Problems encountered and decisions
#
# Known decisions and alternatives are reported conservatively; migration identity is not treated as proof of biological replayability.
#
# ## Producer / builder
#
# The per-output contracts name an evidenced tracked producer or state that it is unavailable.
#
# ## Full worker rebuild command (inert text; never executed by this notebook)
#
# Any command below is documentation only and remains approved-worker, staging and review gated.
#
# ## Migration receipt
#
# Every output includes its generation-matched, verified migration receipt.
#
# ## QC, bounded replay and verification
#
# The first code cell validates all embedded output contracts offline. The opt-in cell verifies one selected GCS object metadata record and Parquet footer, chosen with `JOUVENCE_OUTPUT_ID`; it never scans all family outputs.
#
# ## Reproducibility limits
#
# Replay levels remain per output. No family-level label upgrades weaker members.
#
# ## Linked code, tests, reports and historical notebooks
#
# Links are listed in each output contract.

# %% [markdown]
# ## Per-output reproduction contracts
#
# ### Output `edges__cell_type_expresses_gene`
#
# - Canonical URI: `gs://jouvencekb/main/edges/cell_type_expresses_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__cell_type_expresses_gene.md`](../../docs/parquet-catalog/datasets/edges__cell_type_expresses_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: scRNA-seq (CellxGene)
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **1,561,873**; bytes: **6,532,333**; row groups: **2**; schema hash (`arrow-fields-v1`): `55de19336a48d53e1108734aeb431d3ad8cc602391781c594cd9d0c89ecfa364`; generation: `1785155481432694`; CRC32C: `7dWZWg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
# | `tpm` | `double` | `true` |
# | `expression_level` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/cell_type_expresses_gene.parquet`
# - Destination generation: `1785155481432694`
# - Destination CRC32C: `7dWZWg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__cell_type_expresses_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `edges__dataset_contains_tissue`
#
# - Canonical URI: `gs://jouvencekb/main/edges/dataset_contains_tissue.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__dataset_contains_tissue.md`](../../docs/parquet-catalog/datasets/edges__dataset_contains_tissue.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Measured entity
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **27**; bytes: **5,447**; row groups: **1**; schema hash (`arrow-fields-v1`): `078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1`; generation: `1785155481793607`; CRC32C: `+VGYUg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/dataset_contains_tissue.parquet`
# - Destination generation: `1785155481793607`
# - Destination CRC32C: `+VGYUg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__dataset_contains_tissue.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `edges__disease_subtype_of_disease`
#
# - Canonical URI: `gs://jouvencekb/main/edges/disease_subtype_of_disease.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__disease_subtype_of_disease.md`](../../docs/parquet-catalog/datasets/edges__disease_subtype_of_disease.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: EFO / MONDO hierarchy
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **104,809**; bytes: **648,897**; row groups: **1**; schema hash (`arrow-fields-v1`): `078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1`; generation: `1785155483031395`; CRC32C: `Q63HnA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/disease_subtype_of_disease.parquet`
# - Destination generation: `1785155483031395`
# - Destination CRC32C: `Q63HnA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__disease_subtype_of_disease.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `edges__gene_ortholog_gene`
#
# - Canonical URI: `gs://jouvencekb/main/edges/gene_ortholog_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__gene_ortholog_gene.md`](../../docs/parquet-catalog/datasets/edges__gene_ortholog_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Cross-species orthology
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **161,675**; bytes: **3,076,768**; row groups: **1**; schema hash (`arrow-fields-v1`): `c4f6301b53d5fa75e4765f8795cab15d62a99122d40248b3f28e72c8a198e898`; generation: `1785155484030458`; CRC32C: `QRHIgA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
# | `homology_type` | `large_string` | `true` |
# | `species_id` | `large_string` | `true` |
# | `species_name` | `large_string` | `true` |
# | `is_high_confidence` | `bool` | `true` |
# | `query_percentage_identity` | `double` | `true` |
# | `target_percentage_identity` | `double` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/gene_ortholog_gene.parquet`
# - Destination generation: `1785155484030458`
# - Destination CRC32C: `QRHIgA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__gene_ortholog_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `edges__molecule_associated_phenotype`
#
# - Canonical URI: `gs://jouvencekb/main/edges/molecule_associated_phenotype.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__molecule_associated_phenotype.md`](../../docs/parquet-catalog/datasets/edges__molecule_associated_phenotype.md)
# - Replay level: **`provenance-gap`**
# - Meaning: Non-causal molecule-to-phenotype side-effect/rescue association; direction is molecule→phenotype
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **64,784**; bytes: **111,612**; row groups: **1**; schema hash (`arrow-fields-v1`): `7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2`; generation: `1785155484199958`; CRC32C: `pMESXg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `display_relation` | `string` | `true` |
# | `source` | `string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `exact accepted source-to-object lineage`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/molecule_associated_phenotype.parquet`
# - Destination generation: `1785155484199958`
# - Destination CRC32C: `pMESXg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__molecule_associated_phenotype.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `edges__molecule_contraindicates_disease`
#
# - Canonical URI: `gs://jouvencekb/main/edges/molecule_contraindicates_disease.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__molecule_contraindicates_disease.md`](../../docs/parquet-catalog/datasets/edges__molecule_contraindicates_disease.md)
# - Replay level: **`provenance-gap`**
# - Meaning: Contraindication
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **30,675**; bytes: **67,065**; row groups: **1**; schema hash (`arrow-fields-v1`): `078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1`; generation: `1785155484349742`; CRC32C: `4nlliA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `exact accepted source-to-object lineage`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/molecule_contraindicates_disease.parquet`
# - Destination generation: `1785155484349742`
# - Destination CRC32C: `4nlliA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__molecule_contraindicates_disease.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `edges__molecule_parent_of_molecule`
#
# - Canonical URI: `gs://jouvencekb/main/edges/molecule_parent_of_molecule.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__molecule_parent_of_molecule.md`](../../docs/parquet-catalog/datasets/edges__molecule_parent_of_molecule.md)
# - Replay level: **`provenance-gap`**
# - Meaning: Chemical/drug parent-child hierarchy relation.
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **4,140**; bytes: **19,797**; row groups: **1**; schema hash (`arrow-fields-v1`): `7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2`; generation: `1785155484679611`; CRC32C: `lBYRsQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `display_relation` | `string` | `true` |
# | `source` | `string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `exact accepted source-to-object lineage`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/molecule_parent_of_molecule.parquet`
# - Destination generation: `1785155484679611`
# - Destination CRC32C: `lBYRsQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__molecule_parent_of_molecule.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `edges__molecule_synergizes_molecule`
#
# - Canonical URI: `gs://jouvencekb/main/edges/molecule_synergizes_molecule.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__molecule_synergizes_molecule.md`](../../docs/parquet-catalog/datasets/edges__molecule_synergizes_molecule.md)
# - Replay level: **`provenance-gap`**
# - Meaning: Drug combination synergy or interaction-effect relation; not a physical molecular interaction.
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **2,672,628**; bytes: **4,284,625**; row groups: **22**; schema hash (`arrow-fields-v1`): `7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2`; generation: `1785155484817964`; CRC32C: `iQeHYQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `display_relation` | `string` | `true` |
# | `source` | `string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `exact accepted source-to-object lineage`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/molecule_synergizes_molecule.parquet`
# - Destination generation: `1785155484817964`
# - Destination CRC32C: `iQeHYQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__molecule_synergizes_molecule.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `edges__molecule_treats_disease`
#
# - Canonical URI: `gs://jouvencekb/main/edges/molecule_treats_disease.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__molecule_treats_disease.md`](../../docs/parquet-catalog/datasets/edges__molecule_treats_disease.md)
# - Replay level: **`provenance-gap`**
# - Meaning: Indication (clinical)
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **14,135**; bytes: **57,319**; row groups: **1**; schema hash (`arrow-fields-v1`): `078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1`; generation: `1785155486922602`; CRC32C: `5SqHVw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `exact accepted source-to-object lineage`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/molecule_treats_disease.parquet`
# - Destination generation: `1785155486922602`
# - Destination CRC32C: `5SqHVw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__molecule_treats_disease.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `edges__tissue_expresses_gene`
#
# - Canonical URI: `gs://jouvencekb/main/edges/tissue_expresses_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__tissue_expresses_gene.md`](../../docs/parquet-catalog/datasets/edges__tissue_expresses_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: GTEx / HPA bulk RNA
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **5,338,736**; bytes: **41,362,747**; row groups: **45**; schema hash (`arrow-fields-v1`): `145011ad67eba82a0e51e34b197b573edea387d056056d12af46675f8ae32b0f`; generation: `1785155489893065`; CRC32C: `H22BCQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `display_relation` | `string` | `true` |
# | `source` | `string` | `true` |
# | `credibility` | `int64` | `true` |
# | `tpm` | `double` | `true` |
# | `expression_level` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/tissue_expresses_gene.parquet`
# - Destination generation: `1785155489893065`
# - Destination CRC32C: `H22BCQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__tissue_expresses_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `evidence__gene_ortholog_gene`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/gene_ortholog_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__gene_ortholog_gene.md`](../../docs/parquet-catalog/datasets/evidence__gene_ortholog_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `gene_ortholog_gene` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **161,675**; bytes: **5,533,441**; row groups: **1**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155492452605`; CRC32C: `p2igJw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/gene_ortholog_gene.parquet`
# - Destination generation: `1785155492452605`
# - Destination CRC32C: `p2igJw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__gene_ortholog_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `evidence__molecule_treats_disease`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/molecule_treats_disease.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__molecule_treats_disease.md`](../../docs/parquet-catalog/datasets/evidence__molecule_treats_disease.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `molecule_treats_disease` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **8,285**; bytes: **891,126**; row groups: **2**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155492750134`; CRC32C: `dfr1NA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/molecule_treats_disease.parquet`
# - Destination generation: `1785155492750134`
# - Destination CRC32C: `dfr1NA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__molecule_treats_disease.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `features__cell_type_textual_summary`
#
# - Canonical URI: `gs://jouvencekb/main/features/cell_type_textual_summary.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__cell_type_textual_summary.md`](../../docs/parquet-catalog/datasets/features__cell_type_textual_summary.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-backed text payloads for `cell_type` nodes, suitable for retrieval or text feature construction.
# - Does not mean: Text is not a curated label, causal claim, or complete coverage of the node table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **3,135**; bytes: **352,433**; row groups: **1**; schema hash (`arrow-fields-v1`): `072e4e1123aae68dcd32db4e101aaaa5fe72ae3dbba51a17c9484a660724221b`; generation: `1785155495088519`; CRC32C: `HNEhIw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `feature_key` | `string` | `true` |
# | `feature_table` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `summary_kind` | `string` | `true` |
# | `summary_text` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `feature_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/cell_type_textual_summary.parquet`
# - Destination generation: `1785155495088519`
# - Destination CRC32C: `HNEhIw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__cell_type_textual_summary.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `features__disease_textual_summary`
#
# - Canonical URI: `gs://jouvencekb/main/features/disease_textual_summary.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__disease_textual_summary.md`](../../docs/parquet-catalog/datasets/features__disease_textual_summary.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-backed text payloads for `disease` nodes, suitable for retrieval or text feature construction.
# - Does not mean: Text is not a curated label, causal claim, or complete coverage of the node table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **26,395**; bytes: **2,964,350**; row groups: **1**; schema hash (`arrow-fields-v1`): `072e4e1123aae68dcd32db4e101aaaa5fe72ae3dbba51a17c9484a660724221b`; generation: `1785155495411230`; CRC32C: `uiqsnA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `feature_key` | `string` | `true` |
# | `feature_table` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `summary_kind` | `string` | `true` |
# | `summary_text` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `feature_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/disease_textual_summary.parquet`
# - Destination generation: `1785155495411230`
# - Destination CRC32C: `uiqsnA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__disease_textual_summary.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `features__gene_textual_summary`
#
# - Canonical URI: `gs://jouvencekb/main/features/gene_textual_summary.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__gene_textual_summary.md`](../../docs/parquet-catalog/datasets/features__gene_textual_summary.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-backed text payloads for `gene` nodes, suitable for retrieval or text feature construction.
# - Does not mean: Text is not a curated label, causal claim, or complete coverage of the node table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **212,029**; bytes: **7,588,830**; row groups: **1**; schema hash (`arrow-fields-v1`): `072e4e1123aae68dcd32db4e101aaaa5fe72ae3dbba51a17c9484a660724221b`; generation: `1785155495564485`; CRC32C: `RZuhQw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `feature_key` | `string` | `true` |
# | `feature_table` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `summary_kind` | `string` | `true` |
# | `summary_text` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `feature_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/gene_textual_summary.parquet`
# - Destination generation: `1785155495564485`
# - Destination CRC32C: `RZuhQw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__gene_textual_summary.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `features__molecule_textual_summary`
#
# - Canonical URI: `gs://jouvencekb/main/features/molecule_textual_summary.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__molecule_textual_summary.md`](../../docs/parquet-catalog/datasets/features__molecule_textual_summary.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-backed text payloads for `molecule` nodes, suitable for retrieval or text feature construction.
# - Does not mean: Text is not a curated label, causal claim, or complete coverage of the node table.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **22,230**; bytes: **730,115**; row groups: **1**; schema hash (`arrow-fields-v1`): `072e4e1123aae68dcd32db4e101aaaa5fe72ae3dbba51a17c9484a660724221b`; generation: `1785155495836531`; CRC32C: `InV3zA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `feature_key` | `string` | `true` |
# | `feature_table` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `summary_kind` | `string` | `true` |
# | `summary_text` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `feature_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/molecule_textual_summary.parquet`
# - Destination generation: `1785155495836531`
# - Destination CRC32C: `InV3zA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__molecule_textual_summary.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `nodes__cell_type`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/cell_type.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__cell_type.md`](../../docs/parquet-catalog/datasets/nodes__cell_type.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Canonical cell_type registry keyed in the CL namespace (example `CL:0000576`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **3,513**; bytes: **82,710**; row groups: **1**; schema hash (`arrow-fields-v1`): `e6cae8e01a9c7efa80a5b09329d848fe28a3dba2675cb9182250f48826b08034`; generation: `1785155477358732`; CRC32C: `yTb77A==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `name` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `uberon_id` | `large_string` | `true` |
# | `mesh_id` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/cell_type.parquet`
# - Destination generation: `1785155477358732`
# - Destination CRC32C: `yTb77A==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__cell_type.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`
#
#
# ### Output `nodes__dataset`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/dataset.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__dataset.md`](../../docs/parquet-catalog/datasets/nodes__dataset.md)
# - Replay level: **`provenance-gap`**
# - Meaning: Canonical dataset registry keyed in the DOI / UUID namespace (example `DOI:10.1038/s41586-023-06221-2`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable
#
# - `https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **1**; bytes: **2,579**; row groups: **1**; schema hash (`arrow-fields-v1`): `4e3d5500d9d5bf9b8b46ba66d78325daa50fcc7b104c15ad7117de4ac2c1dec5`; generation: `1785155477598313`; CRC32C: `j4ZN5w==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `name` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.
#
# **Problems encountered and decisions.** The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.
#
# Known gaps: `current builder`, `exact accepted source-to-object lineage`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/dataset.parquet`
# - Destination generation: `1785155477598313`
# - Destination CRC32C: `j4ZN5w==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__dataset.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/06_build_core_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/export_kg.py`

# %% [markdown]
# ## Offline bounded contract check
#
# This cell uses only the embedded frozen lineage record.

# %%
import hashlib
import json

RECORDS = json.loads(r'''[{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/cell_type_expresses_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__cell_type_expresses_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"double","name":"tpm","nullable":true},{"dtype":"int64","name":"expression_level","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__cell_type_expresses_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"scRNA-seq (CellxGene)","migration_receipt":{"action":"copied","destination_crc32c":"7dWZWg==","destination_generation":"1785155481432694","source":"kg/v2/edges/cell_type_expresses_gene.parquet","source_generation":"1781177661088086","verified":true},"name":"cell_type_expresses_gene","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":6532333,"crc32c_base64":"7dWZWg==","generation":"1785155481432694","md5_base64":"39oktc2xzF//JLMYYhisvA==","row_groups":2,"rows":1561873,"schema_hash":"55de19336a48d53e1108734aeb431d3ad8cc602391781c594cd9d0c89ecfa364","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/dataset_contains_tissue.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__dataset_contains_tissue.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__dataset_contains_tissue.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Measured entity","migration_receipt":{"action":"copied","destination_crc32c":"+VGYUg==","destination_generation":"1785155481793607","source":"kg/v2/edges/dataset_contains_tissue.parquet","source_generation":"1781481610287887","verified":true},"name":"dataset_contains_tissue","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":5447,"crc32c_base64":"+VGYUg==","generation":"1785155481793607","md5_base64":"s/1YO7aeuiep4Du47hpHhg==","row_groups":1,"rows":27,"schema_hash":"078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/disease_subtype_of_disease.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__disease_subtype_of_disease.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__disease_subtype_of_disease.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"EFO / MONDO hierarchy","migration_receipt":{"action":"copied","destination_crc32c":"Q63HnA==","destination_generation":"1785155483031395","source":"kg/v2/edges/disease_subtype_of_disease.parquet","source_generation":"1781177662823319","verified":true},"name":"disease_subtype_of_disease","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":648897,"crc32c_base64":"Q63HnA==","generation":"1785155483031395","md5_base64":"90RFFncsJZ9Wj5EiMzcwRg==","row_groups":1,"rows":104809,"schema_hash":"078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/gene_ortholog_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__gene_ortholog_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"large_string","name":"homology_type","nullable":true},{"dtype":"large_string","name":"species_id","nullable":true},{"dtype":"large_string","name":"species_name","nullable":true},{"dtype":"bool","name":"is_high_confidence","nullable":true},{"dtype":"double","name":"query_percentage_identity","nullable":true},{"dtype":"double","name":"target_percentage_identity","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__gene_ortholog_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Cross-species orthology","migration_receipt":{"action":"copied","destination_crc32c":"QRHIgA==","destination_generation":"1785155484030458","source":"kg/v2/edges/gene_ortholog_gene.parquet","source_generation":"1781617033917375","verified":true},"name":"gene_ortholog_gene","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":3076768,"crc32c_base64":"QRHIgA==","generation":"1785155484030458","md5_base64":"+z89LaFwp0oY3uTJgiy/TQ==","row_groups":1,"rows":161675,"schema_hash":"c4f6301b53d5fa75e4765f8795cab15d62a99122d40248b3f28e72c8a198e898","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/molecule_associated_phenotype.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__molecule_associated_phenotype.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"display_relation","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__molecule_associated_phenotype.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Non-causal molecule-to-phenotype side-effect/rescue association; direction is molecule→phenotype","migration_receipt":{"action":"copied","destination_crc32c":"pMESXg==","destination_generation":"1785155484199958","source":"kg/v2/edges/molecule_associated_phenotype.parquet","source_generation":"1781796935117381","verified":true},"name":"molecule_associated_phenotype","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":111612,"crc32c_base64":"pMESXg==","generation":"1785155484199958","md5_base64":"jDlMgFXi8mabZULz/sOQnQ==","row_groups":1,"rows":64784,"schema_hash":"7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"provenance-gap","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"provenance-gap","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/molecule_contraindicates_disease.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__molecule_contraindicates_disease.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__molecule_contraindicates_disease.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Contraindication","migration_receipt":{"action":"copied","destination_crc32c":"4nlliA==","destination_generation":"1785155484349742","source":"kg/v2/edges/molecule_contraindicates_disease.parquet","source_generation":"1781177663101628","verified":true},"name":"molecule_contraindicates_disease","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":67065,"crc32c_base64":"4nlliA==","generation":"1785155484349742","md5_base64":"ixr4zyqm6tV++hhcKn9lCA==","row_groups":1,"rows":30675,"schema_hash":"078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"provenance-gap","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"provenance-gap","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/molecule_parent_of_molecule.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__molecule_parent_of_molecule.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"display_relation","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__molecule_parent_of_molecule.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Chemical/drug parent-child hierarchy relation.","migration_receipt":{"action":"copied","destination_crc32c":"lBYRsQ==","destination_generation":"1785155484679611","source":"kg/v2/edges/molecule_parent_of_molecule.parquet","source_generation":"1781796942923766","verified":true},"name":"molecule_parent_of_molecule","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":19797,"crc32c_base64":"lBYRsQ==","generation":"1785155484679611","md5_base64":"OEqS3FWlGG5lPX3u0wNUow==","row_groups":1,"rows":4140,"schema_hash":"7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"provenance-gap","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"provenance-gap","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/molecule_synergizes_molecule.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__molecule_synergizes_molecule.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"display_relation","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__molecule_synergizes_molecule.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Drug combination synergy or interaction-effect relation; not a physical molecular interaction.","migration_receipt":{"action":"copied","destination_crc32c":"iQeHYQ==","destination_generation":"1785155484817964","source":"kg/v2/edges/molecule_synergizes_molecule.parquet","source_generation":"1781796942792175","verified":true},"name":"molecule_synergizes_molecule","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":4284625,"crc32c_base64":"iQeHYQ==","generation":"1785155484817964","md5_base64":"eea/DOo7o4LqxYp0JVweFw==","row_groups":22,"rows":2672628,"schema_hash":"7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"provenance-gap","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"provenance-gap","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/molecule_treats_disease.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__molecule_treats_disease.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__molecule_treats_disease.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Indication (clinical)","migration_receipt":{"action":"copied","destination_crc32c":"5SqHVw==","destination_generation":"1785155486922602","source":"kg/v2/edges/molecule_treats_disease.parquet","source_generation":"1781177663416404","verified":true},"name":"molecule_treats_disease","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":57319,"crc32c_base64":"5SqHVw==","generation":"1785155486922602","md5_base64":"eaFp6AYU6VBmXjxFxfAK5Q==","row_groups":1,"rows":14135,"schema_hash":"078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"provenance-gap","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"provenance-gap","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/tissue_expresses_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__tissue_expresses_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"display_relation","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"double","name":"tpm","nullable":true},{"dtype":"int64","name":"expression_level","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__tissue_expresses_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"GTEx / HPA bulk RNA","migration_receipt":{"action":"copied","destination_crc32c":"H22BCQ==","destination_generation":"1785155489893065","source":"kg/v2/edges/tissue_expresses_gene.parquet","source_generation":"1781796940864266","verified":true},"name":"tissue_expresses_gene","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":41362747,"crc32c_base64":"H22BCQ==","generation":"1785155489893065","md5_base64":"Z20jxG/HwBkMNYi/GDdZzw==","row_groups":45,"rows":5338736,"schema_hash":"145011ad67eba82a0e51e34b197b573edea387d056056d12af46675f8ae32b0f","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/gene_ortholog_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__gene_ortholog_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__gene_ortholog_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Source-level support records for the canonical `gene_ortholog_gene` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"p2igJw==","destination_generation":"1785155492452605","source":"kg/v2/evidence/gene_ortholog_gene.parquet","source_generation":"1781617071683561","verified":true},"name":"gene_ortholog_gene","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":5533441,"crc32c_base64":"p2igJw==","generation":"1785155492452605","md5_base64":"NO9E500P1k0hwDNZhBNduw==","row_groups":1,"rows":161675,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/molecule_treats_disease.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__molecule_treats_disease.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__molecule_treats_disease.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Source-level support records for the canonical `molecule_treats_disease` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"dfr1NA==","destination_generation":"1785155492750134","source":"kg/v2/evidence/molecule_treats_disease.parquet","source_generation":"1784745798547712","verified":true},"name":"molecule_treats_disease","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":891126,"crc32c_base64":"dfr1NA==","generation":"1785155492750134","md5_base64":"XSz+ZiruueQY1go0EZtYLw==","row_groups":2,"rows":8285,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/cell_type_textual_summary.parquet","catalog_page":"docs/parquet-catalog/datasets/features__cell_type_textual_summary.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"feature_key","nullable":true},{"dtype":"string","name":"feature_table","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"summary_kind","nullable":true},{"dtype":"string","name":"summary_text","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["feature_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"features","links":["docs/parquet-catalog/datasets/features__cell_type_textual_summary.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Source-backed text payloads for `cell_type` nodes, suitable for retrieval or text feature construction.","migration_receipt":{"action":"copied","destination_crc32c":"HNEhIw==","destination_generation":"1785155495088519","source":"kg/v2/features/cell_type_textual_summary.parquet","source_generation":"1782169810447963","verified":true},"name":"cell_type_textual_summary","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"Text is not a curated label, causal claim, or complete coverage of the node table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":352433,"crc32c_base64":"HNEhIw==","generation":"1785155495088519","md5_base64":"7OjTIkfpZ1eeNfhJ5Cffsg==","row_groups":1,"rows":3135,"schema_hash":"072e4e1123aae68dcd32db4e101aaaa5fe72ae3dbba51a17c9484a660724221b","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/disease_textual_summary.parquet","catalog_page":"docs/parquet-catalog/datasets/features__disease_textual_summary.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"feature_key","nullable":true},{"dtype":"string","name":"feature_table","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"summary_kind","nullable":true},{"dtype":"string","name":"summary_text","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["feature_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"features","links":["docs/parquet-catalog/datasets/features__disease_textual_summary.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Source-backed text payloads for `disease` nodes, suitable for retrieval or text feature construction.","migration_receipt":{"action":"copied","destination_crc32c":"uiqsnA==","destination_generation":"1785155495411230","source":"kg/v2/features/disease_textual_summary.parquet","source_generation":"1782169812047483","verified":true},"name":"disease_textual_summary","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"Text is not a curated label, causal claim, or complete coverage of the node table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":2964350,"crc32c_base64":"uiqsnA==","generation":"1785155495411230","md5_base64":"0BYaowYTpCIDg+Jrmxjqpg==","row_groups":1,"rows":26395,"schema_hash":"072e4e1123aae68dcd32db4e101aaaa5fe72ae3dbba51a17c9484a660724221b","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/gene_textual_summary.parquet","catalog_page":"docs/parquet-catalog/datasets/features__gene_textual_summary.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"feature_key","nullable":true},{"dtype":"string","name":"feature_table","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"summary_kind","nullable":true},{"dtype":"string","name":"summary_text","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["feature_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"features","links":["docs/parquet-catalog/datasets/features__gene_textual_summary.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Source-backed text payloads for `gene` nodes, suitable for retrieval or text feature construction.","migration_receipt":{"action":"copied","destination_crc32c":"RZuhQw==","destination_generation":"1785155495564485","source":"kg/v2/features/gene_textual_summary.parquet","source_generation":"1782169813900972","verified":true},"name":"gene_textual_summary","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"Text is not a curated label, causal claim, or complete coverage of the node table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":7588830,"crc32c_base64":"RZuhQw==","generation":"1785155495564485","md5_base64":"gSS9z4G+qMdJi59Inq+Xvw==","row_groups":1,"rows":212029,"schema_hash":"072e4e1123aae68dcd32db4e101aaaa5fe72ae3dbba51a17c9484a660724221b","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/molecule_textual_summary.parquet","catalog_page":"docs/parquet-catalog/datasets/features__molecule_textual_summary.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"feature_key","nullable":true},{"dtype":"string","name":"feature_table","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"summary_kind","nullable":true},{"dtype":"string","name":"summary_text","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["feature_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"features","links":["docs/parquet-catalog/datasets/features__molecule_textual_summary.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Source-backed text payloads for `molecule` nodes, suitable for retrieval or text feature construction.","migration_receipt":{"action":"copied","destination_crc32c":"InV3zA==","destination_generation":"1785155495836531","source":"kg/v2/features/molecule_textual_summary.parquet","source_generation":"1782169815729970","verified":true},"name":"molecule_textual_summary","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"Text is not a curated label, causal claim, or complete coverage of the node table.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":730115,"crc32c_base64":"InV3zA==","generation":"1785155495836531","md5_base64":"Pjqe3hbkOvsDB9RK3MA2hw==","row_groups":1,"rows":22230,"schema_hash":"072e4e1123aae68dcd32db4e101aaaa5fe72ae3dbba51a17c9484a660724221b","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/cell_type.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__cell_type.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"large_string","name":"name","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"large_string","name":"uberon_id","nullable":true},{"dtype":"large_string","name":"mesh_id","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__cell_type.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Canonical cell_type registry keyed in the CL namespace (example `CL:0000576`).","migration_receipt":{"action":"copied","destination_crc32c":"yTb77A==","destination_generation":"1785155477358732","source":"kg/v2/nodes/cell_type.parquet","source_generation":"1781177659496138","verified":true},"name":"cell_type","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":82710,"crc32c_base64":"yTb77A==","generation":"1785155477358732","md5_base64":"VGKQnbojTMUMgM/8OxZ41A==","row_groups":1,"rows":3513,"schema_hash":"e6cae8e01a9c7efa80a5b09329d848fe28a3dba2675cb9182250f48826b08034","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/dataset.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__dataset.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"large_string","name":"name","nullable":true},{"dtype":"large_string","name":"source","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__dataset.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/06_build_core_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/export_kg.py"],"mappings_and_joins":"Normalize legacy node and endpoint identifiers to the declared Jouvence namespaces while preserving source labels and typed endpoints.","meaning":"Canonical dataset registry keyed in the DOI / UUID namespace (example `DOI:10.1038/s41586-023-06221-2`).","migration_receipt":{"action":"copied","destination_crc32c":"j4ZN5w==","destination_generation":"1785155477598313","source":"kg/v2/nodes/dataset.parquet","source_generation":"1781481541510033","verified":true},"name":"dataset","native_inputs":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"native_source":["https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/CNQV69"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"txgnn_legacy","problems_and_decisions":"The immutable Dataverse identity is known, but the complete accepted acquisition/build argv and several constituent source releases are not tracked.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":2579,"crc32c_base64":"j4ZN5w==","generation":"1785155477598313","md5_base64":"wb+nMOuydmpoHpGu9LL93w==","row_groups":1,"rows":1,"schema_hash":"4e3d5500d9d5bf9b8b46ba66d78325daa50fcc7b104c15ad7117de4ac2c1dec5","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Do not infer missing evidence, source releases or endpoint projections from a legacy relation name.","rebuild_command_evidenced":false,"release":"TxData Dataverse DOI 10.7910/DVN/CNQV69; constituent upstream releases vary and are not always recoverable","replay_level":"provenance-gap","reproduce_notebook":"notebooks/reproduce/txgnn_legacy_bundle.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"provenance-gap","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"txgnn_legacy","source_family_label":"TxData/TxGNN legacy source bundle","transformations_and_filters":"Export legacy source tables into typed nodes, deduplicated edge assertions and evidence where recoverable."}]''')

def require(condition, message):
    if not condition:
        raise RuntimeError(message)

for RECORD in RECORDS:
    require(RECORD["canonical_uri"] == "gs://jouvencekb/main/" + ("embeddings" if RECORD["layer"] == "embedding" else RECORD["layer"]) + "/" + RECORD["name"] + ".parquet", "canonical URI/identity mismatch")
    require(RECORD["replay_level"] in ['documented-not-replayed', 'fully-replayable', 'historical-builder-only', 'provenance-gap'], "unsupported replay level")
    require(RECORD["qc"]["rows"] >= 0, "negative expected row count")
    require(len(RECORD["qc"]["schema_hash"]) == 64, "invalid schema hash")
    require(RECORD["migration_receipt"]["verified"] is True, "migration receipt is not verified")
    require(bool(RECORD["fields"]), "empty expected schema")
summary = {
    "pipeline_family": RECORDS[0]["pipeline_family"],
    "output_count": len(RECORDS),
    "identities": [record["layer"] + "__" + record["name"] for record in RECORDS],
}
summary

# %% [markdown]
# ## Optional bounded live canonical footer check
#
# This cell is skipped unless the caller explicitly opts in.

# %%
import os

if os.environ.get("JOUVENCE_LIVE_GCS") != "1":
    live_result = {"status": "SKIPPED", "reason": "set JOUVENCE_LIVE_GCS=1 and caller-owned JOUVENCE_BILLING_PROJECT"}
else:
    import gcsfs
    import pyarrow.parquet as pq

    billing_project = os.environ.get("JOUVENCE_BILLING_PROJECT")
    if not billing_project:
        raise RuntimeError("JOUVENCE_BILLING_PROJECT is required for requester-pays live verification")
    fs = gcsfs.GCSFileSystem(project=billing_project, requester_pays=billing_project, version_aware=True)
    if not fs.version_aware:
        raise RuntimeError("version-aware GCS reads are required")
    selected_id = os.environ.get("JOUVENCE_OUTPUT_ID", RECORDS[0]["layer"] + "__" + RECORDS[0]["name"])
    selected = [record for record in RECORDS if record["layer"] + "__" + record["name"] == selected_id]
    if len(selected) != 1:
        raise RuntimeError("JOUVENCE_OUTPUT_ID must select exactly one output owned by this notebook")
    RECORD = selected[0]
    object_path = RECORD["canonical_uri"].removeprefix("gs://")
    if "#" in object_path:
        raise RuntimeError("canonical object key must not already contain a generation suffix")
    expected_generation = RECORD["qc"]["generation"]
    pinned_path = object_path + "#" + expected_generation
    info = fs.info(pinned_path)
    if str(info.get("generation", "")) != expected_generation:
        raise RuntimeError("generation-qualified object resolved a different generation")
    with fs.open(pinned_path, "rb") as handle:
        parquet = pq.ParquetFile(handle)
        live_fields = [
            {"name": field.name, "dtype": str(field.type), "nullable": bool(field.nullable)}
            for field in parquet.schema_arrow
        ]
        live_rows = parquet.metadata.num_rows
        live_row_groups = parquet.metadata.num_row_groups
    if live_rows != RECORD["qc"]["rows"]:
        raise RuntimeError("live footer row count differs from the frozen registry")
    if live_row_groups != RECORD["qc"]["row_groups"]:
        raise RuntimeError("live footer row-group count differs from the frozen registry")
    if live_fields != RECORD["fields"]:
        raise RuntimeError("live footer schema differs from the frozen registry")
    live_result = {"status": "PASS", "generation": str(info["generation"]), "rows": live_rows, "row_groups": live_row_groups}
live_result
