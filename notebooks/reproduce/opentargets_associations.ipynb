# %% [markdown]
# # Reproduce Open Targets Platform 26.03 and bundled ENCODE rE2G
#
# Generated by reproduce/generate_parquet_reproduction_notebooks.py; do not edit.
#
# ## Objective and meaning
#
# Document the coherent `opentargets` acquisition/build/mapping pipeline and safely verify all 33 current canonical Parquets assigned to it.
#
# Grouping justification: these outputs share a defensible source/transformation family context. Exact producer and command evidence remains per output and may be absent; layer alone is not used as a grouping rule, and differences remain explicit in each output contract.
#
# ## Canonical outputs owned by this notebook
#
# | Layer | Canonical output | Rows | Replay level | Catalog |
# |---|---|---:|---|---|
# | `edges` | `disease_associated_gene` | 83,339 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__disease_associated_gene.md) |
# | `edges` | `disease_associated_protein` | 3,243 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__disease_associated_protein.md) |
# | `edges` | `disease_manifests_in_tissue` | 19 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__disease_manifests_in_tissue.md) |
# | `edges` | `enhancer_regulates_gene` | 48,808,144 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__enhancer_regulates_gene.md) |
# | `edges` | `gene_interacts_gene` | 7,424,037 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__gene_interacts_gene.md) |
# | `edges` | `molecule_targets_gene` | 41,239 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__molecule_targets_gene.md) |
# | `edges` | `mutation_affects_molecule_response` | 4,866 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__mutation_affects_molecule_response.md) |
# | `edges` | `mutation_affects_transcript` | 2,599,922 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__mutation_affects_transcript.md) |
# | `edges` | `mutation_associated_disease` | 4,656,171 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__mutation_associated_disease.md) |
# | `edges` | `mutation_associated_gene` | 535,093 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__mutation_associated_gene.md) |
# | `edges` | `mutation_associated_phenotype` | 164,406 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__mutation_associated_phenotype.md) |
# | `edges` | `mutation_causes_protein_change` | 177,735 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__mutation_causes_protein_change.md) |
# | `edges` | `mutation_in_gene` | 2,599,525 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__mutation_in_gene.md) |
# | `edges` | `mutation_overlaps_enhancer` | 1,664,278 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__mutation_overlaps_enhancer.md) |
# | `evidence` | `disease_associated_gene` | 2,928 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__disease_associated_gene.md) |
# | `evidence` | `disease_associated_protein` | 35,839 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__disease_associated_protein.md) |
# | `evidence` | `disease_manifests_in_tissue` | 29 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__disease_manifests_in_tissue.md) |
# | `evidence` | `enhancer_regulates_gene` | 48,810,390 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__enhancer_regulates_gene.md) |
# | `evidence` | `gene_interacts_gene` | 14,336,594 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__gene_interacts_gene.md) |
# | `evidence` | `molecule_targets_gene` | 41,239 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__molecule_targets_gene.md) |
# | `evidence` | `mutation_affects_molecule_response` | 18,595 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__mutation_affects_molecule_response.md) |
# | `evidence` | `mutation_affects_transcript` | 2,599,922 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__mutation_affects_transcript.md) |
# | `evidence` | `mutation_associated_disease` | 4,656,171 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__mutation_associated_disease.md) |
# | `evidence` | `mutation_associated_gene` | 535,093 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__mutation_associated_gene.md) |
# | `evidence` | `mutation_associated_phenotype` | 169,005 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__mutation_associated_phenotype.md) |
# | `evidence` | `mutation_causes_protein_change` | 177,735 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__mutation_causes_protein_change.md) |
# | `evidence` | `mutation_in_gene` | 2,599,525 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__mutation_in_gene.md) |
# | `evidence` | `mutation_overlaps_enhancer` | 1,664,278 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/evidence__mutation_overlaps_enhancer.md) |
# | `nodes` | `disease` | 41,859 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/nodes__disease.md) |
# | `nodes` | `enhancer` | 48,808,144 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/nodes__enhancer.md) |
# | `nodes` | `molecule` | 31,007 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/nodes__molecule.md) |
# | `nodes` | `mutation` | 2,589,509 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/nodes__mutation.md) |
# | `nodes` | `paper` | 2,958,199 | `provenance-gap` | [catalog](../../docs/parquet-catalog/datasets/nodes__paper.md) |

# %% [markdown]
# ## Native inputs, release, acquisition and environment
#
# Shared acquisition context is stated once; release and retained input differences are restated under every owned output.
#
# ## Expected schema and identifiers
#
# Each output section carries its exact catalog schema, row count, object generation and checksum.
#
# ## Keys, mappings and joins
#
# Shared family mappings are applied only where stated; every output preserves its own key contract.
#
# ## Cleaning, normalization, transformations and filters
#
# Transformation and filter differences are explicit per output below.
#
# ## Deduplication and assertion/evidence semantics
#
# Canonical edges are deduplicated assertions; source-specific multiplicity and context remain evidence/features where applicable.
#
# ## Quarantines, exclusions and missing data
#
# Every output contract states its known exclusions and unresolved provenance.
#
# ## Problems encountered and decisions
#
# Known decisions and alternatives are reported conservatively; migration identity is not treated as proof of biological replayability.
#
# ## Producer / builder
#
# The per-output contracts name an evidenced tracked producer or state that it is unavailable.
#
# ## Full worker rebuild command (inert text; never executed by this notebook)
#
# Any command below is documentation only and remains approved-worker, staging and review gated.
#
# ## Migration receipt
#
# Every output includes its generation-matched, verified migration receipt.
#
# ## QC, bounded replay and verification
#
# The first code cell validates all embedded output contracts offline. The opt-in cell verifies one selected GCS object metadata record and Parquet footer, chosen with `JOUVENCE_OUTPUT_ID`; it never scans all family outputs.
#
# ## Reproducibility limits
#
# Replay levels remain per output. No family-level label upgrades weaker members.
#
# ## Linked code, tests, reports and historical notebooks
#
# Links are listed in each output contract.

# %% [markdown]
# ## Per-output reproduction contracts
#
# ### Output `edges__disease_associated_gene`
#
# - Canonical URI: `gs://jouvencekb/main/edges/disease_associated_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__disease_associated_gene.md`](../../docs/parquet-catalog/datasets/edges__disease_associated_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Gene→disease direction for causal/directed disease association; source/evidence rows preserve predicate, score, and provenance.
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **83,339**; bytes: **314,067**; row groups: **1**; schema hash (`arrow-fields-v1`): `35fa300d9883a453a33684ed2798242febf297771190efa79b0f0a08f5ea6b1a`; generation: `1785155482007624`; CRC32C: `BeQhmg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
# | `score` | `double` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/disease_associated_gene.parquet`
# - Destination generation: `1785155482007624`
# - Destination CRC32C: `BeQhmg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__disease_associated_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__disease_associated_protein`
#
# - Canonical URI: `gs://jouvencekb/main/edges/disease_associated_protein.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__disease_associated_protein.md`](../../docs/parquet-catalog/datasets/edges__disease_associated_protein.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Protein→disease direction for protein-native causal/directed disease association; use only protein-specific evidence.
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **3,243**; bytes: **59,222**; row groups: **1**; schema hash (`arrow-fields-v1`): `532b5b19522e5941c98a494849263d9e033b4f9b638076a27f88b9d79327bcf5`; generation: `1785155482165594`; CRC32C: `FAnzhg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
# | `causal_mechanisms` | `large_string` | `true` |
# | `mechanism_status` | `large_string` | `true` |
# | `effect_directions` | `large_string` | `true` |
# | `effect_direction_status` | `large_string` | `true` |
# | `inheritance_modes` | `large_string` | `true` |
# | `causal_support_level` | `large_string` | `true` |
# | `evidence_count` | `int64` | `true` |
# | `causal_feature_contract_version` | `large_string` | `true` |
# | `both_operands_known` | `bool` | `true` |
# | `disease_operand_contract_version` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/disease_associated_protein.parquet`
# - Destination generation: `1785155482165594`
# - Destination CRC32C: `FAnzhg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__disease_associated_protein.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__disease_manifests_in_tissue`
#
# - Canonical URI: `gs://jouvencekb/main/edges/disease_manifests_in_tissue.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__disease_manifests_in_tissue.md`](../../docs/parquet-catalog/datasets/edges__disease_manifests_in_tissue.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Pathology annotation
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **19**; bytes: **5,416**; row groups: **1**; schema hash (`arrow-fields-v1`): `078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1`; generation: `1785155482824533`; CRC32C: `u8X16w==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/disease_manifests_in_tissue.parquet`
# - Destination generation: `1785155482824533`
# - Destination CRC32C: `u8X16w==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__disease_manifests_in_tissue.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__enhancer_regulates_gene`
#
# - Canonical URI: `gs://jouvencekb/main/edges/enhancer_regulates_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__enhancer_regulates_gene.md`](../../docs/parquet-catalog/datasets/edges__enhancer_regulates_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: ENCODE-rE2G composite enhancer-to-gene prediction; preserve biosample, assay feature scores, distance, study, and model score in edge/evidence metadata.
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **48,808,144**; bytes: **1,997,157,871**; row groups: **118**; schema hash (`arrow-fields-v1`): `b619587ee4f7bf9df888bf6a2506a2429369e8b640ac03020754fbf520a2933a`; generation: `1785155483362416`; CRC32C: `MNF0ow==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `e2g_score` | `double` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/enhancer_regulates_gene.parquet`
# - Destination generation: `1785155483362416`
# - Destination CRC32C: `MNF0ow==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__enhancer_regulates_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__gene_interacts_gene`
#
# - Canonical URI: `gs://jouvencekb/main/edges/gene_interacts_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__gene_interacts_gene.md`](../../docs/parquet-catalog/datasets/edges__gene_interacts_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Keep broad for current OpenTargets interaction because canonical endpoints are gene-level; preserve source-specific evidence metadata and do not project text_span product IDs into protein/transcript/TF/enhancer relations.
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **7,424,037**; bytes: **36,907,950**; row groups: **61**; schema hash (`arrow-fields-v1`): `7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2`; generation: `1785155483887629`; CRC32C: `uOngJA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `display_relation` | `string` | `true` |
# | `source` | `string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/gene_interacts_gene.parquet`
# - Destination generation: `1785155483887629`
# - Destination CRC32C: `uOngJA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__gene_interacts_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__molecule_targets_gene`
#
# - Canonical URI: `gs://jouvencekb/main/edges/molecule_targets_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__molecule_targets_gene.md`](../../docs/parquet-catalog/datasets/edges__molecule_targets_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Drug/compound target relation for sources whose native target endpoint is a gene or OpenTargets Ensembl target ID; preserve source MoA/action metadata in evidence.
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **41,239**; bytes: **238,792**; row groups: **1**; schema hash (`arrow-fields-v1`): `bfee26da8e6a4b1b5da85c6da9fb39c9ce5106d4ab68cd105185873a6438b565`; generation: `1785155486721297`; CRC32C: `D5jLtA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `display_relation` | `string` | `true` |
# | `source` | `string` | `true` |
# | `credibility` | `int64` | `true` |
# | `action_type` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/molecule_targets_gene.parquet`
# - Destination generation: `1785155486721297`
# - Destination CRC32C: `D5jLtA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__molecule_targets_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__mutation_affects_molecule_response`
#
# - Canonical URI: `gs://jouvencekb/main/edges/mutation_affects_molecule_response.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__mutation_affects_molecule_response.md`](../../docs/parquet-catalog/datasets/edges__mutation_affects_molecule_response.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Pharmacogenomics
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **4,866**; bytes: **45,989**; row groups: **1**; schema hash (`arrow-fields-v1`): `3998ac659feaaf75a1772fe1a5294a71cb814ad3b0c539c6de85ff37b479dadb`; generation: `1785155487091862`; CRC32C: `Ha05SQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
# | `pgx_category` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/mutation_affects_molecule_response.parquet`
# - Destination generation: `1785155487091862`
# - Destination CRC32C: `Ha05SQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__mutation_affects_molecule_response.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__mutation_affects_transcript`
#
# - Canonical URI: `gs://jouvencekb/main/edges/mutation_affects_transcript.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__mutation_affects_transcript.md`](../../docs/parquet-catalog/datasets/edges__mutation_affects_transcript.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Transcript-level consequence such as splicing/UTR/coding-transcript effect; canonical promoted/review-accepted from OpenTargets VEP transcriptConsequences with canonical mutation/transcript endpoints and allowed transcript-local consequence policy
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **2,599,922**; bytes: **20,266,519**; row groups: **22**; schema hash (`arrow-fields-v1`): `b4f1a985561189e67ebff6aad1255198b4799fb5196a89f45fd68a78e6500f43`; generation: `1785155487269758`; CRC32C: `GuUaHw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `display_relation` | `string` | `true` |
# | `source` | `string` | `true` |
# | `credibility` | `int32` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/mutation_affects_transcript.parquet`
# - Destination generation: `1785155487269758`
# - Destination CRC32C: `GuUaHw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__mutation_affects_transcript.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__mutation_associated_disease`
#
# - Canonical URI: `gs://jouvencekb/main/edges/mutation_associated_disease.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__mutation_associated_disease.md`](../../docs/parquet-catalog/datasets/edges__mutation_associated_disease.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: GWAS / ClinVar / OpenTargets known-variant disease association; canonical edge exists, evidence backfill remains next tranche
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **4,656,171**; bytes: **89,034,605**; row groups: **5**; schema hash (`arrow-fields-v1`): `0e2d3dd1958960bac40344ecb41b055465417e6869cf940e1fc72c0dc9aea513`; generation: `1785155487470336`; CRC32C: `o751XA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
# | `score` | `double` | `true` |
# | `datatype` | `large_string` | `true` |
# | `studyLocusId` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/mutation_associated_disease.parquet`
# - Destination generation: `1785155487470336`
# - Destination CRC32C: `o751XA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__mutation_associated_disease.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__mutation_associated_gene`
#
# - Canonical URI: `gs://jouvencekb/main/edges/mutation_associated_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__mutation_associated_gene.md`](../../docs/parquet-catalog/datasets/edges__mutation_associated_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Statistical/functional locus-to-gene prediction (for example OpenTargets L2G/GWAS); canonical promoted GWAS/L2G relation with evidence support
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **535,093**; bytes: **22,829,668**; row groups: **200**; schema hash (`arrow-fields-v1`): `d05a48086562da908fdea3808e439cfd079757260e796024fb4140ce4bdc2a16`; generation: `1785155487740464`; CRC32C: `lrFdnQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
# | `score` | `double` | `true` |
# | `datatype` | `large_string` | `true` |
# | `studyLocusId` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/mutation_associated_gene.parquet`
# - Destination generation: `1785155487740464`
# - Destination CRC32C: `lrFdnQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__mutation_associated_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__mutation_associated_phenotype`
#
# - Canonical URI: `gs://jouvencekb/main/edges/mutation_associated_phenotype.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__mutation_associated_phenotype.md`](../../docs/parquet-catalog/datasets/edges__mutation_associated_phenotype.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: OpenTargets EVA/ClinVar HP-only mutation→phenotype association; include all clinical-significance classes and preserve the exact assertion in edge/evidence metadata rather than restricting the relation to pathogenic/likely pathogenic.
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **164,406**; bytes: **1,262,716**; row groups: **1**; schema hash (`arrow-fields-v1`): `078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1`; generation: `1785155487890849`; CRC32C: `BZw6Sw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/mutation_associated_phenotype.parquet`
# - Destination generation: `1785155487890849`
# - Destination CRC32C: `BZw6Sw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__mutation_associated_phenotype.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__mutation_causes_protein_change`
#
# - Canonical URI: `gs://jouvencekb/main/edges/mutation_causes_protein_change.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__mutation_causes_protein_change.md`](../../docs/parquet-catalog/datasets/edges__mutation_causes_protein_change.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Amino acid change with ENSP protein endpoint; canonical OpenTargets protein-change edge and evidence files exist
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **177,735**; bytes: **2,640,740**; row groups: **1**; schema hash (`arrow-fields-v1`): `b8751beb2caa6055e55f3028c86c221a962942496f68e8dfb1ba920bfd69b828`; generation: `1785155488079071`; CRC32C: `9nwQNQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
# | `amino_acid_change` | `large_string` | `true` |
# | `uniprot_id` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/mutation_causes_protein_change.parquet`
# - Destination generation: `1785155488079071`
# - Destination CRC32C: `9nwQNQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__mutation_causes_protein_change.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__mutation_in_gene`
#
# - Canonical URI: `gs://jouvencekb/main/edges/mutation_in_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__mutation_in_gene.md`](../../docs/parquet-catalog/datasets/edges__mutation_in_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Physical/genomic containment only; do not use for L2G/GWAS association or OpenTargets L2G targetId smoke output
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **2,599,525**; bytes: **19,913,850**; row groups: **22**; schema hash (`arrow-fields-v1`): `7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2`; generation: `1785155488238195`; CRC32C: `fs0JZg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `display_relation` | `string` | `true` |
# | `source` | `string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/mutation_in_gene.parquet`
# - Destination generation: `1785155488238195`
# - Destination CRC32C: `fs0JZg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__mutation_in_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `edges__mutation_overlaps_enhancer`
#
# - Canonical URI: `gs://jouvencekb/main/edges/mutation_overlaps_enhancer.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__mutation_overlaps_enhancer.md`](../../docs/parquet-catalog/datasets/edges__mutation_overlaps_enhancer.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Variant-enhancer interval overlap: coordinate overlap alone remains context/support-only, while the reviewed non-context-support-gated candidate from t_73c67c1b was canonical promoted/review-required by t_00551bc3 with evidence support and leakage policy. This remains associative/indirect; stronger allele-specific regulatory or enhancer-activity evidence is preferred, and downstream disease/gene support is not by itself proof of enhancer perturbation.
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **1,664,278**; bytes: **3,122,917**; row groups: **14**; schema hash (`arrow-fields-v1`): `7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2`; generation: `1785155488400365`; CRC32C: `H0Gguw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `display_relation` | `string` | `true` |
# | `source` | `string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/mutation_overlaps_enhancer.parquet`
# - Destination generation: `1785155488400365`
# - Destination CRC32C: `H0Gguw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__mutation_overlaps_enhancer.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__disease_associated_gene`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/disease_associated_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__disease_associated_gene.md`](../../docs/parquet-catalog/datasets/evidence__disease_associated_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `disease_associated_gene` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **2,928**; bytes: **90,231**; row groups: **1**; schema hash (`arrow-fields-v1`): `0beeb15b80896c37055bcab526fc11d4376ed2762facadbc59b012f280d8b03c`; generation: `1785155491117311`; CRC32C: `sL6BUQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `evidence_type` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `source_dataset` | `large_string` | `true` |
# | `source_record_id` | `large_string` | `true` |
# | `paper_id` | `large_string` | `true` |
# | `dataset_id` | `large_string` | `true` |
# | `study_id` | `large_string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `large_string` | `true` |
# | `confidence_interval` | `large_string` | `true` |
# | `predicate` | `large_string` | `true` |
# | `text_span` | `large_string` | `true` |
# | `section` | `large_string` | `true` |
# | `extraction_method` | `large_string` | `true` |
# | `license` | `large_string` | `true` |
# | `release` | `large_string` | `true` |
# | `created_at` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/disease_associated_gene.parquet`
# - Destination generation: `1785155491117311`
# - Destination CRC32C: `sL6BUQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__disease_associated_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__disease_associated_protein`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/disease_associated_protein.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__disease_associated_protein.md`](../../docs/parquet-catalog/datasets/evidence__disease_associated_protein.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `disease_associated_protein` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **35,839**; bytes: **4,093,409**; row groups: **1**; schema hash (`arrow-fields-v1`): `924be33fcb96d1412b4aeda7c3d31fd17d6615dbd560d58c6ac32c4077736254`; generation: `1785155491357899`; CRC32C: `+BucBA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `evidence_type` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `source_dataset` | `large_string` | `true` |
# | `source_record_id` | `large_string` | `true` |
# | `paper_id` | `large_string` | `true` |
# | `dataset_id` | `large_string` | `true` |
# | `study_id` | `large_string` | `true` |
# | `evidence_score` | `large_string` | `true` |
# | `effect_size` | `large_string` | `true` |
# | `p_value` | `large_string` | `true` |
# | `direction` | `large_string` | `true` |
# | `confidence_interval` | `large_string` | `true` |
# | `predicate` | `large_string` | `true` |
# | `text_span` | `large_string` | `true` |
# | `section` | `large_string` | `true` |
# | `extraction_method` | `large_string` | `true` |
# | `license` | `large_string` | `true` |
# | `release` | `large_string` | `true` |
# | `created_at` | `large_string` | `true` |
# | `uniprot_accession` | `large_string` | `true` |
# | `uniprot_entry_id` | `large_string` | `true` |
# | `ensp_id` | `large_string` | `true` |
# | `isoform` | `large_string` | `true` |
# | `disease_source_id` | `large_string` | `true` |
# | `disease_name` | `large_string` | `true` |
# | `disease_acronym` | `large_string` | `true` |
# | `disease_description` | `large_string` | `true` |
# | `variant_ft_id` | `large_string` | `true` |
# | `aa_change` | `large_string` | `true` |
# | `variant_category` | `large_string` | `true` |
# | `dbsnp_id` | `large_string` | `true` |
# | `eco_codes` | `large_string` | `true` |
# | `pmids` | `large_string` | `true` |
# | `mapping_confidence` | `large_string` | `true` |
# | `mapping_method` | `large_string` | `true` |
# | `source_native_endpoint_policy` | `large_string` | `true` |
# | `materialization_assertion_id` | `large_string` | `true` |
# | `source_assertion_id` | `large_string` | `true` |
# | `normalized_causal_mechanism` | `large_string` | `true` |
# | `normalized_effect_direction` | `large_string` | `true` |
# | `normalized_inheritance_mode` | `large_string` | `true` |
# | `normalized_clinical_significance` | `large_string` | `true` |
# | `normalized_causal_support_level` | `large_string` | `true` |
# | `materialization_assertion_conflict` | `bool` | `true` |
# | `causal_feature_contract_version` | `large_string` | `true` |
# | `operand_source_family` | `large_string` | `true` |
# | `operand_source_record_id` | `large_string` | `true` |
# | `operand_source_release` | `large_string` | `true` |
# | `operand_mapping_path` | `large_string` | `true` |
# | `mechanism_operand` | `large_string` | `true` |
# | `disease_direction_operand` | `large_string` | `true` |
# | `operand_confidence` | `large_string` | `true` |
# | `operand_support_class` | `large_string` | `true` |
# | `operand_reject_reason` | `large_string` | `true` |
# | `mechanism_operand_conflict` | `bool` | `true` |
# | `disease_direction_operand_conflict` | `bool` | `true` |
# | `disease_operand_contract_version` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/disease_associated_protein.parquet`
# - Destination generation: `1785155491357899`
# - Destination CRC32C: `+BucBA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__disease_associated_protein.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__disease_manifests_in_tissue`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/disease_manifests_in_tissue.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__disease_manifests_in_tissue.md`](../../docs/parquet-catalog/datasets/evidence__disease_manifests_in_tissue.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `disease_manifests_in_tissue` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **29**; bytes: **22,231**; row groups: **1**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155491791763`; CRC32C: `IIwEJw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/disease_manifests_in_tissue.parquet`
# - Destination generation: `1785155491791763`
# - Destination CRC32C: `IIwEJw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__disease_manifests_in_tissue.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__enhancer_regulates_gene`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/enhancer_regulates_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__enhancer_regulates_gene.md`](../../docs/parquet-catalog/datasets/evidence__enhancer_regulates_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `enhancer_regulates_gene` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **48,810,390**; bytes: **4,788,517,448**; row groups: **398**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155492052917`; CRC32C: `N3XR1g==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/enhancer_regulates_gene.parquet`
# - Destination generation: `1785155492052917`
# - Destination CRC32C: `N3XR1g==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__enhancer_regulates_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__gene_interacts_gene`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/gene_interacts_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__gene_interacts_gene.md`](../../docs/parquet-catalog/datasets/evidence__gene_interacts_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `gene_interacts_gene` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **14,336,594**; bytes: **483,161,330**; row groups: **117**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155492268116`; CRC32C: `NdyPtg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/gene_interacts_gene.parquet`
# - Destination generation: `1785155492268116`
# - Destination CRC32C: `NdyPtg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__gene_interacts_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__molecule_targets_gene`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/molecule_targets_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__molecule_targets_gene.md`](../../docs/parquet-catalog/datasets/evidence__molecule_targets_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `molecule_targets_gene` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **41,239**; bytes: **1,028,430**; row groups: **1**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155492590166`; CRC32C: `AR1yjQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/molecule_targets_gene.parquet`
# - Destination generation: `1785155492590166`
# - Destination CRC32C: `AR1yjQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__molecule_targets_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__mutation_affects_molecule_response`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/mutation_affects_molecule_response.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__mutation_affects_molecule_response.md`](../../docs/parquet-catalog/datasets/evidence__mutation_affects_molecule_response.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `mutation_affects_molecule_response` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **18,595**; bytes: **864,665**; row groups: **1**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155492906893`; CRC32C: `39T8jw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/mutation_affects_molecule_response.parquet`
# - Destination generation: `1785155492906893`
# - Destination CRC32C: `39T8jw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__mutation_affects_molecule_response.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__mutation_affects_transcript`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/mutation_affects_transcript.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__mutation_affects_transcript.md`](../../docs/parquet-catalog/datasets/evidence__mutation_affects_transcript.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `mutation_affects_transcript` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **2,599,922**; bytes: **199,510,540**; row groups: **22**; schema hash (`arrow-fields-v1`): `858c75d0941ff8256a7878d18c7e3cfb2168b91e634b9ea48f7035592544bbc4`; generation: `1785155493058158`; CRC32C: `hcDMOA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `edge_key` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `evidence_score` | `float` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `extension<arrow.json>` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/mutation_affects_transcript.parquet`
# - Destination generation: `1785155493058158`
# - Destination CRC32C: `hcDMOA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__mutation_affects_transcript.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__mutation_associated_disease`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/mutation_associated_disease.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__mutation_associated_disease.md`](../../docs/parquet-catalog/datasets/evidence__mutation_associated_disease.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `mutation_associated_disease` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **4,656,171**; bytes: **331,005,888**; row groups: **47**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155493231401`; CRC32C: `eSbqYw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/mutation_associated_disease.parquet`
# - Destination generation: `1785155493231401`
# - Destination CRC32C: `eSbqYw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__mutation_associated_disease.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__mutation_associated_gene`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/mutation_associated_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__mutation_associated_gene.md`](../../docs/parquet-catalog/datasets/evidence__mutation_associated_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `mutation_associated_gene` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **535,093**; bytes: **52,033,340**; row groups: **1**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155493582759`; CRC32C: `ghJqEw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/mutation_associated_gene.parquet`
# - Destination generation: `1785155493582759`
# - Destination CRC32C: `ghJqEw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__mutation_associated_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__mutation_associated_phenotype`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/mutation_associated_phenotype.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__mutation_associated_phenotype.md`](../../docs/parquet-catalog/datasets/evidence__mutation_associated_phenotype.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `mutation_associated_phenotype` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **169,005**; bytes: **13,186,402**; row groups: **1**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155493747697`; CRC32C: `OmhXCw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/mutation_associated_phenotype.parquet`
# - Destination generation: `1785155493747697`
# - Destination CRC32C: `OmhXCw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__mutation_associated_phenotype.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__mutation_causes_protein_change`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/mutation_causes_protein_change.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__mutation_causes_protein_change.md`](../../docs/parquet-catalog/datasets/evidence__mutation_causes_protein_change.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `mutation_causes_protein_change` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **177,735**; bytes: **5,872,369**; row groups: **1**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155493902102`; CRC32C: `x1C66Q==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/mutation_causes_protein_change.parquet`
# - Destination generation: `1785155493902102`
# - Destination CRC32C: `x1C66Q==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__mutation_causes_protein_change.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__mutation_in_gene`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/mutation_in_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__mutation_in_gene.md`](../../docs/parquet-catalog/datasets/evidence__mutation_in_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `mutation_in_gene` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **2,599,525**; bytes: **231,527,887**; row groups: **22**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155494069911`; CRC32C: `HqjMHw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/mutation_in_gene.parquet`
# - Destination generation: `1785155494069911`
# - Destination CRC32C: `HqjMHw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__mutation_in_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `evidence__mutation_overlaps_enhancer`
#
# - Canonical URI: `gs://jouvencekb/main/evidence/mutation_overlaps_enhancer.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/evidence__mutation_overlaps_enhancer.md`](../../docs/parquet-catalog/datasets/evidence__mutation_overlaps_enhancer.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Source-level support records for the canonical `mutation_overlaps_enhancer` assertion.
# - Does not mean: Rows are not additional graph edges and evidence row count is not edge count or independent-study count.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **1,664,278**; bytes: **12,608,882**; row groups: **14**; schema hash (`arrow-fields-v1`): `20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e`; generation: `1785155494232678`; CRC32C: `goEUTw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `edge_key` | `string` | `true` |
# | `relation` | `string` | `true` |
# | `x_id` | `string` | `true` |
# | `x_type` | `string` | `true` |
# | `y_id` | `string` | `true` |
# | `y_type` | `string` | `true` |
# | `evidence_type` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `paper_id` | `string` | `true` |
# | `dataset_id` | `string` | `true` |
# | `study_id` | `string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `string` | `true` |
# | `confidence_interval` | `string` | `true` |
# | `predicate` | `string` | `true` |
# | `text_span` | `string` | `true` |
# | `section` | `string` | `true` |
# | `extraction_method` | `string` | `true` |
# | `license` | `string` | `true` |
# | `release` | `string` | `true` |
# | `created_at` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `source_record_id`
# - Linkage: `(relation, x_id, y_id) -> matching edge assertion`, `edge_key -> matching edge assertion`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/evidence/mutation_overlaps_enhancer.parquet`
# - Destination generation: `1785155494232678`
# - Destination CRC32C: `goEUTw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/evidence__mutation_overlaps_enhancer.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `nodes__disease`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/disease.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__disease.md`](../../docs/parquet-catalog/datasets/nodes__disease.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Canonical disease registry keyed in the EFO namespace (example `EFO:0000305`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **41,859**; bytes: **3,569,466**; row groups: **1**; schema hash (`arrow-fields-v1`): `92f5124bfdfb394db16acf3612aaacc8b8615c27ff6dd7a34734f2b975c1d9b5`; generation: `1785155477787675`; CRC32C: `UnDlhQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `legacy_type` | `string` | `true` |
# | `legacy_id` | `string` | `true` |
# | `legacy_index` | `double` | `true` |
# | `source` | `large_string` | `true` |
# | `ncbi_gene_id` | `string` | `true` |
# | `hgnc_id` | `string` | `true` |
# | `uniprot_id` | `string` | `true` |
# | `gene_name` | `string` | `true` |
# | `drugbank_id` | `string` | `true` |
# | `pubchem_cid` | `string` | `true` |
# | `cas_rn` | `string` | `true` |
# | `inchikey` | `string` | `true` |
# | `smiles` | `string` | `true` |
# | `mondo_id` | `large_string` | `true` |
# | `efo_id` | `string` | `true` |
# | `mp_id` | `string` | `true` |
# | `mesh_id` | `large_string` | `true` |
# | `hp_id` | `large_string` | `true` |
# | `omim_id` | `large_string` | `true` |
# | `doid_id` | `large_string` | `true` |
# | `icd10_code` | `large_string` | `true` |
# | `go_id` | `string` | `true` |
# | `kegg_id` | `string` | `true` |
# | `bto_id` | `string` | `true` |
# | `fma_id` | `string` | `true` |
# | `name` | `large_string` | `true` |
# | `description` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/disease.parquet`
# - Destination generation: `1785155477787675`
# - Destination CRC32C: `UnDlhQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__disease.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `nodes__enhancer`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/enhancer.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__enhancer.md`](../../docs/parquet-catalog/datasets/nodes__enhancer.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Canonical enhancer registry keyed in the ENCODE namespace (example `EH38E1516972`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **48,808,144**; bytes: **3,404,993,079**; row groups: **118**; schema hash (`arrow-fields-v1`): `6982f75c970e6f7f14786ce3191831dbb15c4489b1b85270a50642039a18a4e3`; generation: `1785155478101933`; CRC32C: `wYXovg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `chromosome` | `large_string` | `true` |
# | `start` | `int64` | `true` |
# | `end` | `int64` | `true` |
# | `name` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/enhancer.parquet`
# - Destination generation: `1785155478101933`
# - Destination CRC32C: `wYXovg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__enhancer.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `nodes__molecule`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/molecule.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__molecule.md`](../../docs/parquet-catalog/datasets/nodes__molecule.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Canonical molecule registry keyed in the ChEMBL namespace (example `CHEMBL941`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **31,007**; bytes: **1,842,052**; row groups: **1**; schema hash (`arrow-fields-v1`): `c6069b518bb95a97b05fc6198653bd2f262f475cbcd5e247f322ba65a37be0fb`; generation: `1785155478709145`; CRC32C: `gGE+YQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `legacy_type` | `large_string` | `true` |
# | `legacy_id` | `large_string` | `true` |
# | `legacy_index` | `double` | `true` |
# | `source` | `large_string` | `true` |
# | `ncbi_gene_id` | `large_string` | `true` |
# | `hgnc_id` | `double` | `true` |
# | `uniprot_id` | `double` | `true` |
# | `gene_name` | `large_string` | `true` |
# | `drugbank_id` | `large_string` | `true` |
# | `pubchem_cid` | `large_string` | `true` |
# | `cas_rn` | `large_string` | `true` |
# | `inchikey` | `large_string` | `true` |
# | `smiles` | `large_string` | `true` |
# | `mondo_id` | `large_string` | `true` |
# | `efo_id` | `double` | `true` |
# | `mp_id` | `double` | `true` |
# | `mesh_id` | `double` | `true` |
# | `hp_id` | `large_string` | `true` |
# | `omim_id` | `double` | `true` |
# | `doid_id` | `double` | `true` |
# | `icd10_code` | `double` | `true` |
# | `go_id` | `large_string` | `true` |
# | `kegg_id` | `double` | `true` |
# | `bto_id` | `double` | `true` |
# | `fma_id` | `double` | `true` |
# | `name` | `large_string` | `true` |
# | `description` | `large_string` | `true` |
# | `drug_type` | `large_string` | `true` |
# | `is_approved` | `bool` | `true` |
# | `max_clinical_trial_phase` | `large_string` | `true` |
# | `has_been_withdrawn` | `bool` | `true` |
# | `black_box_warning` | `bool` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/molecule.parquet`
# - Destination generation: `1785155478709145`
# - Destination CRC32C: `gGE+YQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__molecule.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `nodes__mutation`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/mutation.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__mutation.md`](../../docs/parquet-catalog/datasets/nodes__mutation.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Canonical mutation registry keyed in the dbSNP namespace (example `rs7412`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **2,589,509**; bytes: **89,685,283**; row groups: **2**; schema hash (`arrow-fields-v1`): `309adcafe428b4e1e19d1a1c061362407ec177ed7c39f7215483ac18fc0ac89c`; generation: `1785155478914362`; CRC32C: `Ka/IoA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `hgvs` | `large_string` | `true` |
# | `clinvar_id` | `large_string` | `true` |
# | `gnomad_id` | `large_string` | `true` |
# | `name` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/mutation.parquet`
# - Destination generation: `1785155478914362`
# - Destination CRC32C: `Ka/IoA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__mutation.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`
#
#
# ### Output `nodes__paper`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/paper.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__paper.md`](../../docs/parquet-catalog/datasets/nodes__paper.md)
# - Replay level: **`provenance-gap`**
# - Meaning: Canonical paper registry keyed in the PubMed namespace (example `PMID:12345678`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable
#
# - `https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **2,958,199**; bytes: **26,231,759**; row groups: **1**; schema hash (`arrow-fields-v1`): `e39b928ac80d3d20c0df3b9dee5661403644bb07532b8175960e8f5e8b30e3a2`; generation: `1785155479308410`; CRC32C: `7S3Tng==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `doi` | `large_string` | `true` |
# | `pmc_id` | `large_string` | `true` |
# | `arxiv_id` | `large_string` | `true` |
# | `year` | `int64` | `true` |
# | `source` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.
#
# **Cleaning, normalization, transformations and filters.** Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.
#
# **Problems encountered and decisions.** The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.
#
# Known gaps: `current builder`, `exact accepted source-to-object lineage`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/paper.parquet`
# - Destination generation: `1785155479308410`
# - Destination CRC32C: `7S3Tng==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__paper.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/07_opentargets_edges_and_evidence.ipynb`
# - `reproduce/26_source_reproduction_index.ipynb`
# - `manage_db/ingest_opentargets.py`

# %% [markdown]
# ## Offline bounded contract check
#
# This cell uses only the embedded frozen lineage record.

# %%
import hashlib
import json

RECORDS = json.loads(r'''[{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/disease_associated_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__disease_associated_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"double","name":"score","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__disease_associated_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Gene→disease direction for causal/directed disease association; source/evidence rows preserve predicate, score, and provenance.","migration_receipt":{"action":"copied","destination_crc32c":"BeQhmg==","destination_generation":"1785155482007624","source":"kg/v2/edges/disease_associated_gene.parquet","source_generation":"1781862037334855","verified":true},"name":"disease_associated_gene","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":314067,"crc32c_base64":"BeQhmg==","generation":"1785155482007624","md5_base64":"7FWBVKWpVNDyRY0Z5knChA==","row_groups":1,"rows":83339,"schema_hash":"35fa300d9883a453a33684ed2798242febf297771190efa79b0f0a08f5ea6b1a","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/disease_associated_protein.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__disease_associated_protein.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"large_string","name":"causal_mechanisms","nullable":true},{"dtype":"large_string","name":"mechanism_status","nullable":true},{"dtype":"large_string","name":"effect_directions","nullable":true},{"dtype":"large_string","name":"effect_direction_status","nullable":true},{"dtype":"large_string","name":"inheritance_modes","nullable":true},{"dtype":"large_string","name":"causal_support_level","nullable":true},{"dtype":"int64","name":"evidence_count","nullable":true},{"dtype":"large_string","name":"causal_feature_contract_version","nullable":true},{"dtype":"bool","name":"both_operands_known","nullable":true},{"dtype":"large_string","name":"disease_operand_contract_version","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__disease_associated_protein.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Protein→disease direction for protein-native causal/directed disease association; use only protein-specific evidence.","migration_receipt":{"action":"copied","destination_crc32c":"FAnzhg==","destination_generation":"1785155482165594","source":"kg/v2/edges/disease_associated_protein.parquet","source_generation":"1784726656613727","verified":true},"name":"disease_associated_protein","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":59222,"crc32c_base64":"FAnzhg==","generation":"1785155482165594","md5_base64":"ZdTFrVZqZcYsDTRExLiu0g==","row_groups":1,"rows":3243,"schema_hash":"532b5b19522e5941c98a494849263d9e033b4f9b638076a27f88b9d79327bcf5","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/disease_manifests_in_tissue.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__disease_manifests_in_tissue.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__disease_manifests_in_tissue.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Pathology annotation","migration_receipt":{"action":"copied","destination_crc32c":"u8X16w==","destination_generation":"1785155482824533","source":"kg/v2/edges/disease_manifests_in_tissue.parquet","source_generation":"1782325469191009","verified":true},"name":"disease_manifests_in_tissue","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":5416,"crc32c_base64":"u8X16w==","generation":"1785155482824533","md5_base64":"InWrVFw5VmnbbQJ1DGbeSQ==","row_groups":1,"rows":19,"schema_hash":"078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/enhancer_regulates_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__enhancer_regulates_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"double","name":"e2g_score","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__enhancer_regulates_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"ENCODE-rE2G composite enhancer-to-gene prediction; preserve biosample, assay feature scores, distance, study, and model score in edge/evidence metadata.","migration_receipt":{"action":"copied","destination_crc32c":"MNF0ow==","destination_generation":"1785155483362416","source":"kg/v2/edges/enhancer_regulates_gene.parquet","source_generation":"1781481654900481","verified":true},"name":"enhancer_regulates_gene","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":1997157871,"crc32c_base64":"MNF0ow==","generation":"1785155483362416","md5_base64":"wZPnYXmcbGyQfcAdGioZgw==","row_groups":118,"rows":48808144,"schema_hash":"b619587ee4f7bf9df888bf6a2506a2429369e8b640ac03020754fbf520a2933a","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/gene_interacts_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__gene_interacts_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"display_relation","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__gene_interacts_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Keep broad for current OpenTargets interaction because canonical endpoints are gene-level; preserve source-specific evidence metadata and do not project text_span product IDs into protein/transcript/TF/enhancer relations.","migration_receipt":{"action":"copied","destination_crc32c":"uOngJA==","destination_generation":"1785155483887629","source":"kg/v2/edges/gene_interacts_gene.parquet","source_generation":"1781803599193107","verified":true},"name":"gene_interacts_gene","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":36907950,"crc32c_base64":"uOngJA==","generation":"1785155483887629","md5_base64":"ToVuKhLC7KIly8SQwHZeHQ==","row_groups":61,"rows":7424037,"schema_hash":"7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/molecule_targets_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__molecule_targets_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"display_relation","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"string","name":"action_type","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__molecule_targets_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Drug/compound target relation for sources whose native target endpoint is a gene or OpenTargets Ensembl target ID; preserve source MoA/action metadata in evidence.","migration_receipt":{"action":"copied","destination_crc32c":"D5jLtA==","destination_generation":"1785155486721297","source":"kg/v2/edges/molecule_targets_gene.parquet","source_generation":"1781796932474539","verified":true},"name":"molecule_targets_gene","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":238792,"crc32c_base64":"D5jLtA==","generation":"1785155486721297","md5_base64":"1MKTWfaX8LiHeQa3Xuxhtg==","row_groups":1,"rows":41239,"schema_hash":"bfee26da8e6a4b1b5da85c6da9fb39c9ce5106d4ab68cd105185873a6438b565","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/mutation_affects_molecule_response.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__mutation_affects_molecule_response.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"large_string","name":"pgx_category","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__mutation_affects_molecule_response.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Pharmacogenomics","migration_receipt":{"action":"copied","destination_crc32c":"Ha05SQ==","destination_generation":"1785155487091862","source":"kg/v2/edges/mutation_affects_molecule_response.parquet","source_generation":"1781011439757450","verified":true},"name":"mutation_affects_molecule_response","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":45989,"crc32c_base64":"Ha05SQ==","generation":"1785155487091862","md5_base64":"ZC0gmmx1YgyBb7nzIZwimg==","row_groups":1,"rows":4866,"schema_hash":"3998ac659feaaf75a1772fe1a5294a71cb814ad3b0c539c6de85ff37b479dadb","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/mutation_affects_transcript.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__mutation_affects_transcript.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"display_relation","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"int32","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__mutation_affects_transcript.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Transcript-level consequence such as splicing/UTR/coding-transcript effect; canonical promoted/review-accepted from OpenTargets VEP transcriptConsequences with canonical mutation/transcript endpoints and allowed transcript-local consequence policy","migration_receipt":{"action":"copied","destination_crc32c":"GuUaHw==","destination_generation":"1785155487269758","source":"kg/v2/edges/mutation_affects_transcript.parquet","source_generation":"1782244419732373","verified":true},"name":"mutation_affects_transcript","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":20266519,"crc32c_base64":"GuUaHw==","generation":"1785155487269758","md5_base64":"/37msg3JvBxsQucaRBrVng==","row_groups":22,"rows":2599922,"schema_hash":"b4f1a985561189e67ebff6aad1255198b4799fb5196a89f45fd68a78e6500f43","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/mutation_associated_disease.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__mutation_associated_disease.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"double","name":"score","nullable":true},{"dtype":"large_string","name":"datatype","nullable":true},{"dtype":"string","name":"studyLocusId","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__mutation_associated_disease.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"GWAS / ClinVar / OpenTargets known-variant disease association; canonical edge exists, evidence backfill remains next tranche","migration_receipt":{"action":"copied","destination_crc32c":"o751XA==","destination_generation":"1785155487470336","source":"kg/v2/edges/mutation_associated_disease.parquet","source_generation":"1781177669019995","verified":true},"name":"mutation_associated_disease","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":89034605,"crc32c_base64":"o751XA==","generation":"1785155487470336","md5_base64":"zLGYtlXPzeoskJ3G8Bap5w==","row_groups":5,"rows":4656171,"schema_hash":"0e2d3dd1958960bac40344ecb41b055465417e6869cf940e1fc72c0dc9aea513","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/mutation_associated_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__mutation_associated_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"double","name":"score","nullable":true},{"dtype":"large_string","name":"datatype","nullable":true},{"dtype":"large_string","name":"studyLocusId","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__mutation_associated_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Statistical/functional locus-to-gene prediction (for example OpenTargets L2G/GWAS); canonical promoted GWAS/L2G relation with evidence support","migration_receipt":{"action":"copied","destination_crc32c":"lrFdnQ==","destination_generation":"1785155487740464","source":"kg/v2/edges/mutation_associated_gene.parquet","source_generation":"1781115246447606","verified":true},"name":"mutation_associated_gene","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":22829668,"crc32c_base64":"lrFdnQ==","generation":"1785155487740464","md5_base64":"lc6K2XGOY4lRgR92i0sHCQ==","row_groups":200,"rows":535093,"schema_hash":"d05a48086562da908fdea3808e439cfd079757260e796024fb4140ce4bdc2a16","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/mutation_associated_phenotype.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__mutation_associated_phenotype.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__mutation_associated_phenotype.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"OpenTargets EVA/ClinVar HP-only mutation→phenotype association; include all clinical-significance classes and preserve the exact assertion in edge/evidence metadata rather than restricting the relation to pathogenic/likely pathogenic.","migration_receipt":{"action":"copied","destination_crc32c":"BZw6Sw==","destination_generation":"1785155487890849","source":"kg/v2/edges/mutation_associated_phenotype.parquet","source_generation":"1781862015591483","verified":true},"name":"mutation_associated_phenotype","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":1262716,"crc32c_base64":"BZw6Sw==","generation":"1785155487890849","md5_base64":"2bdBcneMYEvOIdNdQ6clWQ==","row_groups":1,"rows":164406,"schema_hash":"078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/mutation_causes_protein_change.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__mutation_causes_protein_change.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"large_string","name":"amino_acid_change","nullable":true},{"dtype":"large_string","name":"uniprot_id","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__mutation_causes_protein_change.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Amino acid change with ENSP protein endpoint; canonical OpenTargets protein-change edge and evidence files exist","migration_receipt":{"action":"copied","destination_crc32c":"9nwQNQ==","destination_generation":"1785155488079071","source":"kg/v2/edges/mutation_causes_protein_change.parquet","source_generation":"1781115243890755","verified":true},"name":"mutation_causes_protein_change","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":2640740,"crc32c_base64":"9nwQNQ==","generation":"1785155488079071","md5_base64":"5TRtuQuYxgHv8QrjqzURew==","row_groups":1,"rows":177735,"schema_hash":"b8751beb2caa6055e55f3028c86c221a962942496f68e8dfb1ba920bfd69b828","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/mutation_in_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__mutation_in_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"display_relation","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__mutation_in_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Physical/genomic containment only; do not use for L2G/GWAS association or OpenTargets L2G targetId smoke output","migration_receipt":{"action":"copied","destination_crc32c":"fs0JZg==","destination_generation":"1785155488238195","source":"kg/v2/edges/mutation_in_gene.parquet","source_generation":"1782322585154580","verified":true},"name":"mutation_in_gene","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":19913850,"crc32c_base64":"fs0JZg==","generation":"1785155488238195","md5_base64":"rdOXaLA95h9W3Kg6yN+qYg==","row_groups":22,"rows":2599525,"schema_hash":"7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/mutation_overlaps_enhancer.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__mutation_overlaps_enhancer.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"display_relation","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__mutation_overlaps_enhancer.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Variant-enhancer interval overlap: coordinate overlap alone remains context/support-only, while the reviewed non-context-support-gated candidate from t_73c67c1b was canonical promoted/review-required by t_00551bc3 with evidence support and leakage policy. This remains associative/indirect; stronger allele-specific regulatory or enhancer-activity evidence is preferred, and downstream disease/gene support is not by itself proof of enhancer perturbation.","migration_receipt":{"action":"copied","destination_crc32c":"H0Gguw==","destination_generation":"1785155488400365","source":"kg/v2/edges/mutation_overlaps_enhancer.parquet","source_generation":"1782342624393775","verified":true},"name":"mutation_overlaps_enhancer","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":3122917,"crc32c_base64":"H0Gguw==","generation":"1785155488400365","md5_base64":"Oj09RGOE0vq49clIviaNVw==","row_groups":14,"rows":1664278,"schema_hash":"7dee93bb2a4f4d78d9cc253aa6202439ce98e8c3f91477c9258d3b51d5f77fe2","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/disease_associated_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__disease_associated_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"edge_key","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"evidence_type","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"large_string","name":"source_dataset","nullable":true},{"dtype":"large_string","name":"source_record_id","nullable":true},{"dtype":"large_string","name":"paper_id","nullable":true},{"dtype":"large_string","name":"dataset_id","nullable":true},{"dtype":"large_string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"large_string","name":"direction","nullable":true},{"dtype":"large_string","name":"confidence_interval","nullable":true},{"dtype":"large_string","name":"predicate","nullable":true},{"dtype":"large_string","name":"text_span","nullable":true},{"dtype":"large_string","name":"section","nullable":true},{"dtype":"large_string","name":"extraction_method","nullable":true},{"dtype":"large_string","name":"license","nullable":true},{"dtype":"large_string","name":"release","nullable":true},{"dtype":"large_string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__disease_associated_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `disease_associated_gene` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"sL6BUQ==","destination_generation":"1785155491117311","source":"kg/v2/evidence/disease_associated_gene.parquet","source_generation":"1781862037978269","verified":true},"name":"disease_associated_gene","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":90231,"crc32c_base64":"sL6BUQ==","generation":"1785155491117311","md5_base64":"BkME69pcfFeoGEDT6IvD8g==","row_groups":1,"rows":2928,"schema_hash":"0beeb15b80896c37055bcab526fc11d4376ed2762facadbc59b012f280d8b03c","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/disease_associated_protein.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__disease_associated_protein.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"edge_key","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"evidence_type","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"large_string","name":"source_dataset","nullable":true},{"dtype":"large_string","name":"source_record_id","nullable":true},{"dtype":"large_string","name":"paper_id","nullable":true},{"dtype":"large_string","name":"dataset_id","nullable":true},{"dtype":"large_string","name":"study_id","nullable":true},{"dtype":"large_string","name":"evidence_score","nullable":true},{"dtype":"large_string","name":"effect_size","nullable":true},{"dtype":"large_string","name":"p_value","nullable":true},{"dtype":"large_string","name":"direction","nullable":true},{"dtype":"large_string","name":"confidence_interval","nullable":true},{"dtype":"large_string","name":"predicate","nullable":true},{"dtype":"large_string","name":"text_span","nullable":true},{"dtype":"large_string","name":"section","nullable":true},{"dtype":"large_string","name":"extraction_method","nullable":true},{"dtype":"large_string","name":"license","nullable":true},{"dtype":"large_string","name":"release","nullable":true},{"dtype":"large_string","name":"created_at","nullable":true},{"dtype":"large_string","name":"uniprot_accession","nullable":true},{"dtype":"large_string","name":"uniprot_entry_id","nullable":true},{"dtype":"large_string","name":"ensp_id","nullable":true},{"dtype":"large_string","name":"isoform","nullable":true},{"dtype":"large_string","name":"disease_source_id","nullable":true},{"dtype":"large_string","name":"disease_name","nullable":true},{"dtype":"large_string","name":"disease_acronym","nullable":true},{"dtype":"large_string","name":"disease_description","nullable":true},{"dtype":"large_string","name":"variant_ft_id","nullable":true},{"dtype":"large_string","name":"aa_change","nullable":true},{"dtype":"large_string","name":"variant_category","nullable":true},{"dtype":"large_string","name":"dbsnp_id","nullable":true},{"dtype":"large_string","name":"eco_codes","nullable":true},{"dtype":"large_string","name":"pmids","nullable":true},{"dtype":"large_string","name":"mapping_confidence","nullable":true},{"dtype":"large_string","name":"mapping_method","nullable":true},{"dtype":"large_string","name":"source_native_endpoint_policy","nullable":true},{"dtype":"large_string","name":"materialization_assertion_id","nullable":true},{"dtype":"large_string","name":"source_assertion_id","nullable":true},{"dtype":"large_string","name":"normalized_causal_mechanism","nullable":true},{"dtype":"large_string","name":"normalized_effect_direction","nullable":true},{"dtype":"large_string","name":"normalized_inheritance_mode","nullable":true},{"dtype":"large_string","name":"normalized_clinical_significance","nullable":true},{"dtype":"large_string","name":"normalized_causal_support_level","nullable":true},{"dtype":"bool","name":"materialization_assertion_conflict","nullable":true},{"dtype":"large_string","name":"causal_feature_contract_version","nullable":true},{"dtype":"large_string","name":"operand_source_family","nullable":true},{"dtype":"large_string","name":"operand_source_record_id","nullable":true},{"dtype":"large_string","name":"operand_source_release","nullable":true},{"dtype":"large_string","name":"operand_mapping_path","nullable":true},{"dtype":"large_string","name":"mechanism_operand","nullable":true},{"dtype":"large_string","name":"disease_direction_operand","nullable":true},{"dtype":"large_string","name":"operand_confidence","nullable":true},{"dtype":"large_string","name":"operand_support_class","nullable":true},{"dtype":"large_string","name":"operand_reject_reason","nullable":true},{"dtype":"bool","name":"mechanism_operand_conflict","nullable":true},{"dtype":"bool","name":"disease_direction_operand_conflict","nullable":true},{"dtype":"large_string","name":"disease_operand_contract_version","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__disease_associated_protein.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `disease_associated_protein` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"+BucBA==","destination_generation":"1785155491357899","source":"kg/v2/evidence/disease_associated_protein.parquet","source_generation":"1784726654659180","verified":true},"name":"disease_associated_protein","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":4093409,"crc32c_base64":"+BucBA==","generation":"1785155491357899","md5_base64":"Ts29bjHI3t3DNGxzSq7Q0g==","row_groups":1,"rows":35839,"schema_hash":"924be33fcb96d1412b4aeda7c3d31fd17d6615dbd560d58c6ac32c4077736254","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/disease_manifests_in_tissue.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__disease_manifests_in_tissue.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__disease_manifests_in_tissue.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `disease_manifests_in_tissue` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"IIwEJw==","destination_generation":"1785155491791763","source":"kg/v2/evidence/disease_manifests_in_tissue.parquet","source_generation":"1782325470549824","verified":true},"name":"disease_manifests_in_tissue","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":22231,"crc32c_base64":"IIwEJw==","generation":"1785155491791763","md5_base64":"lNf56ZhTdB/0T2CaaCNvZw==","row_groups":1,"rows":29,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/enhancer_regulates_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__enhancer_regulates_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__enhancer_regulates_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `enhancer_regulates_gene` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"N3XR1g==","destination_generation":"1785155492052917","source":"kg/v2/evidence/enhancer_regulates_gene.parquet","source_generation":"1781801628963725","verified":true},"name":"enhancer_regulates_gene","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":4788517448,"crc32c_base64":"N3XR1g==","generation":"1785155492052917","md5_base64":"Z7WeXB6PZ4th3uMxO/i0tg==","row_groups":398,"rows":48810390,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/gene_interacts_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__gene_interacts_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__gene_interacts_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `gene_interacts_gene` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"NdyPtg==","destination_generation":"1785155492268116","source":"kg/v2/evidence/gene_interacts_gene.parquet","source_generation":"1781803599380343","verified":true},"name":"gene_interacts_gene","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":483161330,"crc32c_base64":"NdyPtg==","generation":"1785155492268116","md5_base64":"g7ELzr9UQHS0rM0U+sHkxA==","row_groups":117,"rows":14336594,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/molecule_targets_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__molecule_targets_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__molecule_targets_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `molecule_targets_gene` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"AR1yjQ==","destination_generation":"1785155492590166","source":"kg/v2/evidence/molecule_targets_gene.parquet","source_generation":"1782079495600450","verified":true},"name":"molecule_targets_gene","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":1028430,"crc32c_base64":"AR1yjQ==","generation":"1785155492590166","md5_base64":"4uQXe3q9QOQT7PCZ0sOyjQ==","row_groups":1,"rows":41239,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/mutation_affects_molecule_response.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__mutation_affects_molecule_response.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__mutation_affects_molecule_response.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `mutation_affects_molecule_response` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"39T8jw==","destination_generation":"1785155492906893","source":"kg/v2/evidence/mutation_affects_molecule_response.parquet","source_generation":"1781521354803508","verified":true},"name":"mutation_affects_molecule_response","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":864665,"crc32c_base64":"39T8jw==","generation":"1785155492906893","md5_base64":"3k8hM0c8GsOhjEdZkefskg==","row_groups":1,"rows":18595,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/mutation_affects_transcript.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__mutation_affects_transcript.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"float","name":"evidence_score","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"extension<arrow.json>","name":"text_span","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__mutation_affects_transcript.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `mutation_affects_transcript` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"hcDMOA==","destination_generation":"1785155493058158","source":"kg/v2/evidence/mutation_affects_transcript.parquet","source_generation":"1782244424766297","verified":true},"name":"mutation_affects_transcript","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":199510540,"crc32c_base64":"hcDMOA==","generation":"1785155493058158","md5_base64":null,"row_groups":22,"rows":2599922,"schema_hash":"858c75d0941ff8256a7878d18c7e3cfb2168b91e634b9ea48f7035592544bbc4","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/mutation_associated_disease.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__mutation_associated_disease.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__mutation_associated_disease.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `mutation_associated_disease` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"eSbqYw==","destination_generation":"1785155493231401","source":"kg/v2/evidence/mutation_associated_disease.parquet","source_generation":"1781623545995654","verified":true},"name":"mutation_associated_disease","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":331005888,"crc32c_base64":"eSbqYw==","generation":"1785155493231401","md5_base64":"nUbbzdDlFhgNflu8YIeHSw==","row_groups":47,"rows":4656171,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/mutation_associated_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__mutation_associated_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__mutation_associated_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `mutation_associated_gene` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"ghJqEw==","destination_generation":"1785155493582759","source":"kg/v2/evidence/mutation_associated_gene.parquet","source_generation":"1781523166198675","verified":true},"name":"mutation_associated_gene","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":52033340,"crc32c_base64":"ghJqEw==","generation":"1785155493582759","md5_base64":"aIoL0OQAKizvffOox+O5Ug==","row_groups":1,"rows":535093,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/mutation_associated_phenotype.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__mutation_associated_phenotype.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__mutation_associated_phenotype.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `mutation_associated_phenotype` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"OmhXCw==","destination_generation":"1785155493747697","source":"kg/v2/evidence/mutation_associated_phenotype.parquet","source_generation":"1781862016276390","verified":true},"name":"mutation_associated_phenotype","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":13186402,"crc32c_base64":"OmhXCw==","generation":"1785155493747697","md5_base64":"FgfRddqNuw1+R8pwT1puUg==","row_groups":1,"rows":169005,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/mutation_causes_protein_change.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__mutation_causes_protein_change.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__mutation_causes_protein_change.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `mutation_causes_protein_change` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"x1C66Q==","destination_generation":"1785155493902102","source":"kg/v2/evidence/mutation_causes_protein_change.parquet","source_generation":"1781523184471410","verified":true},"name":"mutation_causes_protein_change","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":5872369,"crc32c_base64":"x1C66Q==","generation":"1785155493902102","md5_base64":"Vj/Ddb46kKDPeSg7e0w3CQ==","row_groups":1,"rows":177735,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/mutation_in_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__mutation_in_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__mutation_in_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `mutation_in_gene` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"HqjMHw==","destination_generation":"1785155494069911","source":"kg/v2/evidence/mutation_in_gene.parquet","source_generation":"1782322590641106","verified":true},"name":"mutation_in_gene","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":231527887,"crc32c_base64":"HqjMHw==","generation":"1785155494069911","md5_base64":null,"row_groups":22,"rows":2599525,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/evidence/mutation_overlaps_enhancer.parquet","catalog_page":"docs/parquet-catalog/datasets/evidence__mutation_overlaps_enhancer.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"edge_key","nullable":true},{"dtype":"string","name":"relation","nullable":true},{"dtype":"string","name":"x_id","nullable":true},{"dtype":"string","name":"x_type","nullable":true},{"dtype":"string","name":"y_id","nullable":true},{"dtype":"string","name":"y_type","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"paper_id","nullable":true},{"dtype":"string","name":"dataset_id","nullable":true},{"dtype":"string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"string","name":"direction","nullable":true},{"dtype":"string","name":"confidence_interval","nullable":true},{"dtype":"string","name":"predicate","nullable":true},{"dtype":"string","name":"text_span","nullable":true},{"dtype":"string","name":"section","nullable":true},{"dtype":"string","name":"extraction_method","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"release","nullable":true},{"dtype":"string","name":"created_at","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["source_record_id"],"linkage":["(relation, x_id, y_id) -> matching edge assertion","edge_key -> matching edge assertion"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"evidence","links":["docs/parquet-catalog/datasets/evidence__mutation_overlaps_enhancer.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Source-level support records for the canonical `mutation_overlaps_enhancer` assertion.","migration_receipt":{"action":"copied","destination_crc32c":"goEUTw==","destination_generation":"1785155494232678","source":"kg/v2/evidence/mutation_overlaps_enhancer.parquet","source_generation":"1782342625133072","verified":true},"name":"mutation_overlaps_enhancer","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Rows are not additional graph edges and evidence row count is not edge count or independent-study count.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":12608882,"crc32c_base64":"goEUTw==","generation":"1785155494232678","md5_base64":"lF7nKMKbJAiJBDCKgf8Fag==","row_groups":14,"rows":1664278,"schema_hash":"20807dd887b30d2157cc588a675e771138aa671adc65199e830413cfafa3a28e","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/disease.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__disease.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"string","name":"legacy_type","nullable":true},{"dtype":"string","name":"legacy_id","nullable":true},{"dtype":"double","name":"legacy_index","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"string","name":"ncbi_gene_id","nullable":true},{"dtype":"string","name":"hgnc_id","nullable":true},{"dtype":"string","name":"uniprot_id","nullable":true},{"dtype":"string","name":"gene_name","nullable":true},{"dtype":"string","name":"drugbank_id","nullable":true},{"dtype":"string","name":"pubchem_cid","nullable":true},{"dtype":"string","name":"cas_rn","nullable":true},{"dtype":"string","name":"inchikey","nullable":true},{"dtype":"string","name":"smiles","nullable":true},{"dtype":"large_string","name":"mondo_id","nullable":true},{"dtype":"string","name":"efo_id","nullable":true},{"dtype":"string","name":"mp_id","nullable":true},{"dtype":"large_string","name":"mesh_id","nullable":true},{"dtype":"large_string","name":"hp_id","nullable":true},{"dtype":"large_string","name":"omim_id","nullable":true},{"dtype":"large_string","name":"doid_id","nullable":true},{"dtype":"large_string","name":"icd10_code","nullable":true},{"dtype":"string","name":"go_id","nullable":true},{"dtype":"string","name":"kegg_id","nullable":true},{"dtype":"string","name":"bto_id","nullable":true},{"dtype":"string","name":"fma_id","nullable":true},{"dtype":"large_string","name":"name","nullable":true},{"dtype":"string","name":"description","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__disease.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Canonical disease registry keyed in the EFO namespace (example `EFO:0000305`).","migration_receipt":{"action":"copied","destination_crc32c":"UnDlhQ==","destination_generation":"1785155477787675","source":"kg/v2/nodes/disease.parquet","source_generation":"1781177660230499","verified":true},"name":"disease","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":3569466,"crc32c_base64":"UnDlhQ==","generation":"1785155477787675","md5_base64":"spWhpZni5HcR6NgWJRcgBw==","row_groups":1,"rows":41859,"schema_hash":"92f5124bfdfb394db16acf3612aaacc8b8615c27ff6dd7a34734f2b975c1d9b5","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/enhancer.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__enhancer.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"large_string","name":"chromosome","nullable":true},{"dtype":"int64","name":"start","nullable":true},{"dtype":"int64","name":"end","nullable":true},{"dtype":"large_string","name":"name","nullable":true},{"dtype":"large_string","name":"source","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__enhancer.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Canonical enhancer registry keyed in the ENCODE namespace (example `EH38E1516972`).","migration_receipt":{"action":"copied","destination_crc32c":"wYXovg==","destination_generation":"1785155478101933","source":"kg/v2/nodes/enhancer.parquet","source_generation":"1781481603774953","verified":true},"name":"enhancer","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":3404993079,"crc32c_base64":"wYXovg==","generation":"1785155478101933","md5_base64":"AM0+bRM0dLsnMu+o5ADVbg==","row_groups":118,"rows":48808144,"schema_hash":"6982f75c970e6f7f14786ce3191831dbb15c4489b1b85270a50642039a18a4e3","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/molecule.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__molecule.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"large_string","name":"legacy_type","nullable":true},{"dtype":"large_string","name":"legacy_id","nullable":true},{"dtype":"double","name":"legacy_index","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"large_string","name":"ncbi_gene_id","nullable":true},{"dtype":"double","name":"hgnc_id","nullable":true},{"dtype":"double","name":"uniprot_id","nullable":true},{"dtype":"large_string","name":"gene_name","nullable":true},{"dtype":"large_string","name":"drugbank_id","nullable":true},{"dtype":"large_string","name":"pubchem_cid","nullable":true},{"dtype":"large_string","name":"cas_rn","nullable":true},{"dtype":"large_string","name":"inchikey","nullable":true},{"dtype":"large_string","name":"smiles","nullable":true},{"dtype":"large_string","name":"mondo_id","nullable":true},{"dtype":"double","name":"efo_id","nullable":true},{"dtype":"double","name":"mp_id","nullable":true},{"dtype":"double","name":"mesh_id","nullable":true},{"dtype":"large_string","name":"hp_id","nullable":true},{"dtype":"double","name":"omim_id","nullable":true},{"dtype":"double","name":"doid_id","nullable":true},{"dtype":"double","name":"icd10_code","nullable":true},{"dtype":"large_string","name":"go_id","nullable":true},{"dtype":"double","name":"kegg_id","nullable":true},{"dtype":"double","name":"bto_id","nullable":true},{"dtype":"double","name":"fma_id","nullable":true},{"dtype":"large_string","name":"name","nullable":true},{"dtype":"large_string","name":"description","nullable":true},{"dtype":"large_string","name":"drug_type","nullable":true},{"dtype":"bool","name":"is_approved","nullable":true},{"dtype":"large_string","name":"max_clinical_trial_phase","nullable":true},{"dtype":"bool","name":"has_been_withdrawn","nullable":true},{"dtype":"bool","name":"black_box_warning","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__molecule.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Canonical molecule registry keyed in the ChEMBL namespace (example `CHEMBL941`).","migration_receipt":{"action":"copied","destination_crc32c":"gGE+YQ==","destination_generation":"1785155478709145","source":"kg/v2/nodes/molecule.parquet","source_generation":"1781012112292838","verified":true},"name":"molecule","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":1842052,"crc32c_base64":"gGE+YQ==","generation":"1785155478709145","md5_base64":"Sxyi0r/yrO/Gap01XMawZw==","row_groups":1,"rows":31007,"schema_hash":"c6069b518bb95a97b05fc6198653bd2f262f475cbcd5e247f322ba65a37be0fb","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/mutation.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__mutation.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"large_string","name":"hgvs","nullable":true},{"dtype":"large_string","name":"clinvar_id","nullable":true},{"dtype":"large_string","name":"gnomad_id","nullable":true},{"dtype":"large_string","name":"name","nullable":true},{"dtype":"large_string","name":"source","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__mutation.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Canonical mutation registry keyed in the dbSNP namespace (example `rs7412`).","migration_receipt":{"action":"copied","destination_crc32c":"Ka/IoA==","destination_generation":"1785155478914362","source":"kg/v2/nodes/mutation.parquet","source_generation":"1781115241845253","verified":true},"name":"mutation","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":89685283,"crc32c_base64":"Ka/IoA==","generation":"1785155478914362","md5_base64":"IlXuascsr6lsWOT7OUcdoA==","row_groups":2,"rows":2589509,"schema_hash":"309adcafe428b4e1e19d1a1c061362407ec177ed7c39f7215483ac18fc0ac89c","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/paper.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__paper.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"large_string","name":"doi","nullable":true},{"dtype":"large_string","name":"pmc_id","nullable":true},{"dtype":"large_string","name":"arxiv_id","nullable":true},{"dtype":"int64","name":"year","nullable":true},{"dtype":"large_string","name":"source","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__paper.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/07_opentargets_edges_and_evidence.ipynb","reproduce/26_source_reproduction_index.ipynb","manage_db/ingest_opentargets.py"],"mappings_and_joins":"Normalize release-pinned ENSG/ENST/ENSP, ChEMBL, EFO, HP and variant identifiers; resolve endpoints against canonical typed node tables before accepting assertions.","meaning":"Canonical paper registry keyed in the PubMed namespace (example `PMID:12345678`).","migration_receipt":{"action":"copied","destination_crc32c":"7S3Tng==","destination_generation":"1785155479308410","source":"kg/v2/nodes/paper.parquet","source_generation":"1780923392822057","verified":true},"name":"paper","native_inputs":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"native_source":["https://ftp.ebi.ac.uk/pub/databases/opentargets/platform/26.03/output/etl/parquet/"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"opentargets","problems_and_decisions":"The current code and release endpoint remain, but the exact accepted raw Open Targets snapshot is not retained under raw/ and per-table historical commands/receipts are incomplete.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","exact accepted source-to-object lineage","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":26231759,"crc32c_base64":"7S3Tng==","generation":"1785155479308410","md5_base64":"/r9faeF1qZca9h0DB3K8sA==","row_groups":1,"rows":2958199,"schema_hash":"e39b928ac80d3d20c0df3b9dee5661403644bb07532b8175960e8f5e8b30e3a2","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Quarantine unmapped or ambiguous endpoints and unsupported predicates; never project gene endpoints to proteins or convert association evidence into causal assertions.","rebuild_command_evidenced":false,"release":"Open Targets Platform 26.03; ENCODE rE2G snapshot bundled in that release where applicable","replay_level":"provenance-gap","reproduce_notebook":"notebooks/reproduce/opentargets_associations.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"provenance-gap","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"opentargets","source_family_label":"Open Targets Platform 26.03 and bundled ENCODE rE2G","transformations_and_filters":"Select source-native datasets, normalize endpoint IDs and predicates, retain scores/context in evidence, and emit broad graph assertions separately from source support rows."}]''')

def require(condition, message):
    if not condition:
        raise RuntimeError(message)

for RECORD in RECORDS:
    require(RECORD["canonical_uri"] == "gs://jouvencekb/main/" + ("embeddings" if RECORD["layer"] == "embedding" else RECORD["layer"]) + "/" + RECORD["name"] + ".parquet", "canonical URI/identity mismatch")
    require(RECORD["replay_level"] in ['documented-not-replayed', 'fully-replayable', 'historical-builder-only', 'provenance-gap'], "unsupported replay level")
    require(RECORD["qc"]["rows"] >= 0, "negative expected row count")
    require(len(RECORD["qc"]["schema_hash"]) == 64, "invalid schema hash")
    require(RECORD["migration_receipt"]["verified"] is True, "migration receipt is not verified")
    require(bool(RECORD["fields"]), "empty expected schema")
summary = {
    "pipeline_family": RECORDS[0]["pipeline_family"],
    "output_count": len(RECORDS),
    "identities": [record["layer"] + "__" + record["name"] for record in RECORDS],
}
summary

# %% [markdown]
# ## Optional bounded live canonical footer check
#
# This cell is skipped unless the caller explicitly opts in.

# %%
import os

if os.environ.get("JOUVENCE_LIVE_GCS") != "1":
    live_result = {"status": "SKIPPED", "reason": "set JOUVENCE_LIVE_GCS=1 and caller-owned JOUVENCE_BILLING_PROJECT"}
else:
    import gcsfs
    import pyarrow.parquet as pq

    billing_project = os.environ.get("JOUVENCE_BILLING_PROJECT")
    if not billing_project:
        raise RuntimeError("JOUVENCE_BILLING_PROJECT is required for requester-pays live verification")
    fs = gcsfs.GCSFileSystem(project=billing_project, requester_pays=billing_project, version_aware=True)
    if not fs.version_aware:
        raise RuntimeError("version-aware GCS reads are required")
    selected_id = os.environ.get("JOUVENCE_OUTPUT_ID", RECORDS[0]["layer"] + "__" + RECORDS[0]["name"])
    selected = [record for record in RECORDS if record["layer"] + "__" + record["name"] == selected_id]
    if len(selected) != 1:
        raise RuntimeError("JOUVENCE_OUTPUT_ID must select exactly one output owned by this notebook")
    RECORD = selected[0]
    object_path = RECORD["canonical_uri"].removeprefix("gs://")
    if "#" in object_path:
        raise RuntimeError("canonical object key must not already contain a generation suffix")
    expected_generation = RECORD["qc"]["generation"]
    pinned_path = object_path + "#" + expected_generation
    info = fs.info(pinned_path)
    if str(info.get("generation", "")) != expected_generation:
        raise RuntimeError("generation-qualified object resolved a different generation")
    with fs.open(pinned_path, "rb") as handle:
        parquet = pq.ParquetFile(handle)
        live_fields = [
            {"name": field.name, "dtype": str(field.type), "nullable": bool(field.nullable)}
            for field in parquet.schema_arrow
        ]
        live_rows = parquet.metadata.num_rows
        live_row_groups = parquet.metadata.num_row_groups
    if live_rows != RECORD["qc"]["rows"]:
        raise RuntimeError("live footer row count differs from the frozen registry")
    if live_row_groups != RECORD["qc"]["row_groups"]:
        raise RuntimeError("live footer row-group count differs from the frozen registry")
    if live_fields != RECORD["fields"]:
        raise RuntimeError("live footer schema differs from the frozen registry")
    live_result = {"status": "PASS", "generation": str(info["generation"]), "rows": live_rows, "row_groups": live_row_groups}
live_result
