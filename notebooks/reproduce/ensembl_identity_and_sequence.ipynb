# %% [markdown]
# # Reproduce Ensembl release 114 GRCh38 identity and sequence
#
# Generated by reproduce/generate_parquet_reproduction_notebooks.py; do not edit.
#
# ## Objective and meaning
#
# Document the coherent `ensembl` acquisition/build/mapping pipeline and safely verify all 9 current canonical Parquets assigned to it.
#
# Grouping justification: these outputs share a defensible source/transformation family context. Exact producer and command evidence remains per output and may be absent; layer alone is not used as a grouping rule, and differences remain explicit in each output contract.
#
# ## Canonical outputs owned by this notebook
#
# | Layer | Canonical output | Rows | Replay level | Catalog |
# |---|---|---:|---|---|
# | `edges` | `gene_has_transcript` | 507,365 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__gene_has_transcript.md) |
# | `edges` | `organism_has_gene` | 109,325 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__organism_has_gene.md) |
# | `edges` | `transcript_encodes_protein` | 233,995 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/edges__transcript_encodes_protein.md) |
# | `features` | `protein_sequence` | 112,051 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/features__protein_sequence.md) |
# | `features` | `transcript_sequence` | 187,268 | `documented-not-replayed` | [catalog](../../docs/parquet-catalog/datasets/features__transcript_sequence.md) |
# | `nodes` | `gene` | 267,830 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/nodes__gene.md) |
# | `nodes` | `organism` | 1 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/nodes__organism.md) |
# | `nodes` | `protein` | 233,995 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/nodes__protein.md) |
# | `nodes` | `transcript` | 507,365 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/nodes__transcript.md) |

# %% [markdown]
# ## Native inputs, release, acquisition and environment
#
# Shared acquisition context is stated once; release and retained input differences are restated under every owned output.
#
# ## Expected schema and identifiers
#
# Each output section carries its exact catalog schema, row count, object generation and checksum.
#
# ## Keys, mappings and joins
#
# Shared family mappings are applied only where stated; every output preserves its own key contract.
#
# ## Cleaning, normalization, transformations and filters
#
# Transformation and filter differences are explicit per output below.
#
# ## Deduplication and assertion/evidence semantics
#
# Canonical edges are deduplicated assertions; source-specific multiplicity and context remain evidence/features where applicable.
#
# ## Quarantines, exclusions and missing data
#
# Every output contract states its known exclusions and unresolved provenance.
#
# ## Problems encountered and decisions
#
# Known decisions and alternatives are reported conservatively; migration identity is not treated as proof of biological replayability.
#
# ## Producer / builder
#
# The per-output contracts name an evidenced tracked producer or state that it is unavailable.
#
# ## Full worker rebuild command (inert text; never executed by this notebook)
#
# Any command below is documentation only and remains approved-worker, staging and review gated.
#
# ## Migration receipt
#
# Every output includes its generation-matched, verified migration receipt.
#
# ## QC, bounded replay and verification
#
# The first code cell validates all embedded output contracts offline. The opt-in cell verifies one selected GCS object metadata record and Parquet footer, chosen with `JOUVENCE_OUTPUT_ID`; it never scans all family outputs.
#
# ## Reproducibility limits
#
# Replay levels remain per output. No family-level label upgrades weaker members.
#
# ## Linked code, tests, reports and historical notebooks
#
# Links are listed in each output contract.

# %% [markdown]
# ## Per-output reproduction contracts
#
# ### Output `edges__gene_has_transcript`
#
# - Canonical URI: `gs://jouvencekb/main/edges/gene_has_transcript.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__gene_has_transcript.md`](../../docs/parquet-catalog/datasets/edges__gene_has_transcript.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Transcription
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Ensembl release 114, GRCh38
#
# - `gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **507,365**; bytes: **3,889,581**; row groups: **1**; schema hash (`arrow-fields-v1`): `446b99597208f274249b3197ade88b09514891a85167d284f85a58280a260657`; generation: `1785155483713373`; CRC32C: `JFerpQ==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
# | `transcript_biotype` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.
#
# **Problems encountered and decisions.** Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/gene_has_transcript.parquet`
# - Destination generation: `1785155483713373`
# - Destination CRC32C: `JFerpQ==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__gene_has_transcript.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_sequence_features.py`
#
#
# ### Output `edges__organism_has_gene`
#
# - Canonical URI: `gs://jouvencekb/main/edges/organism_has_gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__organism_has_gene.md`](../../docs/parquet-catalog/datasets/edges__organism_has_gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Ensembl species
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Ensembl release 114, GRCh38
#
# - `gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **109,325**; bytes: **653,414**; row groups: **1**; schema hash (`arrow-fields-v1`): `078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1`; generation: `1785155488582377`; CRC32C: `gv9lcw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.
#
# **Problems encountered and decisions.** Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/organism_has_gene.parquet`
# - Destination generation: `1785155488582377`
# - Destination CRC32C: `gv9lcw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__organism_has_gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_sequence_features.py`
#
#
# ### Output `edges__transcript_encodes_protein`
#
# - Canonical URI: `gs://jouvencekb/main/edges/transcript_encodes_protein.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/edges__transcript_encodes_protein.md`](../../docs/parquet-catalog/datasets/edges__transcript_encodes_protein.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Translation
# - Does not mean: It is not evidence multiplicity: source-specific support belongs in the matching evidence table.
#
# **Native inputs and release.** Ensembl release 114, GRCh38
#
# - `gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **233,995**; bytes: **2,581,718**; row groups: **1**; schema hash (`arrow-fields-v1`): `078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1`; generation: `1785155490317765`; CRC32C: `SDt59g==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `x_id` | `large_string` | `true` |
# | `x_type` | `large_string` | `true` |
# | `y_id` | `large_string` | `true` |
# | `y_type` | `large_string` | `true` |
# | `relation` | `large_string` | `true` |
# | `display_relation` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `credibility` | `int64` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `relation`, `x_id`, `y_id`
# - Candidate/join key: none declared
# - Linkage: `x_id -> nodes/<x_type>.id`, `y_id -> nodes/<y_type>.id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.
#
# **Problems encountered and decisions.** Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/edges/transcript_encodes_protein.parquet`
# - Destination generation: `1785155490317765`
# - Destination CRC32C: `SDt59g==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/edges__transcript_encodes_protein.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_sequence_features.py`
#
#
# ### Output `features__protein_sequence`
#
# - Canonical URI: `gs://jouvencekb/main/features/protein_sequence.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__protein_sequence.md`](../../docs/parquet-catalog/datasets/features__protein_sequence.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Ensembl human protein sequences keyed to canonical protein nodes.
# - Does not mean: Rows are sequences, not protein-function labels or one row for every protein node.
#
# **Native inputs and release.** Ensembl release 114, GRCh38
#
# - `gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **112,051**; bytes: **32,214,242**; row groups: **1**; schema hash (`arrow-fields-v1`): `23cdb2ed216cdf3f4b1a901bafc54c4581cdc54c1bc9132840c90b8b8cc043a9`; generation: `1785155496344724`; CRC32C: `KJ2Gbg==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `feature_key` | `string` | `true` |
# | `feature_table` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `sequence_kind` | `string` | `true` |
# | `sequence` | `string` | `true` |
# | `length` | `int64` | `true` |
# | `alphabet` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `source_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
# | `created_at` | `string` | `true` |
# | `checksum_sha256` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `feature_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.
#
# **Problems encountered and decisions.** Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.
#
# Known gaps: `verified exact rebuild command`.
#
# **Producer / builder.** `manage_db/build_sequence_features.py`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/protein_sequence.parquet`
# - Destination generation: `1785155496344724`
# - Destination CRC32C: `KJ2Gbg==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__protein_sequence.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_sequence_features.py`
#
#
# ### Output `features__transcript_sequence`
#
# - Canonical URI: `gs://jouvencekb/main/features/transcript_sequence.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__transcript_sequence.md`](../../docs/parquet-catalog/datasets/features__transcript_sequence.md)
# - Replay level: **`documented-not-replayed`**
# - Meaning: Ensembl human transcript cDNA sequences keyed to canonical transcript nodes.
# - Does not mean: Rows are cDNA payloads, not gene-level sequence or protein sequence.
#
# **Native inputs and release.** Ensembl release 114, GRCh38
#
# - `gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **187,268**; bytes: **137,652,176**; row groups: **2**; schema hash (`arrow-fields-v1`): `23cdb2ed216cdf3f4b1a901bafc54c4581cdc54c1bc9132840c90b8b8cc043a9`; generation: `1785155496824664`; CRC32C: `bz9Cjw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `feature_key` | `string` | `true` |
# | `feature_table` | `string` | `true` |
# | `node_id` | `string` | `true` |
# | `node_type` | `string` | `true` |
# | `sequence_kind` | `string` | `true` |
# | `sequence` | `string` | `true` |
# | `length` | `int64` | `true` |
# | `alphabet` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_dataset` | `string` | `true` |
# | `source_record_id` | `string` | `true` |
# | `source_release` | `string` | `true` |
# | `provenance` | `string` | `true` |
# | `license` | `string` | `true` |
# | `citation` | `string` | `true` |
# | `created_at` | `string` | `true` |
# | `checksum_sha256` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `feature_key`, `node_id`
# - Linkage: `node_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.
#
# **Problems encountered and decisions.** Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.
#
# Known gaps: none declared.
#
# **Producer / builder.** `manage_db/build_sequence_features.py`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# ```text
# uv run python -m manage_db.build_sequence_features --kg-root <worker-local-main> --output-root artifacts/staged/<task-id>/sequence-features --transcript-fasta <worker-local-raw>/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz --source-release 'Ensembl release 114'
# ```
#
# This exact argv is preserved as documentation only. It must run on an approved in-region worker, against worker-local verified inputs, with task-local staging and review before any canonical write.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/transcript_sequence.parquet`
# - Destination generation: `1785155496824664`
# - Destination CRC32C: `bz9Cjw==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__transcript_sequence.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_sequence_features.py`
#
#
# ### Output `nodes__gene`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/gene.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__gene.md`](../../docs/parquet-catalog/datasets/nodes__gene.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Canonical gene registry keyed in the Ensembl namespace (example `ENSG00000139618`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** Ensembl release 114, GRCh38
#
# - `gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **267,830**; bytes: **6,644,666**; row groups: **1**; schema hash (`arrow-fields-v1`): `d7b5b9adb0bfb598bf4dc1e7930fac535128eab56f5f81b730ae1589f0e9e477`; generation: `1785155478279997`; CRC32C: `Cg9rzA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `legacy_type` | `large_string` | `true` |
# | `legacy_id` | `large_string` | `true` |
# | `legacy_index` | `double` | `true` |
# | `source` | `large_string` | `true` |
# | `ncbi_gene_id` | `large_string` | `true` |
# | `hgnc_id` | `large_string` | `true` |
# | `uniprot_id` | `large_string` | `true` |
# | `gene_name` | `large_string` | `true` |
# | `drugbank_id` | `large_string` | `true` |
# | `pubchem_cid` | `double` | `true` |
# | `cas_rn` | `double` | `true` |
# | `inchikey` | `double` | `true` |
# | `smiles` | `double` | `true` |
# | `mondo_id` | `large_string` | `true` |
# | `efo_id` | `double` | `true` |
# | `mp_id` | `double` | `true` |
# | `mesh_id` | `double` | `true` |
# | `hp_id` | `large_string` | `true` |
# | `omim_id` | `double` | `true` |
# | `doid_id` | `double` | `true` |
# | `icd10_code` | `double` | `true` |
# | `go_id` | `large_string` | `true` |
# | `kegg_id` | `double` | `true` |
# | `bto_id` | `double` | `true` |
# | `fma_id` | `double` | `true` |
# | `name` | `large_string` | `true` |
# | `description` | `large_string` | `true` |
# | `biotype` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.
#
# **Problems encountered and decisions.** Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/gene.parquet`
# - Destination generation: `1785155478279997`
# - Destination CRC32C: `Cg9rzA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__gene.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_sequence_features.py`
#
#
# ### Output `nodes__organism`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/organism.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__organism.md`](../../docs/parquet-catalog/datasets/nodes__organism.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Canonical organism registry keyed in the NCBI Taxonomy namespace (example `NCBITaxon:9606`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** Ensembl release 114, GRCh38
#
# - `gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **1**; bytes: **3,797**; row groups: **1**; schema hash (`arrow-fields-v1`): `ab459f4ca3986c3e291816e43f73426ad32beab483dab981289776530da5ae22`; generation: `1785155479099323`; CRC32C: `bR8jqA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `taxonomy_id` | `large_string` | `true` |
# | `gbif_id` | `large_string` | `true` |
# | `name` | `large_string` | `true` |
# | `scientific_name` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.
#
# **Problems encountered and decisions.** Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/organism.parquet`
# - Destination generation: `1785155479099323`
# - Destination CRC32C: `bR8jqA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__organism.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_sequence_features.py`
#
#
# ### Output `nodes__protein`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/protein.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__protein.md`](../../docs/parquet-catalog/datasets/nodes__protein.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Canonical protein registry keyed in the Ensembl Protein namespace (example `ENSP00000369497`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** Ensembl release 114, GRCh38
#
# - `gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **233,995**; bytes: **4,121,076**; row groups: **1**; schema hash (`arrow-fields-v1`): `cfae0aa369007228c98ebb50dad2bde772ffc7494de2a3de6971aa6222fc4c60`; generation: `1785155479835352`; CRC32C: `ZJjYGA==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `name` | `large_string` | `true` |
# | `ensembl_gene_id` | `large_string` | `true` |
# | `uniprot_id` | `large_string` | `true` |
# | `refseq_protein` | `large_string` | `true` |
# | `pdb_ids` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.
#
# **Problems encountered and decisions.** Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/protein.parquet`
# - Destination generation: `1785155479835352`
# - Destination CRC32C: `ZJjYGA==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__protein.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_sequence_features.py`
#
#
# ### Output `nodes__transcript`
#
# - Canonical URI: `gs://jouvencekb/main/nodes/transcript.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/nodes__transcript.md`](../../docs/parquet-catalog/datasets/nodes__transcript.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Canonical transcript registry keyed in the Ensembl namespace (example `ENST00000380152`).
# - Does not mean: Presence is an identifier/registry assertion, not evidence for any biological relation.
#
# **Native inputs and release.** Ensembl release 114, GRCh38
#
# - `gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz`
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **507,365**; bytes: **8,645,861**; row groups: **1**; schema hash (`arrow-fields-v1`): `f5dc2a0159d2ac00cb9fd1373764d9e302c2bd46787944a4bb41c02e7b61bdf4`; generation: `1785155480231163`; CRC32C: `SEbSog==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `id` | `large_string` | `true` |
# | `name` | `large_string` | `true` |
# | `ensembl_gene_id` | `large_string` | `true` |
# | `protein_id` | `large_string` | `true` |
# | `refseq_mrna` | `large_string` | `true` |
# | `ccds_id` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: `id`
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.
#
# **Cleaning, normalization, transformations and filters.** Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.
#
# **Problems encountered and decisions.** Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.
#
# Known gaps: `current builder`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/nodes/transcript.parquet`
# - Destination generation: `1785155480231163`
# - Destination CRC32C: `SEbSog==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/nodes__transcript.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `reproduce/29_official_features_exports_reproduction.ipynb`
# - `manage_db/build_sequence_features.py`

# %% [markdown]
# ## Offline bounded contract check
#
# This cell uses only the embedded frozen lineage record.

# %%
import hashlib
import json

RECORDS = json.loads(r'''[{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/gene_has_transcript.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__gene_has_transcript.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true},{"dtype":"large_string","name":"transcript_biotype","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__gene_has_transcript.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_sequence_features.py"],"mappings_and_joins":"Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.","meaning":"Transcription","migration_receipt":{"action":"copied","destination_crc32c":"JFerpQ==","destination_generation":"1785155483713373","source":"kg/v2/edges/gene_has_transcript.parquet","source_generation":"1781019624875742","verified":true},"name":"gene_has_transcript","native_inputs":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"native_source":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"ensembl","problems_and_decisions":"Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":3889581,"crc32c_base64":"JFerpQ==","generation":"1785155483713373","md5_base64":"ykQ5YRSi0zT+wvJ+IE9mkA==","row_groups":1,"rows":507365,"schema_hash":"446b99597208f274249b3197ade88b09514891a85167d284f85a58280a260657","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.","rebuild_command_evidenced":false,"release":"Ensembl release 114, GRCh38","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/ensembl_identity_and_sequence.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"ensembl","source_family_label":"Ensembl release 114 GRCh38 identity and sequence","transformations_and_filters":"Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/organism_has_gene.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__organism_has_gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__organism_has_gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_sequence_features.py"],"mappings_and_joins":"Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.","meaning":"Ensembl species","migration_receipt":{"action":"copied","destination_crc32c":"gv9lcw==","destination_generation":"1785155488582377","source":"kg/v2/edges/organism_has_gene.parquet","source_generation":"1781178275367319","verified":true},"name":"organism_has_gene","native_inputs":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"native_source":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"ensembl","problems_and_decisions":"Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":653414,"crc32c_base64":"gv9lcw==","generation":"1785155488582377","md5_base64":"Vlsl4+PNukG20/M/pgFYrQ==","row_groups":1,"rows":109325,"schema_hash":"078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.","rebuild_command_evidenced":false,"release":"Ensembl release 114, GRCh38","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/ensembl_identity_and_sequence.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"ensembl","source_family_label":"Ensembl release 114 GRCh38 identity and sequence","transformations_and_filters":"Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/edges/transcript_encodes_protein.parquet","catalog_page":"docs/parquet-catalog/datasets/edges__transcript_encodes_protein.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"x_id","nullable":true},{"dtype":"large_string","name":"x_type","nullable":true},{"dtype":"large_string","name":"y_id","nullable":true},{"dtype":"large_string","name":"y_type","nullable":true},{"dtype":"large_string","name":"relation","nullable":true},{"dtype":"large_string","name":"display_relation","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"int64","name":"credibility","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":["x_id -> nodes/<x_type>.id","y_id -> nodes/<y_type>.id"],"source_contract":["relation","x_id","y_id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"edges","links":["docs/parquet-catalog/datasets/edges__transcript_encodes_protein.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_sequence_features.py"],"mappings_and_joins":"Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.","meaning":"Translation","migration_receipt":{"action":"copied","destination_crc32c":"SDt59g==","destination_generation":"1785155490317765","source":"kg/v2/edges/transcript_encodes_protein.parquet","source_generation":"1781019627138325","verified":true},"name":"transcript_encodes_protein","native_inputs":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"native_source":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"non_meaning":"It is not evidence multiplicity: source-specific support belongs in the matching evidence table.","pipeline_family":"ensembl","problems_and_decisions":"Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":2581718,"crc32c_base64":"SDt59g==","generation":"1785155490317765","md5_base64":"J6tjflA9s3mja4Xk1Eascw==","row_groups":1,"rows":233995,"schema_hash":"078d21dc5c592b2abc8eb0eefa1d8758ac533baabeaed459e9491c17acbfc5c1","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.","rebuild_command_evidenced":false,"release":"Ensembl release 114, GRCh38","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/ensembl_identity_and_sequence.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"ensembl","source_family_label":"Ensembl release 114 GRCh38 identity and sequence","transformations_and_filters":"Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/protein_sequence.parquet","catalog_page":"docs/parquet-catalog/datasets/features__protein_sequence.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"feature_key","nullable":true},{"dtype":"string","name":"feature_table","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"sequence_kind","nullable":true},{"dtype":"string","name":"sequence","nullable":true},{"dtype":"int64","name":"length","nullable":true},{"dtype":"string","name":"alphabet","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"source_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"checksum_sha256","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["feature_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["verified exact rebuild command"],"layer":"features","links":["docs/parquet-catalog/datasets/features__protein_sequence.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_sequence_features.py"],"mappings_and_joins":"Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.","meaning":"Ensembl human protein sequences keyed to canonical protein nodes.","migration_receipt":{"action":"copied","destination_crc32c":"KJ2Gbg==","destination_generation":"1785155496344724","source":"kg/v2/features/protein_sequence.parquet","source_generation":"1782169822702242","verified":true},"name":"protein_sequence","native_inputs":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"native_source":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"non_meaning":"Rows are sequences, not protein-function labels or one row for every protein node.","pipeline_family":"ensembl","problems_and_decisions":"Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.","producer":"manage_db/build_sequence_features.py","producer_builder":"manage_db/build_sequence_features.py","provenance_gaps":["verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":32214242,"crc32c_base64":"KJ2Gbg==","generation":"1785155496344724","md5_base64":"pdmnKfOl7yhaECHW+X9ssQ==","row_groups":1,"rows":112051,"schema_hash":"23cdb2ed216cdf3f4b1a901bafc54c4581cdc54c1bc9132840c90b8b8cc043a9","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.","rebuild_command_evidenced":false,"release":"Ensembl release 114, GRCh38","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/ensembl_identity_and_sequence.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"ensembl","source_family_label":"Ensembl release 114 GRCh38 identity and sequence","transformations_and_filters":"Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/transcript_sequence.parquet","catalog_page":"docs/parquet-catalog/datasets/features__transcript_sequence.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"feature_key","nullable":true},{"dtype":"string","name":"feature_table","nullable":true},{"dtype":"string","name":"node_id","nullable":true},{"dtype":"string","name":"node_type","nullable":true},{"dtype":"string","name":"sequence_kind","nullable":true},{"dtype":"string","name":"sequence","nullable":true},{"dtype":"int64","name":"length","nullable":true},{"dtype":"string","name":"alphabet","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_dataset","nullable":true},{"dtype":"string","name":"source_record_id","nullable":true},{"dtype":"string","name":"source_release","nullable":true},{"dtype":"string","name":"provenance","nullable":true},{"dtype":"string","name":"license","nullable":true},{"dtype":"string","name":"citation","nullable":true},{"dtype":"string","name":"created_at","nullable":true},{"dtype":"string","name":"checksum_sha256","nullable":true}],"full_worker_rebuild_command":"uv run python -m manage_db.build_sequence_features --kg-root <worker-local-main> --output-root artifacts/staged/<task-id>/sequence-features --transcript-fasta <worker-local-raw>/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz --source-release 'Ensembl release 114'","keys":{"candidate_join":["feature_key","node_id"],"linkage":["node_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":[],"layer":"features","links":["docs/parquet-catalog/datasets/features__transcript_sequence.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_sequence_features.py"],"mappings_and_joins":"Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.","meaning":"Ensembl human transcript cDNA sequences keyed to canonical transcript nodes.","migration_receipt":{"action":"copied","destination_crc32c":"bz9Cjw==","destination_generation":"1785155496824664","source":"kg/v2/features/transcript_sequence.parquet","source_generation":"1782169828167398","verified":true},"name":"transcript_sequence","native_inputs":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"native_source":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"non_meaning":"Rows are cDNA payloads, not gene-level sequence or protein sequence.","pipeline_family":"ensembl","problems_and_decisions":"Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.","producer":"manage_db/build_sequence_features.py","producer_builder":"manage_db/build_sequence_features.py","provenance_gaps":[],"qc":{"as_of":"2026-07-27","bytes":137652176,"crc32c_base64":"bz9Cjw==","generation":"1785155496824664","md5_base64":"TKpPK0phr6IFBBbJQ8zYQg==","row_groups":2,"rows":187268,"schema_hash":"23cdb2ed216cdf3f4b1a901bafc54c4581cdc54c1bc9132840c90b8b8cc043a9","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.","rebuild_command_evidenced":true,"release":"Ensembl release 114, GRCh38","replay_level":"documented-not-replayed","reproduce_notebook":"notebooks/reproduce/ensembl_identity_and_sequence.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"documented-not-replayed","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"ensembl","source_family_label":"Ensembl release 114 GRCh38 identity and sequence","transformations_and_filters":"Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/gene.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__gene.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"large_string","name":"legacy_type","nullable":true},{"dtype":"large_string","name":"legacy_id","nullable":true},{"dtype":"double","name":"legacy_index","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"large_string","name":"ncbi_gene_id","nullable":true},{"dtype":"large_string","name":"hgnc_id","nullable":true},{"dtype":"large_string","name":"uniprot_id","nullable":true},{"dtype":"large_string","name":"gene_name","nullable":true},{"dtype":"large_string","name":"drugbank_id","nullable":true},{"dtype":"double","name":"pubchem_cid","nullable":true},{"dtype":"double","name":"cas_rn","nullable":true},{"dtype":"double","name":"inchikey","nullable":true},{"dtype":"double","name":"smiles","nullable":true},{"dtype":"large_string","name":"mondo_id","nullable":true},{"dtype":"double","name":"efo_id","nullable":true},{"dtype":"double","name":"mp_id","nullable":true},{"dtype":"double","name":"mesh_id","nullable":true},{"dtype":"large_string","name":"hp_id","nullable":true},{"dtype":"double","name":"omim_id","nullable":true},{"dtype":"double","name":"doid_id","nullable":true},{"dtype":"double","name":"icd10_code","nullable":true},{"dtype":"large_string","name":"go_id","nullable":true},{"dtype":"double","name":"kegg_id","nullable":true},{"dtype":"double","name":"bto_id","nullable":true},{"dtype":"double","name":"fma_id","nullable":true},{"dtype":"large_string","name":"name","nullable":true},{"dtype":"large_string","name":"description","nullable":true},{"dtype":"string","name":"biotype","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__gene.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_sequence_features.py"],"mappings_and_joins":"Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.","meaning":"Canonical gene registry keyed in the Ensembl namespace (example `ENSG00000139618`).","migration_receipt":{"action":"copied","destination_crc32c":"Cg9rzA==","destination_generation":"1785155478279997","source":"kg/v2/nodes/gene.parquet","source_generation":"1781617033173178","verified":true},"name":"gene","native_inputs":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"native_source":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"ensembl","problems_and_decisions":"Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":6644666,"crc32c_base64":"Cg9rzA==","generation":"1785155478279997","md5_base64":"+mANvLavlb8cGaU2zmhkcQ==","row_groups":1,"rows":267830,"schema_hash":"d7b5b9adb0bfb598bf4dc1e7930fac535128eab56f5f81b730ae1589f0e9e477","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.","rebuild_command_evidenced":false,"release":"Ensembl release 114, GRCh38","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/ensembl_identity_and_sequence.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"ensembl","source_family_label":"Ensembl release 114 GRCh38 identity and sequence","transformations_and_filters":"Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/organism.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__organism.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"large_string","name":"taxonomy_id","nullable":true},{"dtype":"large_string","name":"gbif_id","nullable":true},{"dtype":"large_string","name":"name","nullable":true},{"dtype":"large_string","name":"scientific_name","nullable":true},{"dtype":"large_string","name":"source","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__organism.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_sequence_features.py"],"mappings_and_joins":"Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.","meaning":"Canonical organism registry keyed in the NCBI Taxonomy namespace (example `NCBITaxon:9606`).","migration_receipt":{"action":"copied","destination_crc32c":"bR8jqA==","destination_generation":"1785155479099323","source":"kg/v2/nodes/organism.parquet","source_generation":"1781178274773290","verified":true},"name":"organism","native_inputs":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"native_source":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"ensembl","problems_and_decisions":"Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":3797,"crc32c_base64":"bR8jqA==","generation":"1785155479099323","md5_base64":"BfpZ6Aso8rZerMVlkS8DdA==","row_groups":1,"rows":1,"schema_hash":"ab459f4ca3986c3e291816e43f73426ad32beab483dab981289776530da5ae22","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.","rebuild_command_evidenced":false,"release":"Ensembl release 114, GRCh38","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/ensembl_identity_and_sequence.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"ensembl","source_family_label":"Ensembl release 114 GRCh38 identity and sequence","transformations_and_filters":"Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/protein.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__protein.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"large_string","name":"name","nullable":true},{"dtype":"large_string","name":"ensembl_gene_id","nullable":true},{"dtype":"large_string","name":"uniprot_id","nullable":true},{"dtype":"large_string","name":"refseq_protein","nullable":true},{"dtype":"large_string","name":"pdb_ids","nullable":true},{"dtype":"large_string","name":"source","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__protein.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_sequence_features.py"],"mappings_and_joins":"Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.","meaning":"Canonical protein registry keyed in the Ensembl Protein namespace (example `ENSP00000369497`).","migration_receipt":{"action":"copied","destination_crc32c":"ZJjYGA==","destination_generation":"1785155479835352","source":"kg/v2/nodes/protein.parquet","source_generation":"1781017349893351","verified":true},"name":"protein","native_inputs":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"native_source":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"ensembl","problems_and_decisions":"Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":4121076,"crc32c_base64":"ZJjYGA==","generation":"1785155479835352","md5_base64":"l9jzgVfnLERaIq8qtS9qRg==","row_groups":1,"rows":233995,"schema_hash":"cfae0aa369007228c98ebb50dad2bde772ffc7494de2a3de6971aa6222fc4c60","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.","rebuild_command_evidenced":false,"release":"Ensembl release 114, GRCh38","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/ensembl_identity_and_sequence.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"ensembl","source_family_label":"Ensembl release 114 GRCh38 identity and sequence","transformations_and_filters":"Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/nodes/transcript.parquet","catalog_page":"docs/parquet-catalog/datasets/nodes__transcript.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"id","nullable":true},{"dtype":"large_string","name":"name","nullable":true},{"dtype":"large_string","name":"ensembl_gene_id","nullable":true},{"dtype":"large_string","name":"protein_id","nullable":true},{"dtype":"large_string","name":"refseq_mrna","nullable":true},{"dtype":"large_string","name":"ccds_id","nullable":true},{"dtype":"large_string","name":"source","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":["id"],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","verified exact rebuild command"],"layer":"nodes","links":["docs/parquet-catalog/datasets/nodes__transcript.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","reproduce/29_official_features_exports_reproduction.ipynb","manage_db/build_sequence_features.py"],"mappings_and_joins":"Strip Ensembl version suffixes and join exact ENSG/ENST/ENSP identifiers to canonical typed endpoints.","meaning":"Canonical transcript registry keyed in the Ensembl namespace (example `ENST00000380152`).","migration_receipt":{"action":"copied","destination_crc32c":"SEbSog==","destination_generation":"1785155480231163","source":"kg/v2/nodes/transcript.parquet","source_generation":"1781019622726860","verified":true},"name":"transcript","native_inputs":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"native_source":["gs://jouvencekb/raw/ensembl_Homo_sapiens_GRCh38_cdna_release_114.fa.gz"],"non_meaning":"Presence is an identifier/registry assertion, not evidence for any biological relation.","pipeline_family":"ensembl","problems_and_decisions":"Transcript cDNA is retained and current code exists; protein FASTA and the complete node/central-dogma build inputs are not retained in the current raw surface.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":8645861,"crc32c_base64":"SEbSog==","generation":"1785155480231163","md5_base64":"vwNdAmX6l0YZoU4iz40usw==","row_groups":1,"rows":507365,"schema_hash":"f5dc2a0159d2ac00cb9fd1373764d9e302c2bd46787944a4bb41c02e7b61bdf4","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"Reject non-matching IDs, invalid sequence symbols and over-policy lengths; do not invent protein sequences from transcript sequence.","rebuild_command_evidenced":false,"release":"Ensembl release 114, GRCh38","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/ensembl_identity_and_sequence.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"ensembl","source_family_label":"Ensembl release 114 GRCh38 identity and sequence","transformations_and_filters":"Parse release-pinned FASTA or identity tables, normalize sequence alphabets and emit deterministic source-feature keys."}]''')

def require(condition, message):
    if not condition:
        raise RuntimeError(message)

for RECORD in RECORDS:
    require(RECORD["canonical_uri"] == "gs://jouvencekb/main/" + ("embeddings" if RECORD["layer"] == "embedding" else RECORD["layer"]) + "/" + RECORD["name"] + ".parquet", "canonical URI/identity mismatch")
    require(RECORD["replay_level"] in ['documented-not-replayed', 'fully-replayable', 'historical-builder-only', 'provenance-gap'], "unsupported replay level")
    require(RECORD["qc"]["rows"] >= 0, "negative expected row count")
    require(len(RECORD["qc"]["schema_hash"]) == 64, "invalid schema hash")
    require(RECORD["migration_receipt"]["verified"] is True, "migration receipt is not verified")
    require(bool(RECORD["fields"]), "empty expected schema")
summary = {
    "pipeline_family": RECORDS[0]["pipeline_family"],
    "output_count": len(RECORDS),
    "identities": [record["layer"] + "__" + record["name"] for record in RECORDS],
}
summary

# %% [markdown]
# ## Optional bounded live canonical footer check
#
# This cell is skipped unless the caller explicitly opts in.

# %%
import os

if os.environ.get("JOUVENCE_LIVE_GCS") != "1":
    live_result = {"status": "SKIPPED", "reason": "set JOUVENCE_LIVE_GCS=1 and caller-owned JOUVENCE_BILLING_PROJECT"}
else:
    import gcsfs
    import pyarrow.parquet as pq

    billing_project = os.environ.get("JOUVENCE_BILLING_PROJECT")
    if not billing_project:
        raise RuntimeError("JOUVENCE_BILLING_PROJECT is required for requester-pays live verification")
    fs = gcsfs.GCSFileSystem(project=billing_project, requester_pays=billing_project, version_aware=True)
    if not fs.version_aware:
        raise RuntimeError("version-aware GCS reads are required")
    selected_id = os.environ.get("JOUVENCE_OUTPUT_ID", RECORDS[0]["layer"] + "__" + RECORDS[0]["name"])
    selected = [record for record in RECORDS if record["layer"] + "__" + record["name"] == selected_id]
    if len(selected) != 1:
        raise RuntimeError("JOUVENCE_OUTPUT_ID must select exactly one output owned by this notebook")
    RECORD = selected[0]
    object_path = RECORD["canonical_uri"].removeprefix("gs://")
    if "#" in object_path:
        raise RuntimeError("canonical object key must not already contain a generation suffix")
    expected_generation = RECORD["qc"]["generation"]
    pinned_path = object_path + "#" + expected_generation
    info = fs.info(pinned_path)
    if str(info.get("generation", "")) != expected_generation:
        raise RuntimeError("generation-qualified object resolved a different generation")
    with fs.open(pinned_path, "rb") as handle:
        parquet = pq.ParquetFile(handle)
        live_fields = [
            {"name": field.name, "dtype": str(field.type), "nullable": bool(field.nullable)}
            for field in parquet.schema_arrow
        ]
        live_rows = parquet.metadata.num_rows
        live_row_groups = parquet.metadata.num_row_groups
    if live_rows != RECORD["qc"]["rows"]:
        raise RuntimeError("live footer row count differs from the frozen registry")
    if live_row_groups != RECORD["qc"]["row_groups"]:
        raise RuntimeError("live footer row-group count differs from the frozen registry")
    if live_fields != RECORD["fields"]:
        raise RuntimeError("live footer schema differs from the frozen registry")
    live_result = {"status": "PASS", "generation": str(info["generation"]), "rows": live_rows, "row_groups": live_row_groups}
live_result
