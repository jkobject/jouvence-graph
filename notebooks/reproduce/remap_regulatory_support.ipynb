# %% [markdown]
# # Reproduce ReMap CRM aggregate support
#
# Generated by reproduce/generate_parquet_reproduction_notebooks.py; do not edit.
#
# ## Objective and meaning
#
# Document the coherent `remap` acquisition/build/mapping pipeline and safely verify all 2 current canonical Parquets assigned to it.
#
# Grouping justification: these outputs share a defensible source/transformation family context. Exact producer and command evidence remains per output and may be absent; layer alone is not used as a grouping rule, and differences remain explicit in each output contract.
#
# ## Canonical outputs owned by this notebook
#
# | Layer | Canonical output | Rows | Replay level | Catalog |
# |---|---|---:|---|---|
# | `features` | `mutation_overlaps_enhancer_support` | 10,501 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/features__mutation_overlaps_enhancer_support.md) |
# | `features` | `remap_crm_tf_enhancer_support` | 48,768,788 | `historical-builder-only` | [catalog](../../docs/parquet-catalog/datasets/features__remap_crm_tf_enhancer_support.md) |

# %% [markdown]
# ## Native inputs, release, acquisition and environment
#
# Shared acquisition context is stated once; release and retained input differences are restated under every owned output.
#
# ## Expected schema and identifiers
#
# Each output section carries its exact catalog schema, row count, object generation and checksum.
#
# ## Keys, mappings and joins
#
# Shared family mappings are applied only where stated; every output preserves its own key contract.
#
# ## Cleaning, normalization, transformations and filters
#
# Transformation and filter differences are explicit per output below.
#
# ## Deduplication and assertion/evidence semantics
#
# Canonical edges are deduplicated assertions; source-specific multiplicity and context remain evidence/features where applicable.
#
# ## Quarantines, exclusions and missing data
#
# Every output contract states its known exclusions and unresolved provenance.
#
# ## Problems encountered and decisions
#
# Known decisions and alternatives are reported conservatively; migration identity is not treated as proof of biological replayability.
#
# ## Producer / builder
#
# The per-output contracts name an evidenced tracked producer or state that it is unavailable.
#
# ## Full worker rebuild command (inert text; never executed by this notebook)
#
# Any command below is documentation only and remains approved-worker, staging and review gated.
#
# ## Migration receipt
#
# Every output includes its generation-matched, verified migration receipt.
#
# ## QC, bounded replay and verification
#
# The first code cell validates all embedded output contracts offline. The opt-in cell verifies one selected GCS object metadata record and Parquet footer, chosen with `JOUVENCE_OUTPUT_ID`; it never scans all family outputs.
#
# ## Reproducibility limits
#
# Replay levels remain per output. No family-level label upgrades weaker members.
#
# ## Linked code, tests, reports and historical notebooks
#
# Links are listed in each output contract.

# %% [markdown]
# ## Per-output reproduction contracts
#
# ### Output `features__mutation_overlaps_enhancer_support`
#
# - Canonical URI: `gs://jouvencekb/main/features/mutation_overlaps_enhancer_support.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__mutation_overlaps_enhancer_support.md`](../../docs/parquet-catalog/datasets/features__mutation_overlaps_enhancer_support.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: Canonical public `mutation_overlaps_enhancer_support` features table.
# - Does not mean: Interpret only according to its columns and linked provenance; it is not an implicit graph relation.
#
# **Native inputs and release.** ReMap 2022, GRCh38/hg38
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **10,501**; bytes: **400,857**; row groups: **1**; schema hash (`arrow-fields-v1`): `70072b8263d1b09cf6458a1f1ff1a7132d473e88879a0ee3bf92eb95049d8cef`; generation: `1785155497327474`; CRC32C: `Guac4g==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `support_relation` | `large_string` | `true` |
# | `mutation_id` | `large_string` | `true` |
# | `support_target_id` | `large_string` | `true` |
# | `support_target_type` | `large_string` | `true` |
# | `source` | `large_string` | `true` |
# | `source_dataset` | `large_string` | `true` |
# | `source_record_id` | `large_string` | `true` |
# | `study_id` | `large_string` | `true` |
# | `evidence_score` | `double` | `true` |
# | `effect_size` | `double` | `true` |
# | `p_value` | `double` | `true` |
# | `direction` | `large_string` | `true` |
# | `predicate` | `large_string` | `true` |
# | `text_span` | `large_string` | `true` |
# | `support_class` | `large_string` | `true` |
# | `is_context_only_support` | `bool` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: none declared
# - Linkage: none declared
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join TF gene identifiers and enhancer intervals only as aggregate support keys; retain genome build and aggregation policy.
#
# **Cleaning, normalization, transformations and filters.** Aggregate chromosome-level CRM support shards and compact them byte-independently with row-count/SHA-256 validation.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** This is support/QA, not graph topology, observed TF binding or TF-to-gene regulation.
#
# **Problems encountered and decisions.** The migration receipt preserves all historical shard names and compaction checks, but no selected native ReMap raw object or current source-native builder is retained.
#
# Known gaps: `current builder`, `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `copied`
# - Preserved pre-migration source object(s):
#   - `kg/v2/metadata/mutation_overlaps_enhancer_support_rows_t_73c67c1b.parquet`
# - Destination generation: `1785155497327474`
# - Destination CRC32C: `Guac4g==`
# - Verified migration readback: `True`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__mutation_overlaps_enhancer_support.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `docs/remap_crm_canonical_readiness.md`
#
#
# ### Output `features__remap_crm_tf_enhancer_support`
#
# - Canonical URI: `gs://jouvencekb/main/features/remap_crm_tf_enhancer_support.parquet`
# - Catalog: [`docs/parquet-catalog/datasets/features__remap_crm_tf_enhancer_support.md`](../../docs/parquet-catalog/datasets/features__remap_crm_tf_enhancer_support.md)
# - Replay level: **`historical-builder-only`**
# - Meaning: ReMap 2022 compact CRM aggregate support/QA features.
# - Does not mean: Not graph topology, not observed binding, and not canonical `tf_binds_enhancer` edge/evidence.
#
# **Native inputs and release.** ReMap 2022, GRCh38/hg38
#
# - No selected native input is retained or resolvable from current evidence.
#
# **Acquisition/preconditions.** Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.
#
# **Expected schema and identifiers.** Rows: **48,768,788**; bytes: **2,907,628,799**; row groups: **49**; schema hash (`arrow-fields-v1`): `410c411da7c752c91ee74ecf60af84dbf16c8e945d72ae247e87ced97da94cfa`; generation: `1785155751509875`; CRC32C: `fo/bVw==`.
#
# | Column | Arrow dtype | Nullable |
# |---|---|---:|
# | `feature_table` | `string` | `true` |
# | `support_entity_type` | `string` | `true` |
# | `tf_gene_id` | `string` | `true` |
# | `tf_symbol_sample` | `string` | `true` |
# | `enhancer_id` | `string` | `true` |
# | `enhancer_chromosome` | `string` | `true` |
# | `enhancer_start` | `int64` | `true` |
# | `enhancer_end` | `int64` | `true` |
# | `support_entity_id` | `string` | `true` |
# | `support_entity_label` | `string` | `true` |
# | `crm_support_rows` | `int64` | `true` |
# | `crm_interval_count` | `int64` | `true` |
# | `evidence_type` | `string` | `true` |
# | `support_semantics` | `string` | `true` |
# | `relation_under_review` | `string` | `true` |
# | `support_scope` | `string` | `true` |
# | `source` | `string` | `true` |
# | `source_release` | `string` | `true` |
# | `source_url` | `string` | `true` |
# | `genome_build` | `string` | `true` |
# | `liftover_performed` | `bool` | `true` |
# | `aggregation_policy` | `string` | `true` |
# | `provenance_caveat` | `string` | `true` |
# | `source_task_id` | `string` | `true` |
# | `promotion_task_id` | `string` | `true` |
# | `source_report` | `string` | `true` |
# | `readiness_decision_doc` | `string` | `true` |
#
# **Keys, mappings and joins.**
#
# - Source-contract key: none declared
# - Candidate/join key: `support_entity_id`
# - Linkage: `enhancer_id`, `tf_gene_id`
# - Uniqueness note: uniqueness unvalidated by footer-only catalog collection
#
# Join TF gene identifiers and enhancer intervals only as aggregate support keys; retain genome build and aggregation policy.
#
# **Cleaning, normalization, transformations and filters.** Aggregate chromosome-level CRM support shards and compact them byte-independently with row-count/SHA-256 validation.
#
# **Deduplication and assertion/evidence semantics.** Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.
#
# **Quarantines, exclusions and missing data.** This is support/QA, not graph topology, observed TF binding or TF-to-gene regulation.
#
# **Problems encountered and decisions.** The migration receipt preserves all historical shard names and compaction checks, but no selected native ReMap raw object or current source-native builder is retained.
#
# Known gaps: `current builder`, `retained native input`, `verified exact rebuild command`.
#
# **Producer / builder.** `not available as a current tracked builder`.
#
# **Full worker rebuild command (inert; never executed here).**
#
# No verified exact full rebuild command is available. The lineage registry deliberately leaves this gap explicit rather than synthesizing an argv.
#
# **Migration receipt and QC.**
#
# - Action: `compacted`
# - Preserved pre-migration source object(s):
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr1.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr2.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr3.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr4.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr5.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr6.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr7.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr8.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr9.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr10.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr11.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr12.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr13.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr14.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr15.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr16.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr17.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr18.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr19.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr20.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr21.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr22.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chrX.parquet`
#   - `kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chrY.parquet`
# - Destination generation: `1785155751509875`
# - Destination CRC32C: `fo/bVw==`
# - Verified migration readback: `True`
# - Destination SHA-256: `3b9cbc952139fe6f37fff0321f1e42373674de1fee148848d6e141a7d8b520e2`
#
# **Safe bounded replay.** Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.
#
# **Reproducibility limits.** This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.
#
# **Linked code, tests, reports and historical notebooks.**
#
# - `docs/parquet-catalog/datasets/features__remap_crm_tf_enhancer_support.md`
# - `docs/parquet-catalog/inventory.json`
# - `docs/storage-migration-20260727/README.md`
# - `docs/storage-migration-20260727/object-map.json`
# - `docs/remap_crm_canonical_readiness.md`

# %% [markdown]
# ## Offline bounded contract check
#
# This cell uses only the embedded frozen lineage record.

# %%
import hashlib
import json

RECORDS = json.loads(r'''[{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/mutation_overlaps_enhancer_support.parquet","catalog_page":"docs/parquet-catalog/datasets/features__mutation_overlaps_enhancer_support.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"large_string","name":"support_relation","nullable":true},{"dtype":"large_string","name":"mutation_id","nullable":true},{"dtype":"large_string","name":"support_target_id","nullable":true},{"dtype":"large_string","name":"support_target_type","nullable":true},{"dtype":"large_string","name":"source","nullable":true},{"dtype":"large_string","name":"source_dataset","nullable":true},{"dtype":"large_string","name":"source_record_id","nullable":true},{"dtype":"large_string","name":"study_id","nullable":true},{"dtype":"double","name":"evidence_score","nullable":true},{"dtype":"double","name":"effect_size","nullable":true},{"dtype":"double","name":"p_value","nullable":true},{"dtype":"large_string","name":"direction","nullable":true},{"dtype":"large_string","name":"predicate","nullable":true},{"dtype":"large_string","name":"text_span","nullable":true},{"dtype":"large_string","name":"support_class","nullable":true},{"dtype":"bool","name":"is_context_only_support","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":[],"linkage":[],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","retained native input","verified exact rebuild command"],"layer":"features","links":["docs/parquet-catalog/datasets/features__mutation_overlaps_enhancer_support.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","docs/remap_crm_canonical_readiness.md"],"mappings_and_joins":"Join TF gene identifiers and enhancer intervals only as aggregate support keys; retain genome build and aggregation policy.","meaning":"Canonical public `mutation_overlaps_enhancer_support` features table.","migration_receipt":{"action":"copied","destination_crc32c":"Guac4g==","destination_generation":"1785155497327474","source":"kg/v2/metadata/mutation_overlaps_enhancer_support_rows_t_73c67c1b.parquet","source_generation":"1782342625323144","verified":true},"name":"mutation_overlaps_enhancer_support","native_inputs":[],"native_source":[],"non_meaning":"Interpret only according to its columns and linked provenance; it is not an implicit graph relation.","pipeline_family":"remap","problems_and_decisions":"The migration receipt preserves all historical shard names and compaction checks, but no selected native ReMap raw object or current source-native builder is retained.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":400857,"crc32c_base64":"Guac4g==","generation":"1785155497327474","md5_base64":"e63XJEqLZMXoIY64BiMGnA==","row_groups":1,"rows":10501,"schema_hash":"70072b8263d1b09cf6458a1f1ff1a7132d473e88879a0ee3bf92eb95049d8cef","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"This is support/QA, not graph topology, observed TF binding or TF-to-gene regulation.","rebuild_command_evidenced":false,"release":"ReMap 2022, GRCh38/hg38","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/remap_regulatory_support.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"remap","source_family_label":"ReMap CRM aggregate support","transformations_and_filters":"Aggregate chromosome-level CRM support shards and compact them byte-independently with row-count/SHA-256 validation."},{"acquisition_and_preconditions":"Read-only by default. Network, requester-pays GCS and production rebuilds require explicit opt-in; full rebuilds run only on an approved in-region worker with task-local staging.","canonical_uri":"gs://jouvencekb/main/features/remap_crm_tf_enhancer_support.parquet","catalog_page":"docs/parquet-catalog/datasets/features__remap_crm_tf_enhancer_support.md","deduplication_and_evidence":"Deduplicate graph assertions by the declared relation/endpoint contract. Preserve source-specific multiplicity, scores, studies, assays and predicates in evidence or feature sidecars; do not treat migration copies as biological evidence.","fields":[{"dtype":"string","name":"feature_table","nullable":true},{"dtype":"string","name":"support_entity_type","nullable":true},{"dtype":"string","name":"tf_gene_id","nullable":true},{"dtype":"string","name":"tf_symbol_sample","nullable":true},{"dtype":"string","name":"enhancer_id","nullable":true},{"dtype":"string","name":"enhancer_chromosome","nullable":true},{"dtype":"int64","name":"enhancer_start","nullable":true},{"dtype":"int64","name":"enhancer_end","nullable":true},{"dtype":"string","name":"support_entity_id","nullable":true},{"dtype":"string","name":"support_entity_label","nullable":true},{"dtype":"int64","name":"crm_support_rows","nullable":true},{"dtype":"int64","name":"crm_interval_count","nullable":true},{"dtype":"string","name":"evidence_type","nullable":true},{"dtype":"string","name":"support_semantics","nullable":true},{"dtype":"string","name":"relation_under_review","nullable":true},{"dtype":"string","name":"support_scope","nullable":true},{"dtype":"string","name":"source","nullable":true},{"dtype":"string","name":"source_release","nullable":true},{"dtype":"string","name":"source_url","nullable":true},{"dtype":"string","name":"genome_build","nullable":true},{"dtype":"bool","name":"liftover_performed","nullable":true},{"dtype":"string","name":"aggregation_policy","nullable":true},{"dtype":"string","name":"provenance_caveat","nullable":true},{"dtype":"string","name":"source_task_id","nullable":true},{"dtype":"string","name":"promotion_task_id","nullable":true},{"dtype":"string","name":"source_report","nullable":true},{"dtype":"string","name":"readiness_decision_doc","nullable":true}],"full_worker_rebuild_command":null,"keys":{"candidate_join":["support_entity_id"],"linkage":["enhancer_id","tf_gene_id"],"source_contract":[],"uniqueness":"uniqueness unvalidated by footer-only catalog collection"},"known_gaps":["current builder","retained native input","verified exact rebuild command"],"layer":"features","links":["docs/parquet-catalog/datasets/features__remap_crm_tf_enhancer_support.md","docs/parquet-catalog/inventory.json","docs/storage-migration-20260727/README.md","docs/storage-migration-20260727/object-map.json","docs/remap_crm_canonical_readiness.md"],"mappings_and_joins":"Join TF gene identifiers and enhancer intervals only as aggregate support keys; retain genome build and aggregation policy.","meaning":"ReMap 2022 compact CRM aggregate support/QA features.","migration_receipt":{"action":"compacted","destination_crc32c":"fo/bVw==","destination_generation":"1785155751509875","destination_rows":48768788,"destination_sha256":"3b9cbc952139fe6f37fff0321f1e42373674de1fee148848d6e141a7d8b520e2","source_rows":48768788,"sources":["kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr1.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr2.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr3.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr4.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr5.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr6.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr7.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr8.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr9.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr10.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr11.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr12.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr13.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr14.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr15.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr16.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr17.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr18.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr19.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr20.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr21.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chr22.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chrX.parquet","kg/v2/features/remap_crm_tf_enhancer_support_full/summary_chrY.parquet"],"verified":true},"name":"remap_crm_tf_enhancer_support","native_inputs":[],"native_source":[],"non_meaning":"Not graph topology, not observed binding, and not canonical `tf_binds_enhancer` edge/evidence.","pipeline_family":"remap","problems_and_decisions":"The migration receipt preserves all historical shard names and compaction checks, but no selected native ReMap raw object or current source-native builder is retained.","producer":null,"producer_builder":null,"provenance_gaps":["current builder","retained native input","verified exact rebuild command"],"qc":{"as_of":"2026-07-27","bytes":2907628799,"crc32c_base64":"fo/bVw==","generation":"1785155751509875","md5_base64":null,"row_groups":49,"rows":48768788,"schema_hash":"410c411da7c752c91ee74ecf60af84dbf16c8e945d72ae247e87ced97da94cfa","schema_hash_version":"arrow-fields-v1"},"quarantines_exclusions_missing":"This is support/QA, not graph topology, observed TF binding or TF-to-gene regulation.","rebuild_command_evidenced":false,"release":"ReMap 2022, GRCh38/hg38","replay_level":"historical-builder-only","reproduce_notebook":"notebooks/reproduce/remap_regulatory_support.ipynb","reproducibility_limits":"This notebook documents and checks current artifact identity. It does not prove that historical native inputs can recreate identical biological rows unless the status and evidence explicitly establish that stronger claim.","reproducibility_status":"historical-builder-only","safe_bounded_replay":"Validate this frozen registry record, schema contract and migration receipt offline. Optional live mode reads only canonical object metadata/Parquet footer with caller-owned ADC and JOUVENCE_BILLING_PROJECT; it does not scan rows or write.","source_family":"remap","source_family_label":"ReMap CRM aggregate support","transformations_and_filters":"Aggregate chromosome-level CRM support shards and compact them byte-independently with row-count/SHA-256 validation."}]''')

def require(condition, message):
    if not condition:
        raise RuntimeError(message)

for RECORD in RECORDS:
    require(RECORD["canonical_uri"] == "gs://jouvencekb/main/" + ("embeddings" if RECORD["layer"] == "embedding" else RECORD["layer"]) + "/" + RECORD["name"] + ".parquet", "canonical URI/identity mismatch")
    require(RECORD["replay_level"] in ['documented-not-replayed', 'fully-replayable', 'historical-builder-only', 'provenance-gap'], "unsupported replay level")
    require(RECORD["qc"]["rows"] >= 0, "negative expected row count")
    require(len(RECORD["qc"]["schema_hash"]) == 64, "invalid schema hash")
    require(RECORD["migration_receipt"]["verified"] is True, "migration receipt is not verified")
    require(bool(RECORD["fields"]), "empty expected schema")
summary = {
    "pipeline_family": RECORDS[0]["pipeline_family"],
    "output_count": len(RECORDS),
    "identities": [record["layer"] + "__" + record["name"] for record in RECORDS],
}
summary

# %% [markdown]
# ## Optional bounded live canonical footer check
#
# This cell is skipped unless the caller explicitly opts in.

# %%
import os

if os.environ.get("JOUVENCE_LIVE_GCS") != "1":
    live_result = {"status": "SKIPPED", "reason": "set JOUVENCE_LIVE_GCS=1 and caller-owned JOUVENCE_BILLING_PROJECT"}
else:
    import gcsfs
    import pyarrow.parquet as pq

    billing_project = os.environ.get("JOUVENCE_BILLING_PROJECT")
    if not billing_project:
        raise RuntimeError("JOUVENCE_BILLING_PROJECT is required for requester-pays live verification")
    fs = gcsfs.GCSFileSystem(project=billing_project, requester_pays=billing_project, version_aware=True)
    if not fs.version_aware:
        raise RuntimeError("version-aware GCS reads are required")
    selected_id = os.environ.get("JOUVENCE_OUTPUT_ID", RECORDS[0]["layer"] + "__" + RECORDS[0]["name"])
    selected = [record for record in RECORDS if record["layer"] + "__" + record["name"] == selected_id]
    if len(selected) != 1:
        raise RuntimeError("JOUVENCE_OUTPUT_ID must select exactly one output owned by this notebook")
    RECORD = selected[0]
    object_path = RECORD["canonical_uri"].removeprefix("gs://")
    if "#" in object_path:
        raise RuntimeError("canonical object key must not already contain a generation suffix")
    expected_generation = RECORD["qc"]["generation"]
    pinned_path = object_path + "#" + expected_generation
    info = fs.info(pinned_path)
    if str(info.get("generation", "")) != expected_generation:
        raise RuntimeError("generation-qualified object resolved a different generation")
    with fs.open(pinned_path, "rb") as handle:
        parquet = pq.ParquetFile(handle)
        live_fields = [
            {"name": field.name, "dtype": str(field.type), "nullable": bool(field.nullable)}
            for field in parquet.schema_arrow
        ]
        live_rows = parquet.metadata.num_rows
        live_row_groups = parquet.metadata.num_row_groups
    if live_rows != RECORD["qc"]["rows"]:
        raise RuntimeError("live footer row count differs from the frozen registry")
    if live_row_groups != RECORD["qc"]["row_groups"]:
        raise RuntimeError("live footer row-group count differs from the frozen registry")
    if live_fields != RECORD["fields"]:
        raise RuntimeError("live footer schema differs from the frozen registry")
    live_result = {"status": "PASS", "generation": str(info["generation"]), "rows": live_rows, "row_groups": live_row_groups}
live_result
